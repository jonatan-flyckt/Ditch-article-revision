# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix, cohen_kappa_score, precision_score, recall_score
from sklearn.metrics import precision_recall_curve, auc, average_precision_score, f1_score, roc_auc_score, roc_curve
import pandas as pd
import math
from joblib import dump, load
import random
import pickle
import scipy.stats
from PIL import Image
import scipy.stats as stats

from Functions import post_processing
from Functions import general_functions
from Functions import feature_creation

from skimage.restoration import denoise_bilateral

import operator

# %%
zone_1_path = "dataset/zone_4.pickle"
zone_2_path = "dataset/zone_6.pickle"
zone_3_path = "dataset/zone_9.pickle"

# %%
file = open(zone_1_path, "rb")
zone_1 = pickle.load(file)

file = open(zone_2_path, "rb")
zone_2 = pickle.load(file)

file = open(zone_3_path, "rb")
zone_3 = pickle.load(file)

file = None

# %%
#zone_1_resampled = general_functions.create_balanced_dataset([zone_1_path])
#zone_2_resampled = general_functions.create_balanced_dataset([zone_2_path])
#zone_3_resampled = general_functions.create_balanced_dataset([zone_3_path])

#with open("dataset/zone_1_resampled.pickle", "wb") as file:
#    pickle.dump(zone_1_resampled, file)
#with open("dataset/zone_2_resampled.pickle", "wb") as file:
#    pickle.dump(zone_2_resampled, file)
#with open("dataset/zone_3_resampled.pickle", "wb") as file:
#    pickle.dump(zone_3_resampled, file)

# %%
with open("dataset/zone_1_resampled.pickle", "rb") as file:
    zone_1_resampled = pickle.load(file)
with open("dataset/zone_2_resampled.pickle", "rb") as file:
    zone_2_resampled = pickle.load(file)
with open("dataset/zone_3_resampled.pickle", "rb") as file:
    zone_3_resampled = pickle.load(file)

# %%
zone_1.shape
# Out:
# (7852140, 82)

# %%
experiment_arr = [(zone_1_resampled, pd.concat([zone_2, zone_3], ignore_index=True)),
                  (zone_2_resampled, pd.concat([zone_1, zone_3], ignore_index=True)),
                  (zone_3_resampled, pd.concat([zone_1, zone_2], ignore_index=True))]

# %%
zone_1 = None
zone_2 = None
zone_3 = None
zone_1_resampled = None
zone_2_resampled = None
zone_3_resampled = None

# %%
most_important_features = zone_1.columns.tolist()[1:]
for num_features in [81, 70, 60, 50, 40]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(y_test.reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['hpmf_raw', 'skyview_raw', 'impundment_raw', 'slope_raw', 'DEM_ditch_detection', 'DEM_ditch_detection_no_streams', 'conic_mean', 'skyview_non_ditch', 'skyview_gabor', 'conic_mean_no_streams', 'skyview_gabor_no_streams', 'skyview_mean_2', 'skyview_mean_3', 'skyview_mean_4', 'skyview_mean_6', 'skyview_median_2', 'skyview_median_4', 'skyview_median_6', 'skyview_min_2', 'skyview_min_4', 'skyview_min_6', 'skyview_max_2', 'skyview_max_4', 'skyview_max_6', 'skyview_std_2', 'skyview_std_4', 'skyview_std_6', 'impundment_amplified', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'impundment_mean_3', 'impundment_mean_4', 'impundment_mean_6', 'impundment_median_2', 'impundment_median_4', 'impundment_median_6', 'impundment_min_2', 'impundment_min_4', 'impundment_min_6', 'impundment_max_2', 'impundment_max_4', 'impundment_max_6', 'impundment_std_2', 'impundment_std_4', 'impundment_std_6', 'hpmf_filter', 'hpmf_gabor', 'hpmf_gabor_no_streams', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'hpmf_mean_3', 'hpmf_mean_4', 'hpmf_mean_6', 'hpmf_median_2', 'hpmf_median_4', 'hpmf_median_6', 'hpmf_min_2', 'hpmf_min_4', 'hpmf_min_6', 'hpmf_max_2', 'hpmf_max_4', 'hpmf_max_6', 'hpmf_std_2', 'hpmf_std_4', 'hpmf_std_6', 'slope_non_ditch', 'slope_mean_2', 'slope_mean_3', 'slope_mean_4', 'slope_mean_6', 'slope_median_2', 'slope_median_4', 'slope_median_6', 'slope_min_2', 'slope_min_4', 'slope_min_6', 'slope_max_2', 'slope_max_4', 'slope_std_2', 'slope_std_4', 'slope_std_6']
#
#
# Amount of features X_train: 81, X_test: 81
# Amount of features X_train: 81, X_test: 81
#
#
# Importances for experiment:
# impundment_mean_3  -  0.11140104949217865
# impundment_mean_4  -  0.08533342518977793
# impundment_median_4  -  0.051642368251976094
# impundment_mean_2  -  0.05116508044891698
# hpmf_mean_4  -  0.027395081130456397
# hpmf_mean_3  -  0.02494846813977584
# impundment_amplified  -  0.023836299547673176
# hpmf_median_4  -  0.022921853381576242
# impoundment_amplified_no_streams  -  0.021324217513314578
# skyview_max_6  -  0.016325016752276086
# skyview_gabor  -  0.015257568036426132
# hpmf_min_2  -  0.014931548778597103
# impundment_max_2  -  0.014517951863036085
# impundment_std_4  -  0.014492290724267208
# skyview_non_ditch  -  0.014265059104907114
# skyview_gabor_no_streams  -  0.012870908011713443
# slope_min_6  -  0.012845008204794782
# skyview_max_4  -  0.012669341389460128
# impundment_median_2  -  0.011926317780222306
# impundment_max_6  -  0.011722213672805959
# slope_non_ditch  -  0.011612177257283682
# impundment_mean_6  -  0.011159011394011507
# hpmf_filter  -  0.010961143739460938
# impundment_std_6  -  0.010713124371171528
# hpmf_filter_no_streams  -  0.010694043580895804
# impundment_median_6  -  0.010554465887270707
# hpmf_mean_6  -  0.010223633417226865
# slope_min_4  -  0.010071493657418213
# slope_std_6  -  0.009933947322907491
# hpmf_mean_2  -  0.009832274039409682
# slope_median_6  -  0.009700467803665035
# impundment_max_4  -  0.009609636577290845
# impundment_std_2  -  0.00932036484208633
# hpmf_gabor  -  0.009284939510979388
# hpmf_min_4  -  0.009242714842281192
# skyview_min_6  -  0.009094904004331328
# skyview_median_6  -  0.008883803160510736
# slope_mean_6  -  0.008840967279739443
# hpmf_gabor_no_streams  -  0.008696485115261096
# skyview_std_6  -  0.008622691011950321
# slope_min_2  -  0.008605240928087367
# hpmf_median_2  -  0.008485571754175879
# skyview_max_2  -  0.008412893977767259
# hpmf_std_6  -  0.00833430469080771
# slope_std_4  -  0.008277408889045178
# hpmf_min_6  -  0.008086275056659422
# slope_max_4  -  0.007896769379420953
# skyview_mean_6  -  0.007398770891023244
# hpmf_max_6  -  0.007174168981367961
# skyview_min_4  -  0.007115100101143801
# hpmf_std_4  -  0.007112424930280013
# slope_median_4  -  0.006905449067725928
# skyview_median_4  -  0.006853044266602616
# skyview_std_4  -  0.006835510269263605
# slope_std_2  -  0.006656479746839964
# hpmf_std_2  -  0.00652907806556364
# hpmf_median_6  -  0.006090280860928951
# slope_mean_4  -  0.00606756219236952
# slope_median_2  -  0.006063600037012493
# slope_raw  -  0.00584015477858678
# skyview_std_2  -  0.005717419643836744
# skyview_median_2  -  0.005608919314970536
# slope_max_2  -  0.005562426861877437
# slope_mean_2  -  0.005535159572851472
# slope_mean_3  -  0.005390929341164436
# skyview_min_2  -  0.005317102998420246
# skyview_mean_4  -  0.005158298358374849
# hpmf_max_4  -  0.005138881109451124
# conic_mean  -  0.004969757901426474
# skyview_raw  -  0.0048547765317784024
# skyview_mean_3  -  0.004840746296686292
# impundment_raw  -  0.004835598920572228
# skyview_mean_2  -  0.004830819686842057
# conic_mean_no_streams  -  0.004729186969566177
# hpmf_raw  -  0.004095816154978296
# hpmf_max_2  -  0.003820739303170591
# DEM_ditch_detection  -  0.002139789822194655
# DEM_ditch_detection_no_streams  -  0.0021119510968501906
# impundment_min_2  -  0.0015878425527806068
# impundment_min_4  -  0.0001703924682305643
# impundment_min_6  -  0.0
#
#
# Amount of features used:   81
# Cohen's kappa score         0.42246783127431276
# Accuracy score              0.9573622604793088
# Recall score                0.7195363940976807
# Precision score             0.3181410082055405
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_gabor', 'hpmf_min_2', 'impundment_max_2', 'impundment_std_4', 'skyview_non_ditch', 'skyview_gabor_no_streams', 'slope_min_6', 'skyview_max_4', 'impundment_median_2', 'impundment_max_6', 'slope_non_ditch', 'impundment_mean_6', 'hpmf_filter', 'impundment_std_6', 'hpmf_filter_no_streams', 'impundment_median_6', 'hpmf_mean_6', 'slope_min_4', 'slope_std_6', 'hpmf_mean_2', 'slope_median_6', 'impundment_max_4', 'impundment_std_2', 'hpmf_gabor', 'hpmf_min_4', 'skyview_min_6', 'skyview_median_6', 'slope_mean_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'slope_min_2', 'hpmf_median_2', 'skyview_max_2', 'hpmf_std_6', 'slope_std_4', 'hpmf_min_6', 'slope_max_4', 'skyview_mean_6', 'hpmf_max_6', 'skyview_min_4']
#
#
# Amount of features X_train: 50, X_test: 50
# Amount of features X_train: 50, X_test: 50
#
#
# Importances for experiment:
# impundment_mean_3  -  0.18390612532709993
# impundment_mean_4  -  0.08288631291157962
# impundment_median_4  -  0.05543792638922354
# impundment_mean_2  -  0.040737422823273986
# impundment_amplified  -  0.028332397887918612
# impoundment_amplified_no_streams  -  0.024675790784764597
# hpmf_median_4  -  0.02152348153085143
# skyview_max_6  -  0.0214938280621578
# hpmf_mean_4  -  0.021136290593798998
# skyview_gabor  -  0.018516693323575015
# skyview_non_ditch  -  0.017916766829509354
# slope_min_6  -  0.01647776696711388
# skyview_max_4  -  0.01625016004747165
# skyview_gabor_no_streams  -  0.015471735792177057
# slope_median_6  -  0.014578869615682798
# impundment_max_6  -  0.014200510389525947
# hpmf_filter  -  0.01418237699465141
# skyview_median_6  -  0.014150572749908009
# slope_non_ditch  -  0.013991944493628323
# impundment_std_4  -  0.013647063378846037
# slope_std_6  -  0.013625292012728798
# hpmf_filter_no_streams  -  0.013616798226524146
# impundment_median_6  -  0.01355734967023233
# hpmf_mean_6  -  0.013301535936600719
# slope_min_4  -  0.013113931226487359
# hpmf_mean_3  -  0.013022955950555783
# impundment_mean_6  -  0.01288549963587169
# slope_min_2  -  0.012873282288939185
# slope_mean_6  -  0.012748230436108447
# skyview_max_2  -  0.012466051096648525
# slope_std_4  -  0.012431872310147054
# impundment_median_2  -  0.012403263982664347
# hpmf_std_6  -  0.012156793501987912
# skyview_min_6  -  0.012135848131376189
# impundment_std_6  -  0.01206483395580825
# hpmf_min_4  -  0.011988835717566617
# skyview_std_6  -  0.01179419398966469
# slope_max_4  -  0.011419991627498982
# hpmf_min_2  -  0.01111871117270049
# impundment_max_4  -  0.010995365819271501
# skyview_min_4  -  0.01095738826707851
# hpmf_mean_2  -  0.010926516512052105
# hpmf_gabor  -  0.010577243149328354
# hpmf_gabor_no_streams  -  0.010555478101517485
# hpmf_min_6  -  0.010290935734196868
# hpmf_max_6  -  0.01026766354089213
# skyview_mean_6  -  0.01019180454386723
# impundment_max_2  -  0.009807454829577116
# impundment_std_2  -  0.008894052873200983
# hpmf_median_2  -  0.008296788866148302
#
#
# Amount of features used:   50
# Cohen's kappa score         0.4287659646094656
# Accuracy score              0.9587795174309169
# Recall score                0.7124483846470013
# Precision score             0.3257753874914897
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'hpmf_mean_4', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'slope_median_6', 'impundment_max_6', 'hpmf_filter', 'skyview_median_6', 'slope_non_ditch', 'impundment_std_4', 'slope_std_6', 'hpmf_filter_no_streams', 'impundment_median_6', 'hpmf_mean_6', 'slope_min_4', 'hpmf_mean_3', 'impundment_mean_6', 'slope_min_2', 'slope_mean_6', 'skyview_max_2', 'slope_std_4', 'impundment_median_2', 'hpmf_std_6', 'skyview_min_6', 'impundment_std_6']
#
#
# Amount of features X_train: 35, X_test: 35
# Amount of features X_train: 35, X_test: 35
#
#
# Importances for experiment:
# impundment_mean_3  -  0.24244795557932985
# impundment_mean_4  -  0.08432736087789963
# impundment_median_4  -  0.0388092899220288
# impundment_amplified  -  0.03251683866253853
# hpmf_median_4  -  0.03118670696959252
# impoundment_amplified_no_streams  -  0.028045894954289236
# impundment_mean_2  -  0.027217779007092942
# skyview_max_6  -  0.026985516470386973
# skyview_gabor  -  0.022675503374476158
# skyview_non_ditch  -  0.022007487612412495
# slope_min_6  -  0.021017947802288117
# hpmf_mean_6  -  0.02095768259936462
# skyview_median_6  -  0.02076454892104481
# skyview_max_4  -  0.020226109773617825
# skyview_min_6  -  0.019821431685024232
# impundment_max_6  -  0.01977314120542649
# slope_std_6  -  0.019183601799426755
# slope_median_6  -  0.018554641515288357
# skyview_gabor_no_streams  -  0.018325961575512806
# hpmf_std_6  -  0.018014174636441588
# impundment_std_4  -  0.017923229390831262
# slope_std_4  -  0.017805878935558656
# hpmf_filter  -  0.01733938839714691
# impundment_median_6  -  0.017288995195260635
# slope_mean_6  -  0.01695695106192286
# hpmf_mean_4  -  0.0168580164682762
# hpmf_filter_no_streams  -  0.016660844290777018
# slope_min_4  -  0.016617786277927364
# slope_min_2  -  0.01644007522303985
# slope_non_ditch  -  0.016170310511932944
# hpmf_mean_3  -  0.015755673000119864
# impundment_mean_6  -  0.015600672084173949
# skyview_max_2  -  0.015583981310420682
# impundment_median_2  -  0.015129594307468835
# impundment_std_6  -  0.015009028601660299
#
#
# Amount of features used:   35
# Cohen's kappa score         0.41621420721094227
# Accuracy score              0.9569799443209113
# Recall score                0.7083164344372735
# Precision score             0.3140267081150095
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'hpmf_mean_6', 'skyview_median_6', 'skyview_max_4', 'skyview_min_6', 'impundment_max_6', 'slope_std_6', 'slope_median_6', 'skyview_gabor_no_streams', 'hpmf_std_6', 'impundment_std_4', 'slope_std_4', 'hpmf_filter', 'impundment_median_6', 'slope_mean_6']
#
#
# Amount of features X_train: 25, X_test: 25
# Amount of features X_train: 25, X_test: 25
#
#
# Importances for experiment:
# impundment_mean_3  -  0.33138518615941126
# hpmf_median_4  -  0.04342727148448863
# impundment_mean_4  -  0.042796168210811045
# impundment_amplified  -  0.035314629865210626
# skyview_non_ditch  -  0.03378305573251525
# skyview_max_6  -  0.03378030882795117
# hpmf_filter  -  0.031787976641884895
# impoundment_amplified_no_streams  -  0.031330820863758255
# hpmf_mean_6  -  0.031004631121733794
# slope_min_6  -  0.030827954168592922
# impundment_max_6  -  0.030274301261706004
# skyview_median_6  -  0.027470245898869983
# skyview_gabor  -  0.02690263734254267
# skyview_min_6  -  0.025353951554131886
# skyview_max_4  -  0.02532180198779073
# slope_median_6  -  0.024019876201305135
# impundment_mean_2  -  0.023885511736773855
# impundment_median_6  -  0.023529439759687198
# hpmf_std_6  -  0.023487122309173193
# slope_std_6  -  0.023139963861806778
# slope_std_4  -  0.022441646409829985
# skyview_gabor_no_streams  -  0.02059838443671993
# slope_mean_6  -  0.020303221874680723
# impundment_std_4  -  0.02009847571445439
# impundment_median_4  -  0.01773541657416979
#
#
# Amount of features used:   25
# Cohen's kappa score         0.3913691226381095
# Accuracy score              0.9532098892785915
# Recall score                0.6991787817007412
# Precision score             0.2915097701423361
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'hpmf_median_4', 'impundment_mean_4', 'impundment_amplified', 'skyview_non_ditch', 'skyview_max_6', 'hpmf_filter', 'impoundment_amplified_no_streams', 'hpmf_mean_6', 'slope_min_6', 'impundment_max_6', 'skyview_median_6', 'skyview_gabor', 'skyview_min_6', 'skyview_max_4', 'slope_median_6', 'impundment_mean_2', 'impundment_median_6', 'hpmf_std_6', 'slope_std_6']
#
#
# Amount of features X_train: 20, X_test: 20
# Amount of features X_train: 20, X_test: 20
#
#
# Importances for experiment:
# impundment_mean_3  -  0.33484398318485026
# impundment_mean_4  -  0.049443906161920806
# hpmf_median_4  -  0.04551625958518308
# skyview_gabor  -  0.04227984585813584
# impundment_amplified  -  0.039851171718710394
# skyview_max_6  -  0.037082286386047165
# skyview_non_ditch  -  0.03641917997911183
# impundment_max_6  -  0.036177942499159184
# hpmf_filter  -  0.03596566836281637
# impoundment_amplified_no_streams  -  0.034903098392177145
# slope_min_6  -  0.03467149537296181
# hpmf_mean_6  -  0.03458523385545402
# slope_median_6  -  0.03337964399255339
# slope_std_6  -  0.03177042685407044
# skyview_median_6  -  0.03166789852157135
# skyview_min_6  -  0.02919103503381376
# impundment_median_6  -  0.028828890761316426
# skyview_max_4  -  0.028526557720832492
# hpmf_std_6  -  0.02762284969259819
# impundment_mean_2  -  0.02727262606671612
#
#
# Amount of features used:   20
# Cohen's kappa score         0.38874236243557125
# Accuracy score              0.95289475225862
# Recall score                0.6965956323272026
# Precision score             0.2894306184651749
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'skyview_gabor', 'impundment_amplified', 'skyview_max_6', 'skyview_non_ditch', 'impundment_max_6', 'hpmf_filter', 'impoundment_amplified_no_streams', 'slope_min_6', 'hpmf_mean_6', 'slope_median_6', 'slope_std_6', 'skyview_median_6']
#
#
# Amount of features X_train: 15, X_test: 15
# Amount of features X_train: 15, X_test: 15
#
#
# Importances for experiment:
# impundment_mean_3  -  0.34775284216106117
# impundment_mean_4  -  0.05727652908612463
# skyview_max_6  -  0.05457676890527161
# hpmf_median_4  -  0.052350334614881075
# skyview_gabor  -  0.049865310181650115
# impundment_max_6  -  0.04764716249764005
# impundment_amplified  -  0.046527155382335664
# hpmf_filter  -  0.04605643356834952
# slope_min_6  -  0.04364170707940975
# skyview_non_ditch  -  0.04331386229251148
# slope_median_6  -  0.043055767792790606
# hpmf_mean_6  -  0.04299191898329817
# slope_std_6  -  0.042596239400762265
# impoundment_amplified_no_streams  -  0.041300895139217045
# skyview_median_6  -  0.04104707291469675
#
#
# Amount of features used:   15
# Cohen's kappa score         0.37761785359429245
# Accuracy score              0.9512891390117854
# Recall score                0.6892381478628454
# Precision score             0.2800985382969733
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'skyview_max_6', 'hpmf_median_4', 'skyview_gabor', 'impundment_max_6', 'impundment_amplified', 'hpmf_filter', 'slope_min_6', 'skyview_non_ditch']
#
#
# Amount of features X_train: 10, X_test: 10
# Amount of features X_train: 10, X_test: 10
#
#
# Importances for experiment:
# impundment_mean_3  -  0.36209244278058955
# impundment_amplified  -  0.09140525034266508
# skyview_max_6  -  0.07852251479539618
# skyview_gabor  -  0.07327717696382681
# impundment_mean_4  -  0.07266614920983369
# impundment_max_6  -  0.06813181569291227
# hpmf_filter  -  0.06614200204913973
# slope_min_6  -  0.06592470263572334
# hpmf_median_4  -  0.0642373494614153
# skyview_non_ditch  -  0.0576005960684981
#
#
# Amount of features used:   10
# Cohen's kappa score         0.3320598002814307
# Accuracy score              0.941501934504479
# Recall score                0.6889087895127947
# Precision score             0.23933660717578606
#
# ------------------------------------------------------

# %%
most_important_features = zone_4.columns.tolist()[1:]
zone_4 = None
zone_7 = None
zone_4_resampled = None
zone_7_resampled = None
for num_features in [81, 65, 62, 59, 56, 53, 50, 47, 44, 41, 38, 35]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        pred = clf.predict(X_test)

        for i, pred_var in enumerate(pred):
            y_test_all.append(y_test[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['hpmf_raw', 'skyview_raw', 'impundment_raw', 'slope_raw', 'DEM_ditch_detection', 'DEM_ditch_detection_no_streams', 'conic_mean', 'skyview_non_ditch', 'skyview_gabor', 'conic_mean_no_streams', 'skyview_gabor_no_streams', 'skyview_mean_2', 'skyview_mean_3', 'skyview_mean_4', 'skyview_mean_6', 'skyview_median_2', 'skyview_median_4', 'skyview_median_6', 'skyview_min_2', 'skyview_min_4', 'skyview_min_6', 'skyview_max_2', 'skyview_max_4', 'skyview_max_6', 'skyview_std_2', 'skyview_std_4', 'skyview_std_6', 'impundment_amplified', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'impundment_mean_3', 'impundment_mean_4', 'impundment_mean_6', 'impundment_median_2', 'impundment_median_4', 'impundment_median_6', 'impundment_min_2', 'impundment_min_4', 'impundment_min_6', 'impundment_max_2', 'impundment_max_4', 'impundment_max_6', 'impundment_std_2', 'impundment_std_4', 'impundment_std_6', 'hpmf_filter', 'hpmf_gabor', 'hpmf_gabor_no_streams', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'hpmf_mean_3', 'hpmf_mean_4', 'hpmf_mean_6', 'hpmf_median_2', 'hpmf_median_4', 'hpmf_median_6', 'hpmf_min_2', 'hpmf_min_4', 'hpmf_min_6', 'hpmf_max_2', 'hpmf_max_4', 'hpmf_max_6', 'hpmf_std_2', 'hpmf_std_4', 'hpmf_std_6', 'slope_non_ditch', 'slope_mean_2', 'slope_mean_3', 'slope_mean_4', 'slope_mean_6', 'slope_median_2', 'slope_median_4', 'slope_median_6', 'slope_min_2', 'slope_min_4', 'slope_min_6', 'slope_max_2', 'slope_max_4', 'slope_std_2', 'slope_std_4', 'slope_std_6']
#
#
# Amount of features X_train: 81, X_test: 81
# Amount of features X_train: 81, X_test: 81
#
#
# Importances for experiment:
# impundment_mean_3  -  0.10134691373593593
# impundment_mean_4  -  0.08318861317472451
# impundment_mean_2  -  0.05822093590067458
# impundment_median_4  -  0.05651587935400597
# hpmf_mean_4  -  0.027786678680516784
# impundment_amplified  -  0.02350186967957546
# hpmf_median_4  -  0.021902650952333774
# impoundment_amplified_no_streams  -  0.02138039256892298
# hpmf_mean_3  -  0.020875557347188323
# impundment_max_2  -  0.01649622450607665
# skyview_max_6  -  0.016463256797678204
# hpmf_min_2  -  0.01557668644338321
# skyview_gabor  -  0.015349057641211038
# skyview_non_ditch  -  0.014174075815854711
# impundment_std_4  -  0.01374042769595463
# impundment_median_2  -  0.013258916179555762
# slope_min_6  -  0.012986657739605261
# skyview_gabor_no_streams  -  0.012947419604000312
# skyview_max_4  -  0.012552228703692193
# impundment_mean_6  -  0.011826108234970704
# impundment_max_6  -  0.011701684271272557
# slope_non_ditch  -  0.011571246558253432
# hpmf_filter  -  0.011037903998127048
# hpmf_mean_2  -  0.011001078993553553
# impundment_max_4  -  0.010743085583568197
# hpmf_filter_no_streams  -  0.010669439329535343
# impundment_std_6  -  0.010644893876875384
# impundment_median_6  -  0.010425374520727393
# hpmf_mean_6  -  0.01027546347031198
# hpmf_gabor  -  0.010274743396902413
# slope_min_4  -  0.010054032144040222
# slope_std_6  -  0.00992687666677276
# slope_median_6  -  0.009700572851400916
# skyview_min_6  -  0.009134666257474945
# impundment_std_2  -  0.008979857805276237
# skyview_median_6  -  0.008962027639625138
# slope_mean_6  -  0.008808717046427952
# hpmf_gabor_no_streams  -  0.00877277422305312
# skyview_std_6  -  0.00864146053538892
# slope_min_2  -  0.008555953376268372
# hpmf_std_6  -  0.00845584402041542
# skyview_max_2  -  0.00839513585463374
# hpmf_min_4  -  0.008313094218015427
# slope_std_4  -  0.008205707976824433
# slope_max_4  -  0.008047045596508717
# hpmf_min_6  -  0.007918053142550348
# skyview_mean_6  -  0.007378055611502387
# hpmf_median_2  -  0.0073636599069727094
# hpmf_max_6  -  0.007270291580893618
# hpmf_std_4  -  0.007141937839404576
# skyview_min_4  -  0.0071197525478877
# slope_median_4  -  0.006875627363310337
# skyview_std_4  -  0.006858752858412483
# skyview_median_4  -  0.0067367029168078066
# slope_std_2  -  0.0066136708026504135
# hpmf_std_2  -  0.006463865212954344
# slope_median_2  -  0.006051946352456639
# slope_mean_4  -  0.00602956505680299
# hpmf_median_6  -  0.005900656090756359
# slope_raw  -  0.005757627034614567
# skyview_std_2  -  0.00575496416542012
# skyview_median_2  -  0.005595142902447706
# slope_max_2  -  0.00559026746950697
# slope_mean_2  -  0.005517807057969503
# slope_mean_3  -  0.00543957263114918
# skyview_min_2  -  0.005302694608452803
# impundment_raw  -  0.005236785458429159
# hpmf_max_4  -  0.005157279558189147
# skyview_mean_4  -  0.0051156556015219175
# conic_mean  -  0.004997471886157944
# skyview_raw  -  0.004868188154517087
# skyview_mean_3  -  0.004841733252015784
# conic_mean_no_streams  -  0.004781461649371018
# skyview_mean_2  -  0.004775375049966167
# hpmf_raw  -  0.004247021109594505
# hpmf_max_2  -  0.0037813836553994276
# DEM_ditch_detection_no_streams  -  0.0022227728779402136
# DEM_ditch_detection  -  0.0021402328767990446
# impundment_min_2  -  0.0015895653500606556
# impundment_min_4  -  0.00017522939999977473
# impundment_min_6  -  0.0
#
#
# Amount of features used:   81
# Cohen's kappa score         0.4227754958947718
# Accuracy score              0.9574479695980969
# Recall score                0.7189212289149411
# Precision score             0.3185583473243405
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'impundment_median_4', 'hpmf_mean_4', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'hpmf_mean_3', 'impundment_max_2', 'skyview_max_6', 'hpmf_min_2', 'skyview_gabor', 'skyview_non_ditch', 'impundment_std_4', 'impundment_median_2', 'slope_min_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'impundment_mean_6', 'impundment_max_6', 'slope_non_ditch', 'hpmf_filter', 'hpmf_mean_2', 'impundment_max_4', 'hpmf_filter_no_streams', 'impundment_std_6', 'impundment_median_6', 'hpmf_mean_6', 'hpmf_gabor', 'slope_min_4', 'slope_std_6', 'slope_median_6', 'skyview_min_6', 'impundment_std_2', 'skyview_median_6', 'slope_mean_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'skyview_max_2', 'hpmf_min_4', 'slope_std_4', 'slope_max_4', 'hpmf_min_6', 'skyview_mean_6', 'hpmf_median_2', 'hpmf_max_6', 'hpmf_std_4', 'skyview_min_4', 'slope_median_4', 'skyview_std_4', 'skyview_median_4', 'slope_std_2', 'hpmf_std_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6', 'slope_raw', 'skyview_std_2', 'skyview_median_2', 'slope_max_2', 'slope_mean_2', 'slope_mean_3']
#
#
# Amount of features X_train: 65, X_test: 65
# Amount of features X_train: 65, X_test: 65
#
#
# Importances for experiment:
# impundment_mean_3  -  0.13113073946561954
# impundment_mean_4  -  0.08586146621426155
# impundment_median_4  -  0.06461382875432417
# impundment_mean_2  -  0.04940863900773332
# hpmf_mean_4  -  0.025553451595084722
# impundment_amplified  -  0.025472473376040024
# impoundment_amplified_no_streams  -  0.022563312142856205
# hpmf_median_4  -  0.021204811269731384
# skyview_max_6  -  0.018220850939165898
# hpmf_mean_3  -  0.017659532875666874
# skyview_gabor  -  0.016174424050349284
# skyview_non_ditch  -  0.015647826295409964
# slope_min_6  -  0.014123396606914767
# skyview_max_4  -  0.013788361037389434
# skyview_gabor_no_streams  -  0.01376830186761524
# impundment_max_2  -  0.01356841331480518
# impundment_median_2  -  0.012916261632640851
# impundment_std_4  -  0.01282002269174086
# impundment_max_6  -  0.012428112106917646
# slope_non_ditch  -  0.01242577833700138
# hpmf_filter  -  0.01205900718482494
# hpmf_min_2  -  0.011900808979799875
# hpmf_filter_no_streams  -  0.011673417012932247
# impundment_mean_6  -  0.01150361688563866
# impundment_median_6  -  0.011475025864970491
# hpmf_mean_6  -  0.011127646019393958
# impundment_std_6  -  0.01111907474159364
# slope_std_6  -  0.011004595087276643
# slope_min_4  -  0.010950880729337512
# slope_median_6  -  0.010705192436684602
# skyview_median_6  -  0.010194912296876024
# skyview_min_6  -  0.010074355526649165
# impundment_max_4  -  0.010047974161609867
# hpmf_min_4  -  0.009853029788573085
# skyview_max_2  -  0.009727340418370124
# slope_mean_6  -  0.009496830898092345
# hpmf_gabor_no_streams  -  0.009436914431707091
# skyview_std_6  -  0.009427650430816408
# slope_min_2  -  0.009280322912253013
# hpmf_std_6  -  0.009258215587911154
# hpmf_gabor  -  0.009193349404795412
# hpmf_mean_2  -  0.0090360643674792
# slope_std_4  -  0.00893131850361668
# slope_max_4  -  0.008681551064905467
# hpmf_min_6  -  0.008596031465397334
# hpmf_max_6  -  0.008481042040446616
# skyview_mean_6  -  0.008401944374510303
# hpmf_median_2  -  0.008337633833029469
# skyview_median_4  -  0.008094894415412933
# skyview_min_4  -  0.008062784503797462
# hpmf_std_4  -  0.00803788172626774
# skyview_std_4  -  0.007678953029302187
# slope_median_4  -  0.007531297383402042
# skyview_median_2  -  0.00748096605081267
# hpmf_std_2  -  0.007460977177114732
# slope_std_2  -  0.007422672727965011
# impundment_std_2  -  0.007321640150072301
# skyview_std_2  -  0.007139128806592166
# slope_raw  -  0.00679838239715992
# slope_median_2  -  0.006668728273891409
# slope_mean_4  -  0.006513925859906596
# slope_max_2  -  0.006281582631360617
# hpmf_median_6  -  0.006275475985180745
# slope_mean_2  -  0.006045433572784403
# slope_mean_3  -  0.005859525278217412
#
#
# Amount of features used:   65
# Cohen's kappa score         0.42758002488020674
# Accuracy score              0.9584068801626053
# Recall score                0.7157283582983334
# Precision score             0.32394397430574634
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'hpmf_mean_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'hpmf_mean_3', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'impundment_max_2', 'impundment_median_2', 'impundment_std_4', 'impundment_max_6', 'slope_non_ditch', 'hpmf_filter', 'hpmf_min_2', 'hpmf_filter_no_streams', 'impundment_mean_6', 'impundment_median_6', 'hpmf_mean_6', 'impundment_std_6', 'slope_std_6', 'slope_min_4', 'slope_median_6', 'skyview_median_6', 'skyview_min_6', 'impundment_max_4', 'hpmf_min_4', 'skyview_max_2', 'slope_mean_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_gabor', 'hpmf_mean_2', 'slope_std_4', 'slope_max_4', 'hpmf_min_6', 'hpmf_max_6', 'skyview_mean_6', 'hpmf_median_2', 'skyview_median_4', 'skyview_min_4', 'hpmf_std_4', 'skyview_std_4', 'slope_median_4', 'skyview_median_2', 'hpmf_std_2', 'slope_std_2', 'impundment_std_2', 'skyview_std_2', 'slope_raw', 'slope_median_2', 'slope_mean_4', 'slope_max_2']
#
#
# Amount of features X_train: 62, X_test: 62
# Amount of features X_train: 62, X_test: 62
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1444427966798281
# impundment_mean_4  -  0.08166379207107313
# impundment_median_4  -  0.06376454624357443
# impundment_mean_2  -  0.043312911545781804
# impundment_amplified  -  0.025768782877709402
# hpmf_mean_4  -  0.025246795067026415
# impoundment_amplified_no_streams  -  0.02308408305879297
# hpmf_median_4  -  0.022326833709215593
# skyview_max_6  -  0.018402924786240796
# skyview_gabor  -  0.016264769288046373
# skyview_non_ditch  -  0.016168883434849093
# hpmf_mean_3  -  0.01530711118999024
# hpmf_min_2  -  0.014565177224765656
# slope_min_6  -  0.014299702746123697
# skyview_max_4  -  0.014241408291018491
# skyview_gabor_no_streams  -  0.013979439729008485
# slope_non_ditch  -  0.012694484957457626
# impundment_max_6  -  0.012585836722590083
# impundment_median_2  -  0.01245500649239685
# impundment_max_2  -  0.012394330066590412
# hpmf_filter  -  0.01231625253644801
# impundment_std_4  -  0.012301522679629867
# impundment_mean_6  -  0.012147923723520696
# hpmf_filter_no_streams  -  0.011930843551913081
# hpmf_mean_6  -  0.01168802640239797
# impundment_median_6  -  0.01162479032620453
# slope_std_6  -  0.011251359286641227
# slope_min_4  -  0.011230536090392462
# impundment_max_4  -  0.010949557780774805
# impundment_std_6  -  0.010943290914377832
# slope_median_6  -  0.010915757792769376
# skyview_median_6  -  0.010526626052485083
# skyview_min_6  -  0.010324451816405091
# hpmf_gabor  -  0.0102221947756268
# skyview_max_2  -  0.009926987864793199
# slope_mean_6  -  0.00987318262923386
# hpmf_mean_2  -  0.009869097350403134
# slope_min_2  -  0.009814351097939458
# hpmf_gabor_no_streams  -  0.009707522444435283
# hpmf_std_6  -  0.00962545902235326
# skyview_std_6  -  0.009528944116060227
# hpmf_min_4  -  0.009489080838019269
# slope_std_4  -  0.009277371668952395
# slope_max_4  -  0.008919351504683003
# hpmf_min_6  -  0.008857544933599023
# hpmf_max_6  -  0.008634039740060148
# skyview_mean_6  -  0.008551928158119832
# skyview_median_4  -  0.008527217777064854
# hpmf_median_2  -  0.008309171437501308
# skyview_min_4  -  0.008257799157678675
# hpmf_std_4  -  0.008202536497866869
# slope_median_4  -  0.008110537371187821
# skyview_std_4  -  0.007841047279422749
# slope_median_2  -  0.007794442616769754
# skyview_median_2  -  0.007785575101909284
# slope_std_2  -  0.0077273240466764846
# hpmf_std_2  -  0.0076773451952884455
# skyview_std_2  -  0.00744553842597394
# slope_mean_4  -  0.0074142398759622676
# impundment_std_2  -  0.007412702941049464
# slope_raw  -  0.0072446454348152715
# slope_max_2  -  0.006832265560514403
#
#
# Amount of features used:   62
# Cohen's kappa score         0.4276444293483497
# Accuracy score              0.9583749780314665
# Recall score                0.7164796219728293
# Precision score             0.32386386007047663
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_mean_4', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'hpmf_mean_3', 'hpmf_min_2', 'slope_min_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'slope_non_ditch', 'impundment_max_6', 'impundment_median_2', 'impundment_max_2', 'hpmf_filter', 'impundment_std_4', 'impundment_mean_6', 'hpmf_filter_no_streams', 'hpmf_mean_6', 'impundment_median_6', 'slope_std_6', 'slope_min_4', 'impundment_max_4', 'impundment_std_6', 'slope_median_6', 'skyview_median_6', 'skyview_min_6', 'hpmf_gabor', 'skyview_max_2', 'slope_mean_6', 'hpmf_mean_2', 'slope_min_2', 'hpmf_gabor_no_streams', 'hpmf_std_6', 'skyview_std_6', 'hpmf_min_4', 'slope_std_4', 'slope_max_4', 'hpmf_min_6', 'hpmf_max_6', 'skyview_mean_6', 'skyview_median_4', 'hpmf_median_2', 'skyview_min_4', 'hpmf_std_4', 'slope_median_4', 'skyview_std_4', 'slope_median_2', 'skyview_median_2', 'slope_std_2', 'hpmf_std_2', 'skyview_std_2', 'slope_mean_4']
#
#
# Amount of features X_train: 59, X_test: 59
# Amount of features X_train: 59, X_test: 59
#
#
# Importances for experiment:
# impundment_mean_3  -  0.16323216950479696
# impundment_mean_4  -  0.08328514890148522
# impundment_median_4  -  0.06012183625463531
# impundment_mean_2  -  0.033720525637965605
# impundment_amplified  -  0.026469599353802005
# hpmf_mean_4  -  0.023541229799886786
# impoundment_amplified_no_streams  -  0.023198949687583684
# hpmf_median_4  -  0.022027951723099827
# skyview_max_6  -  0.018933510253137165
# skyview_gabor  -  0.01690387886731544
# hpmf_mean_3  -  0.016895300177704905
# skyview_non_ditch  -  0.01620310545999716
# slope_min_6  -  0.014812788549724253
# skyview_max_4  -  0.014740609486481187
# skyview_gabor_no_streams  -  0.014220885803749049
# impundment_std_4  -  0.013809817305652516
# impundment_max_6  -  0.013021487324521288
# slope_non_ditch  -  0.012918798910318153
# impundment_max_2  -  0.0129170915117028
# hpmf_filter  -  0.012723448635073156
# hpmf_min_2  -  0.012486385567141064
# impundment_median_2  -  0.012474254934656016
# hpmf_filter_no_streams  -  0.012237318756874373
# hpmf_mean_6  -  0.012174371261386974
# impundment_median_6  -  0.0119650070309406
# impundment_mean_6  -  0.011811879880842008
# slope_std_6  -  0.011728419434610482
# slope_min_4  -  0.011379815785916193
# slope_median_6  -  0.011301371546254681
# impundment_std_6  -  0.011193787017168893
# skyview_median_6  -  0.010879760714586214
# skyview_min_6  -  0.010569779579712904
# slope_min_2  -  0.010326198681100539
# slope_mean_6  -  0.010250698603602898
# impundment_max_4  -  0.010199330983713416
# skyview_max_2  -  0.010092532061391095
# hpmf_min_4  -  0.009956977635548998
# hpmf_mean_2  -  0.009929500167242256
# hpmf_std_6  -  0.009909533219969378
# skyview_std_6  -  0.009840282452897878
# hpmf_gabor_no_streams  -  0.009777975892391235
# hpmf_gabor  -  0.009725802246426656
# slope_std_4  -  0.009723299696056578
# slope_max_4  -  0.009394089044616659
# hpmf_min_6  -  0.009028591783574746
# skyview_mean_6  -  0.008890749934125346
# hpmf_max_6  -  0.008888451090789489
# slope_median_2  -  0.0087728948355516
# hpmf_median_2  -  0.008596792301086786
# skyview_median_4  -  0.008593814670881016
# slope_median_4  -  0.008545959600744717
# hpmf_std_4  -  0.008530060424649398
# slope_std_2  -  0.008487079726116876
# skyview_min_4  -  0.008484470250486788
# hpmf_std_2  -  0.008151447549229725
# skyview_median_2  -  0.00813259715849337
# skyview_std_4  -  0.008061279454852457
# skyview_std_2  -  0.007917884425619604
# slope_mean_4  -  0.00789142145011746
#
#
# Amount of features used:   59
# Cohen's kappa score         0.42493896755145577
# Accuracy score              0.9580339245097514
# Recall score                0.7148164984035646
# Precision score             0.3214769257889106
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_mean_4', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'hpmf_mean_3', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'impundment_std_4', 'impundment_max_6', 'slope_non_ditch', 'impundment_max_2', 'hpmf_filter', 'hpmf_min_2', 'impundment_median_2', 'hpmf_filter_no_streams', 'hpmf_mean_6', 'impundment_median_6', 'impundment_mean_6', 'slope_std_6', 'slope_min_4', 'slope_median_6', 'impundment_std_6', 'skyview_median_6', 'skyview_min_6', 'slope_min_2', 'slope_mean_6', 'impundment_max_4', 'skyview_max_2', 'hpmf_min_4', 'hpmf_mean_2', 'hpmf_std_6', 'skyview_std_6', 'hpmf_gabor_no_streams', 'hpmf_gabor', 'slope_std_4', 'slope_max_4', 'hpmf_min_6', 'skyview_mean_6', 'hpmf_max_6', 'slope_median_2', 'hpmf_median_2', 'skyview_median_4', 'slope_median_4', 'hpmf_std_4', 'slope_std_2', 'skyview_min_4', 'hpmf_std_2', 'skyview_median_2']
# Amount of features X_train: 56, X_test: 56
# Amount of features X_train: 56, X_test: 56
#
#
# Importances for experiment:
# impundment_mean_3  -  0.15724250428216957
# impundment_mean_4  -  0.08180407803189814
# impundment_median_4  -  0.0622845124549371
# impundment_mean_2  -  0.047266316461828876
# impundment_amplified  -  0.027051403706817544
# hpmf_mean_4  -  0.026849187788144643
# impoundment_amplified_no_streams  -  0.023458540661683062
# hpmf_median_4  -  0.020255672890071262
# skyview_max_6  -  0.019431705768611824
# skyview_gabor  -  0.016912709508749763
# skyview_non_ditch  -  0.016792733485545275
# slope_min_6  -  0.015266900367479585
# skyview_max_4  -  0.014875177133376506
# skyview_gabor_no_streams  -  0.014457425343139273
# impundment_std_4  -  0.014262227339428203
# impundment_max_6  -  0.013402964341934848
# slope_non_ditch  -  0.013251726497364126
# hpmf_filter  -  0.013005088332447741
# hpmf_mean_3  -  0.012933113757200514
# hpmf_filter_no_streams  -  0.012584455105503902
# hpmf_mean_6  -  0.012474571090879037
# impundment_median_6  -  0.012302035733852662
# impundment_median_2  -  0.012301260172472534
# slope_std_6  -  0.012244598322466556
# impundment_mean_6  -  0.012109737186028877
# slope_median_6  -  0.012104303892656182
# slope_min_4  -  0.0120045854656836
# hpmf_min_2  -  0.01161994431975526
# impundment_std_6  -  0.01145668029817223
# skyview_median_6  -  0.011378124307102045
# skyview_min_6  -  0.0111360055528441
# slope_mean_6  -  0.011028233534770691
# impundment_max_2  -  0.010940197727680682
# skyview_std_6  -  0.01072000371984353
# slope_min_2  -  0.010700866129031646
# skyview_max_2  -  0.010670601385212829
# hpmf_min_4  -  0.010547742069118885
# impundment_max_4  -  0.010505045851179493
# slope_std_4  -  0.010471256013594537
# hpmf_gabor  -  0.010391014505692762
# hpmf_std_6  -  0.010237806984381667
# slope_max_4  -  0.010182996621032225
# hpmf_gabor_no_streams  -  0.00998638401189933
# skyview_min_4  -  0.009863866167355177
# slope_median_4  -  0.009651412508029499
# hpmf_mean_2  -  0.009480646947171087
# slope_median_2  -  0.00946791187859317
# slope_std_2  -  0.009429863189212094
# hpmf_min_6  -  0.009362875543690788
# hpmf_max_6  -  0.0092561335234994
# skyview_mean_6  -  0.009094727109978714
# skyview_median_4  -  0.009072296914209502
# hpmf_std_4  -  0.00883562054978577
# skyview_median_2  -  0.008598763041356147
# hpmf_median_2  -  0.008518643446871761
# hpmf_std_2  -  0.008464801026563815
#
#
# Amount of features used:   56
# Cohen's kappa score         0.42862703601490804
# Accuracy score              0.9586618425040817
# Recall score                0.7141577817034631
# Precision score             0.3253002637187694
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_mean_4', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'impundment_std_4', 'impundment_max_6', 'slope_non_ditch', 'hpmf_filter', 'hpmf_mean_3', 'hpmf_filter_no_streams', 'hpmf_mean_6', 'impundment_median_6', 'impundment_median_2', 'slope_std_6', 'impundment_mean_6', 'slope_median_6', 'slope_min_4', 'hpmf_min_2', 'impundment_std_6', 'skyview_median_6', 'skyview_min_6', 'slope_mean_6', 'impundment_max_2', 'skyview_std_6', 'slope_min_2', 'skyview_max_2', 'hpmf_min_4', 'impundment_max_4', 'slope_std_4', 'hpmf_gabor', 'hpmf_std_6', 'slope_max_4', 'hpmf_gabor_no_streams', 'skyview_min_4', 'slope_median_4', 'hpmf_mean_2', 'slope_median_2', 'slope_std_2', 'hpmf_min_6', 'hpmf_max_6', 'skyview_mean_6', 'skyview_median_4', 'hpmf_std_4']
#
#
# Amount of features X_train: 53, X_test: 53
# Amount of features X_train: 53, X_test: 53
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1707045456981644
# impundment_mean_4  -  0.08139031804568958
# impundment_median_4  -  0.06578632414416101
# impundment_mean_2  -  0.04138280259195451
# impundment_amplified  -  0.02771424709004623
# impoundment_amplified_no_streams  -  0.024032379653046616
# hpmf_median_4  -  0.020934609168461245
# hpmf_mean_4  -  0.020406086905727414
# skyview_max_6  -  0.020300063351703073
# skyview_gabor  -  0.017370144271581154
# skyview_non_ditch  -  0.017177116460723067
# slope_min_6  -  0.01565261404229606
# hpmf_mean_3  -  0.015524857717013566
# skyview_max_4  -  0.015419462216291008
# skyview_gabor_no_streams  -  0.014755663649221585
# impundment_max_6  -  0.013707202177263025
# slope_non_ditch  -  0.013536960496368478
# impundment_std_4  -  0.013517115930224564
# hpmf_filter  -  0.013458704414915434
# impundment_median_6  -  0.012937876412449083
# hpmf_filter_no_streams  -  0.012907634442498178
# hpmf_mean_6  -  0.012807714152918658
# slope_std_6  -  0.012591402331455899
# slope_median_6  -  0.012511813772189833
# slope_min_4  -  0.012358210835272034
# hpmf_mean_2  -  0.012204879072078716
# impundment_mean_6  -  0.012196722737030522
# hpmf_min_2  -  0.011902948989029534
# skyview_median_6  -  0.011806557897400134
# impundment_std_6  -  0.011788972519354351
# skyview_min_6  -  0.011439262725962268
# impundment_median_2  -  0.011423463314557233
# slope_mean_6  -  0.011371265929234237
# impundment_max_2  -  0.011270258462792967
# skyview_max_2  -  0.011263967292490882
# slope_min_2  -  0.011130516054073721
# skyview_std_6  -  0.011033204213931936
# slope_std_4  -  0.010807866090633134
# hpmf_min_4  -  0.010728996837340599
# hpmf_std_6  -  0.010656674844613329
# impundment_max_4  -  0.010552450061621857
# slope_max_4  -  0.010427506657224589
# slope_median_2  -  0.010301803983040918
# hpmf_gabor_no_streams  -  0.010206566031527153
# hpmf_gabor  -  0.010121790886266729
# skyview_min_4  -  0.010119644915788917
# skyview_median_4  -  0.010038398895155795
# slope_median_4  -  0.010010419687577717
# slope_std_2  -  0.01000415201605221
# hpmf_min_6  -  0.009678843221318463
# hpmf_std_4  -  0.009649190644847112
# hpmf_max_6  -  0.009611772478474341
# skyview_mean_6  -  0.009366033568944873
#
#
# Amount of features used:   53
# Cohen's kappa score         0.43019817619890155
# Accuracy score              0.9589253375512917
# Recall score                0.7138937506294555
# Precision score             0.3269359979755899
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_mean_4', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'hpmf_mean_3', 'skyview_max_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'slope_non_ditch', 'impundment_std_4', 'hpmf_filter', 'impundment_median_6', 'hpmf_filter_no_streams', 'hpmf_mean_6', 'slope_std_6', 'slope_median_6', 'slope_min_4', 'hpmf_mean_2', 'impundment_mean_6', 'hpmf_min_2', 'skyview_median_6', 'impundment_std_6', 'skyview_min_6', 'impundment_median_2', 'slope_mean_6', 'impundment_max_2', 'skyview_max_2', 'slope_min_2', 'skyview_std_6', 'slope_std_4', 'hpmf_min_4', 'hpmf_std_6', 'impundment_max_4', 'slope_max_4', 'slope_median_2', 'hpmf_gabor_no_streams', 'hpmf_gabor', 'skyview_min_4', 'skyview_median_4', 'slope_median_4', 'slope_std_2', 'hpmf_min_6']
#
#
# Amount of features X_train: 50, X_test: 50
# Amount of features X_train: 50, X_test: 50
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1733639979356857
# impundment_mean_4  -  0.09099231432928254
# impundment_median_4  -  0.05584771114247079
# impundment_mean_2  -  0.040082108441096956
# impundment_amplified  -  0.02826774976904927
# impoundment_amplified_no_streams  -  0.024645826791725618
# hpmf_median_4  -  0.021282574838056643
# skyview_max_6  -  0.02121050869137912
# hpmf_mean_4  -  0.01978605199244248
# skyview_non_ditch  -  0.017960549088965147
# skyview_gabor  -  0.017774157760786904
# slope_min_6  -  0.016379986502495756
# skyview_max_4  -  0.016131663216786062
# hpmf_mean_3  -  0.015750340747034706
# skyview_gabor_no_streams  -  0.015269427049222602
# impundment_std_4  -  0.01440590764792954
# impundment_max_6  -  0.01418411144161737
# slope_non_ditch  -  0.014029547285601903
# hpmf_filter  -  0.013946806395361796
# hpmf_mean_6  -  0.01361216161250784
# hpmf_filter_no_streams  -  0.01350262897317419
# slope_std_6  -  0.013382671496091937
# impundment_median_6  -  0.013329811757005962
# skyview_median_6  -  0.013301008606900387
# impundment_median_2  -  0.013260786002700435
# slope_median_6  -  0.013077032263002886
# slope_min_4  -  0.012852018216425226
# impundment_mean_6  -  0.01272761137604956
# impundment_max_2  -  0.01261259922191156
# hpmf_mean_2  -  0.012309266565245378
# hpmf_std_6  -  0.012263137700472482
# skyview_min_6  -  0.012210561823280812
# slope_mean_6  -  0.012125018644860187
# impundment_std_6  -  0.01200118217241191
# skyview_std_6  -  0.011856424391667734
# skyview_max_2  -  0.011813432153071802
# slope_min_2  -  0.011668443280547808
# hpmf_min_2  -  0.011602537624542502
# hpmf_min_4  -  0.011286088835263318
# slope_std_4  -  0.011230442161584196
# slope_max_4  -  0.011091744240673489
# slope_median_2  -  0.010856734361809343
# impundment_max_4  -  0.010812458936685136
# skyview_min_4  -  0.010769729647197294
# skyview_median_4  -  0.010746563639808682
# hpmf_gabor  -  0.010667424614574025
# hpmf_gabor_no_streams  -  0.01054148750835034
# slope_median_4  -  0.01048694433790317
# slope_std_2  -  0.01047245470670517
# hpmf_min_6  -  0.010218252060584361
#
#
# Amount of features used:   50
# Cohen's kappa score         0.4283547633162076
# Accuracy score              0.9587223992440277
# Recall score                0.7123041202457394
# Precision score             0.3253890687715424
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'hpmf_mean_4', 'skyview_non_ditch', 'skyview_gabor', 'slope_min_6', 'skyview_max_4', 'hpmf_mean_3', 'skyview_gabor_no_streams', 'impundment_std_4', 'impundment_max_6', 'slope_non_ditch', 'hpmf_filter', 'hpmf_mean_6', 'hpmf_filter_no_streams', 'slope_std_6', 'impundment_median_6', 'skyview_median_6', 'impundment_median_2', 'slope_median_6', 'slope_min_4', 'impundment_mean_6', 'impundment_max_2', 'hpmf_mean_2', 'hpmf_std_6', 'skyview_min_6', 'slope_mean_6', 'impundment_std_6', 'skyview_std_6', 'skyview_max_2', 'slope_min_2', 'hpmf_min_2', 'hpmf_min_4', 'slope_std_4', 'slope_max_4', 'slope_median_2', 'impundment_max_4', 'skyview_min_4', 'skyview_median_4', 'hpmf_gabor', 'hpmf_gabor_no_streams']
#
#
# Amount of features X_train: 47, X_test: 47
# Amount of features X_train: 47, X_test: 47
#
#
# Importances for experiment:
# impundment_mean_3  -  0.19201125708822267
# impundment_mean_4  -  0.0914577109519421
# impundment_median_4  -  0.052511222118388254
# impundment_mean_2  -  0.032670060953252575
# impundment_amplified  -  0.029269549612757486
# impoundment_amplified_no_streams  -  0.025078023345685284
# hpmf_median_4  -  0.023269533369933933
# skyview_max_6  -  0.02201942160341852
# skyview_non_ditch  -  0.018529581096481215
# skyview_gabor  -  0.018462657962737772
# slope_min_6  -  0.017116839051723884
# hpmf_mean_4  -  0.01706541430363604
# skyview_max_4  -  0.016774137542052946
# skyview_gabor_no_streams  -  0.015545823660658032
# impundment_max_6  -  0.01490016263579319
# slope_median_6  -  0.014828558615792544
# hpmf_filter  -  0.014640906404314513
# hpmf_mean_6  -  0.014624594612428382
# slope_std_6  -  0.01416443337553706
# slope_non_ditch  -  0.014141930778737075
# impundment_median_6  -  0.014060724244757124
# skyview_median_6  -  0.013895234847107456
# hpmf_filter_no_streams  -  0.013880657926973383
# impundment_std_4  -  0.01377405326222823
# hpmf_std_6  -  0.013490377085420686
# slope_min_4  -  0.013437514788621038
# impundment_median_2  -  0.013351670170020306
# hpmf_mean_3  -  0.013188736503075671
# slope_mean_6  -  0.013166891499524373
# skyview_min_6  -  0.01306619793116387
# impundment_mean_6  -  0.012911287023902797
# impundment_max_2  -  0.01287200465475798
# hpmf_min_4  -  0.012732826216728808
# slope_std_4  -  0.012679864901288187
# skyview_std_6  -  0.012614782651146298
# slope_min_2  -  0.012595501914629166
# impundment_std_6  -  0.012519255030055132
# slope_median_2  -  0.01236309993494681
# skyview_max_2  -  0.012318730089678862
# hpmf_min_2  -  0.012147853455695969
# hpmf_mean_2  -  0.011832763070113723
# slope_max_4  -  0.011815583848694649
# impundment_max_4  -  0.011567558469731213
# skyview_median_4  -  0.01153301909468813
# skyview_min_4  -  0.011396031418368677
# hpmf_gabor_no_streams  -  0.010904755286817986
# hpmf_gabor  -  0.010801205596369965
#
#
# Amount of features used:   47
# Cohen's kappa score         0.42553239647891905
# Accuracy score              0.9583918524122087
# Recall score                0.7101864277140081
# Precision score             0.32296193785332417
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_non_ditch', 'skyview_gabor', 'slope_min_6', 'hpmf_mean_4', 'skyview_max_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'slope_median_6', 'hpmf_filter', 'hpmf_mean_6', 'slope_std_6', 'slope_non_ditch', 'impundment_median_6', 'skyview_median_6', 'hpmf_filter_no_streams', 'impundment_std_4', 'hpmf_std_6', 'slope_min_4', 'impundment_median_2', 'hpmf_mean_3', 'slope_mean_6', 'skyview_min_6', 'impundment_mean_6', 'impundment_max_2', 'hpmf_min_4', 'slope_std_4', 'skyview_std_6', 'slope_min_2', 'impundment_std_6', 'slope_median_2', 'skyview_max_2', 'hpmf_min_2', 'hpmf_mean_2', 'slope_max_4', 'impundment_max_4', 'skyview_median_4']
#
#
# Amount of features X_train: 44, X_test: 44
# Amount of features X_train: 44, X_test: 44
#
#
# Importances for experiment:
# impundment_mean_3  -  0.19571342532031705
# impundment_mean_4  -  0.0840275349100498
# impundment_median_4  -  0.055869373063571856
# impundment_mean_2  -  0.04048538388280143
# impundment_amplified  -  0.030333696015766114
# impoundment_amplified_no_streams  -  0.02580098188430157
# hpmf_median_4  -  0.024452257459528358
# skyview_max_6  -  0.022847342565241083
# skyview_gabor  -  0.019236390499863358
# skyview_non_ditch  -  0.019176568862182063
# slope_min_6  -  0.017931793021383573
# skyview_max_4  -  0.017490352472548574
# hpmf_mean_6  -  0.01721749598877256
# skyview_gabor_no_streams  -  0.016288308028054806
# hpmf_mean_4  -  0.01597986434515792
# impundment_max_6  -  0.015582874515273761
# slope_median_6  -  0.015305985865796547
# hpmf_filter  -  0.015292453219856873
# hpmf_filter_no_streams  -  0.014787397094485625
# slope_std_6  -  0.014773889244485222
# skyview_median_6  -  0.01475579728697908
# slope_non_ditch  -  0.014751703762702927
# impundment_median_6  -  0.014719652399660277
# impundment_median_2  -  0.014421709262780025
# skyview_min_6  -  0.014362023721572751
# hpmf_std_6  -  0.014216296820269328
# slope_min_4  -  0.014132394051285725
# impundment_std_4  -  0.013809942827562795
# slope_mean_6  -  0.01371806023039045
# hpmf_mean_3  -  0.013619449231043645
# skyview_std_6  -  0.013610612177514081
# hpmf_min_4  -  0.01356368303098296
# impundment_mean_6  -  0.01330148585537964
# slope_min_2  -  0.013264721394191735
# slope_std_4  -  0.01322296816295634
# hpmf_min_2  -  0.013114618520059872
# slope_median_2  -  0.012995057982552754
# skyview_max_2  -  0.012896939629784623
# impundment_std_6  -  0.012870334422216852
# slope_max_4  -  0.012782324747026827
# skyview_median_4  -  0.012140415063743398
# hpmf_mean_2  -  0.011877461495717789
# impundment_max_4  -  0.01179585423681687
# impundment_max_2  -  0.011463125427371098
#
#
# Amount of features used:   44
# Cohen's kappa score         0.42350335611886036
# Accuracy score              0.9580042510704089
# Recall score                0.7112616057988845
# Precision score             0.3207207207207207
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4', 'hpmf_mean_6', 'skyview_gabor_no_streams', 'hpmf_mean_4', 'impundment_max_6', 'slope_median_6', 'hpmf_filter', 'hpmf_filter_no_streams', 'slope_std_6', 'skyview_median_6', 'slope_non_ditch', 'impundment_median_6', 'impundment_median_2', 'skyview_min_6', 'hpmf_std_6', 'slope_min_4', 'impundment_std_4', 'slope_mean_6', 'hpmf_mean_3', 'skyview_std_6', 'hpmf_min_4', 'impundment_mean_6', 'slope_min_2', 'slope_std_4', 'hpmf_min_2', 'slope_median_2', 'skyview_max_2', 'impundment_std_6', 'slope_max_4', 'skyview_median_4']
#
#
# Amount of features X_train: 41, X_test: 41
# Amount of features X_train: 41, X_test: 41
#
#
# Importances for experiment:
# impundment_mean_3  -  0.22632877375681676
# impundment_mean_4  -  0.07847424602498428
# impundment_median_4  -  0.04187979908922532
# impundment_mean_2  -  0.03627273921188248
# impundment_amplified  -  0.031089694598524745
# hpmf_median_4  -  0.02745578792557817
# impoundment_amplified_no_streams  -  0.02637207247724297
# skyview_max_6  -  0.02410197064970126
# skyview_non_ditch  -  0.02003354649134703
# skyview_gabor  -  0.019726902835794497
# slope_min_6  -  0.018753946678709166
# skyview_max_4  -  0.01817754599196343
# hpmf_mean_6  -  0.017904796000731124
# hpmf_mean_4  -  0.01788924861593529
# impundment_max_6  -  0.017676366005403666
# skyview_gabor_no_streams  -  0.01666228960991803
# slope_median_6  -  0.015943536149681414
# hpmf_filter  -  0.015858337106214274
# impundment_std_4  -  0.015852962129234167
# impundment_median_6  -  0.015523878116018137
# slope_std_6  -  0.015396862840696662
# hpmf_filter_no_streams  -  0.01522403734119952
# slope_non_ditch  -  0.015221588757267687
# skyview_median_6  -  0.015187339947849002
# skyview_min_6  -  0.01497761904713619
# hpmf_std_6  -  0.014903303681619967
# slope_min_4  -  0.014778601754188731
# hpmf_mean_3  -  0.014230189317316256
# slope_mean_6  -  0.014219654716372444
# impundment_mean_6  -  0.01412688704573698
# skyview_std_6  -  0.014096878997924632
# hpmf_min_4  -  0.01407665771777667
# impundment_median_2  -  0.014042116410537155
# slope_std_4  -  0.013916920288324485
# impundment_std_6  -  0.013854990707745117
# slope_min_2  -  0.01375534793126238
# slope_median_2  -  0.01364714456740417
# skyview_max_2  -  0.013280342917042443
# slope_max_4  -  0.013216528035955945
# hpmf_min_2  -  0.013139731083095258
# skyview_median_4  -  0.012728817428642084
#
#
# Amount of features used:   41
# Cohen's kappa score         0.42389556100738757
# Accuracy score              0.9581493707447906
# Recall score                0.7098271276957708
# Precision score             0.3213886495926212
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_non_ditch', 'skyview_gabor', 'slope_min_6', 'skyview_max_4', 'hpmf_mean_6', 'hpmf_mean_4', 'impundment_max_6', 'skyview_gabor_no_streams', 'slope_median_6', 'hpmf_filter', 'impundment_std_4', 'impundment_median_6', 'slope_std_6', 'hpmf_filter_no_streams', 'slope_non_ditch', 'skyview_median_6', 'skyview_min_6', 'hpmf_std_6', 'slope_min_4', 'hpmf_mean_3', 'slope_mean_6', 'impundment_mean_6', 'skyview_std_6', 'hpmf_min_4', 'impundment_median_2', 'slope_std_4', 'impundment_std_6', 'slope_min_2', 'slope_median_2', 'skyview_max_2']
#
#
# Amount of features X_train: 38, X_test: 38
# Amount of features X_train: 38, X_test: 38
#
#
# Importances for experiment:
# impundment_mean_3  -  0.22023180961057054
# impundment_mean_4  -  0.08036786290201321
# impundment_median_4  -  0.05527534197733538
# impundment_mean_2  -  0.03397025000620673
# impundment_amplified  -  0.031256706590576874
# hpmf_median_4  -  0.02826493942834674
# impoundment_amplified_no_streams  -  0.027467367546867127
# skyview_max_6  -  0.02531397960185125
# skyview_gabor  -  0.020918421296971412
# skyview_non_ditch  -  0.020811782479808246
# slope_min_6  -  0.0197497550498835
# hpmf_mean_6  -  0.01891884331491684
# skyview_max_4  -  0.018915280774003826
# impundment_max_6  -  0.01860169877893148
# skyview_median_6  -  0.01853528040678268
# skyview_gabor_no_streams  -  0.017538869060123346
# slope_median_6  -  0.017052176892484845
# slope_std_6  -  0.016942498396349627
# hpmf_filter  -  0.016535773760654914
# slope_std_4  -  0.016298254311086027
# impundment_std_4  -  0.01628780148626049
# impundment_median_6  -  0.016257341312384363
# skyview_min_6  -  0.01606260747885198
# hpmf_min_4  -  0.016005974539654078
# hpmf_filter_no_streams  -  0.01591758436018968
# hpmf_mean_4  -  0.015912163054695123
# hpmf_std_6  -  0.01579141413033063
# hpmf_mean_3  -  0.01556920230310898
# slope_non_ditch  -  0.015528155067685186
# slope_min_4  -  0.015484666684688632
# slope_mean_6  -  0.015397091783181304
# slope_median_2  -  0.01513816236732082
# skyview_std_6  -  0.015000525749997063
# impundment_median_2  -  0.014788417915591746
# impundment_mean_6  -  0.01455339981509238
# slope_min_2  -  0.014517499631948098
# skyview_max_2  -  0.014456213066591783
# impundment_std_6  -  0.014364887066663185
#
#
# Amount of features used:   38
# Cohen's kappa score         0.4229665689288007
# Accuracy score              0.9580492069677821
# Recall score                0.7089560973485292
# Precision score             0.32062560011817715
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'hpmf_mean_6', 'skyview_max_4', 'impundment_max_6', 'skyview_median_6', 'skyview_gabor_no_streams', 'slope_median_6', 'slope_std_6', 'hpmf_filter', 'slope_std_4', 'impundment_std_4', 'impundment_median_6', 'skyview_min_6', 'hpmf_min_4', 'hpmf_filter_no_streams', 'hpmf_mean_4', 'hpmf_std_6', 'hpmf_mean_3', 'slope_non_ditch', 'slope_min_4', 'slope_mean_6', 'slope_median_2', 'skyview_std_6', 'impundment_median_2', 'impundment_mean_6']
#
#
# Amount of features X_train: 35, X_test: 35
# Amount of features X_train: 35, X_test: 35
#
#
# Importances for experiment:
# impundment_mean_3  -  0.25022596798731583
# impundment_mean_4  -  0.07236863130108086
# impundment_median_4  -  0.04424054649676209
# impundment_amplified  -  0.032971285606058325
# hpmf_median_4  -  0.029707276526362538
# impundment_mean_2  -  0.028336758684145223
# impoundment_amplified_no_streams  -  0.028332885152180562
# skyview_max_6  -  0.027278458747176992
# skyview_non_ditch  -  0.022195560905024135
# impundment_max_6  -  0.02213977823557431
# skyview_gabor  -  0.021309304785167175
# skyview_max_4  -  0.0211469330506421
# slope_min_6  -  0.021077070017272763
# skyview_median_6  -  0.02080223404733604
# hpmf_mean_6  -  0.019953107869199196
# skyview_gabor_no_streams  -  0.018365023359926694
# slope_median_6  -  0.018159219089826248
# slope_std_6  -  0.018094082314053166
# impundment_mean_6  -  0.017505241309881868
# slope_std_4  -  0.01749369936771418
# impundment_std_4  -  0.017446119217013306
# impundment_median_6  -  0.017403337484861496
# hpmf_filter  -  0.017314099857090034
# skyview_min_6  -  0.017104265391328734
# slope_min_4  -  0.017056873378334017
# hpmf_std_6  -  0.0170300418269861
# slope_median_2  -  0.01699347438216253
# hpmf_min_4  -  0.016608170685437074
# hpmf_filter_no_streams  -  0.01654646330232085
# slope_mean_6  -  0.01638892380650545
# slope_non_ditch  -  0.01618394475831311
# hpmf_mean_4  -  0.016007854277684835
# skyview_std_6  -  0.01596446786040076
# hpmf_mean_3  -  0.015519207329493082
# impundment_median_2  -  0.01472969158936839
#
#
# Amount of features used:   35
# Cohen's kappa score         0.42111936292291774
# Accuracy score              0.9579389822392367
# Recall score                0.7056679577876918
# Precision score             0.3194078764992515
#
# ------------------------------------------------------

# %%
from itertools import product

# %%
params = [["gini", "entropy"],
          [35, None],
          [2, 10],
          ["balanced", None],
          [200, 300]]

# %%
most_important_features = ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2',
                           'impundment_amplified', 'hpmf_mean_4', 'impoundment_amplified_no_streams', 'hpmf_median_4',
                           'skyview_max_6', 'skyview_gabor', 'skyview_non_ditch', 'slope_min_6', 'skyview_max_4',
                           'skyview_gabor_no_streams', 'impundment_std_4', 'impundment_max_6', 'slope_non_ditch',
                           'hpmf_filter', 'hpmf_mean_3', 'hpmf_filter_no_streams', 'hpmf_mean_6', 'impundment_median_6',
                           'impundment_median_2', 'slope_std_6', 'impundment_mean_6', 'slope_median_6', 'slope_min_4',
                           'hpmf_min_2', 'impundment_std_6', 'skyview_median_6', 'skyview_min_6', 'slope_mean_6',
                           'impundment_max_2', 'skyview_std_6', 'slope_min_2', 'skyview_max_2', 'hpmf_min_4',
                           'impundment_max_4', 'slope_std_4', 'hpmf_gabor', 'hpmf_std_6', 'slope_max_4',
                           'hpmf_gabor_no_streams', 'skyview_min_4', 'slope_median_4', 'hpmf_mean_2', 'slope_median_2',
                           'slope_std_2', 'hpmf_min_6', 'hpmf_max_6', 'skyview_mean_6', 'skyview_median_4', 'hpmf_std_4']

# %%
param_combos = list(product(*params))

# %%
len(param_combos)
# Out:
# 144

# %%
zone_4 = None
zone_7 = None
zone_4_resampled = None
zone_7_resampled = None
params_and_score = []
j = 0
for combo in param_combos:
    j += 1
    y_test_all = []
    pred_all = []
    
    params = {'criterion': combo[0],
    'max_depth': combo[1],
    'min_samples_split': combo[2],
    'class_weight': combo[3],
    'n_estimators': combo[4]}
    print(f"params: {params}")
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        clf = RandomForestClassifier(**params, n_jobs=-1, random_state=89)
        print(clf)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        pred = clf.predict(X_test)

        for i, pred_var in enumerate(pred):
            y_test_all.append(y_test[i])
            pred_all.append(pred_var)

    print("\n")
    print(f"Iteration {j} of {len(param_combos)}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
    params_and_score.append((params, cohen_kappa_score(y_test_all, pred_all)))

print(params_and_score)
# Out:
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 1 of 144
# Cohen's kappa score         0.41378381457310864
# Accuracy score              0.9560422381669201
# Recall score                0.7172907689836981
# Precision score             0.3100289182594455
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 2 of 144
# Cohen's kappa score         0.41812134703190096
# Accuracy score              0.9565359252382153
# Recall score                0.7213519479777125
# Precision score             0.3135434499942618
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 3 of 144
# Cohen's kappa score         0.41939611364008256
# Accuracy score              0.9566945444171907
# Recall score                0.7222937495406676
# Precision score             0.31462247484627953
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 4 of 144
# Cohen's kappa score         0.4136096987574258
# Accuracy score              0.9559516259261807
# Recall score                0.7183196735813774
# Precision score             0.3096797436165232
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 5 of 144
# Cohen's kappa score         0.4165142261614381
# Accuracy score              0.9562603315783977
# Recall score                0.7214390510124367
# Precision score             0.3119602638873359
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 6 of 144
# Cohen's kappa score         0.41765441554749516
# Accuracy score              0.9563667993693439
# Recall score                0.7229061927535719
# Precision score             0.31281337933195213
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 7 of 144
# Cohen's kappa score         0.41928090416720065
# Accuracy score              0.9570713206845523
# Recall score                0.7154670491941608
# Precision score             0.31574174065233923
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 8 of 144
# Cohen's kappa score         0.42235753672912535
# Accuracy score              0.9573613053256819
# Recall score                0.7192369774158163
# Precision score             0.3180871003506694
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 9 of 144
# Cohen's kappa score         0.4234878058856233
# Accuracy score              0.9574615327795989
# Recall score                0.7207258949156325
# Precision score             0.31892987014238444
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 10 of 144
# Cohen's kappa score         0.4166677687082584
# Accuracy score              0.9562328231539428
# Recall score                0.7223509109072054
# Precision score             0.3119499428122726
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 11 of 144
# Cohen's kappa score         0.42227894657701326
# Accuracy score              0.9571729490304554
# Recall score                0.7222964715105027
# Precision score             0.3174507089937469
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 12 of 144
# Cohen's kappa score         0.423489745117847
# Accuracy score              0.9573481242056305
# Recall score                0.7227183768349479
# Precision score             0.3185664133457794
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 13 of 144
# Cohen's kappa score         0.41765264178929706
# Accuracy score              0.9564462681511028
# Recall score                0.7215397638963365
# Precision score             0.31305247419867993
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 14 of 144
# Cohen's kappa score         0.42160290623154173
# Accuracy score              0.9570236903570237
# Recall score                0.722949744270934
# Precision score             0.3166679980494249
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 15 of 144
# Cohen's kappa score         0.4228106878990546
# Accuracy score              0.9571858117659644
# Recall score                0.7236030170313652
# Precision score             0.31773681335690324
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 16 of 144
# Cohen's kappa score         0.41771827528125083
# Accuracy score              0.9565407010063499
# Recall score                0.7201107297328931
# Precision score             0.31336987962938834
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 17 of 144
# Cohen's kappa score         0.42187126425041543
# Accuracy score              0.9571675364932363
# Recall score                0.7212185714557912
# Precision score             0.3172452933203703
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 18 of 144
# Cohen's kappa score         0.4240389209268285
# Accuracy score              0.9574971281714284
# Recall score                0.7216840282975984
# Precision score             0.31929808926709075
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 19 of 144
# Cohen's kappa score         0.42004086804876617
# Accuracy score              0.9571536549271918
# Recall score                0.7162155908988217
# Precision score             0.316354428918722
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 20 of 144
# Cohen's kappa score         0.4234086671400836
# Accuracy score              0.9575189693510304
# Recall score                0.7194928425803185
# Precision score             0.31907910223090286
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 21 of 144
# Cohen's kappa score         0.4242509945715972
# Accuracy score              0.9575795260909765
# Recall score                0.7208456615883783
# Precision score             0.31966245479520844
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 22 of 144
# Cohen's kappa score         0.41899502868010297
# Accuracy score              0.9568764693446628
# Recall score                0.7180066470503373
# Precision score             0.31499856103424023
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 23 of 144
# Cohen's kappa score         0.42259867728957057
# Accuracy score              0.9573307404096209
# Recall score                0.7204618638416249
# Precision score             0.3181003681149701
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 24 of 144
# Cohen's kappa score         0.4231447646816028
# Accuracy score              0.9573709205388594
# Recall score                0.7213274502491963
# Precision score             0.318480630514781
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 25 of 144
# Cohen's kappa score         0.42223543015834397
# Accuracy score              0.9575317047327225
# Recall score                0.7159161742169573
# Precision score             0.31858049058784055
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 26 of 144
# Cohen's kappa score         0.426401075665236
# Accuracy score              0.9580266016652785
# Recall score                0.7191172107430706
# Precision score             0.32211968137963154
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 27 of 144
# Cohen's kappa score         0.4272640436107519
# Accuracy score              0.9581376541936338
# Recall score                0.7196153312228993
# Precision score             0.32288530660748943
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 28 of 144
# Cohen's kappa score         0.42171013302790417
# Accuracy score              0.9571634611710947
# Recall score                0.7208266077995323
# Precision score             0.3171579406255539
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 29 of 144
# Cohen's kappa score         0.4262018703124928
# Accuracy score              0.9578409834771158
# Recall score                0.7218337366385306
# Precision score             0.3214119495025889
#
# ------------------------------------------------------
#
# params: {'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 30 of 144
# Cohen's kappa score         0.4272090549850909
# Accuracy score              0.9579647713871633
# Recall score                0.722530560916324
# Precision score             0.32228157933077556
#
# ------------------------------------------------------
#
# ...
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 137 of 144
# Cohen's kappa score         0.40699207251132097
# Accuracy score              0.9541540904772456
# Recall score                0.729071454430142
# Precision score             0.301531031532495
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 138 of 144
# Cohen's kappa score         0.4078843538556399
# Accuracy score              0.9542862200623015
# Recall score                0.7295042476339277
# Precision score             0.302307979511197
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 139 of 144
# Cohen's kappa score         0.40348878138207
# Accuracy score              0.9535910592526369
# Recall score                0.7280207740737817
# Precision score             0.2983856932482485
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 140 of 144
# Cohen's kappa score         0.4064857304414883
# Accuracy score              0.9540893310613412
# Recall score                0.7286549930453671
# Precision score             0.3011177715210669
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=300, n_jobs=-1, oob_score=False,
#                        random_state=89, verbose=0, warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 141 of 144
# Cohen's kappa score         0.4078202435490218
# Accuracy score              0.9543321311133016
# Recall score                0.7285597241011376
# Precision score             0.30239922812551545
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 142 of 144
# Cohen's kappa score         0.40414621556716024
# Accuracy score              0.953722679422425
# Recall score                0.7278057384568064
# Precision score             0.29903985416072515
#
# ------------------------------------------------------
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 143 of 144
# Cohen's kappa score         0.4067281620185049
# Accuracy score              0.9541842096549475
# Recall score                0.7278057384568064
# Precision score             0.3014837290432716
#
# ------------------------------------------------------
#
# params: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 300}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)
# Amount of features X_train: 53, X_test: 53
#
#
# Iteration 144 of 144
# Cohen's kappa score         0.4071379428993964
# Accuracy score              0.9542548273464304
# Recall score                0.7278411240646632
# Precision score             0.30186700443890524
#
# ------------------------------------------------------
#
# [({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 100}, 0.41378381457310864), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 200}, 0.41812134703190096), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 300}, 0.41939611364008256), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 100}, 0.4136096987574258), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 200}, 0.4165142261614381), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 300}, 0.41765441554749516), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 100}, 0.41928090416720065), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 200}, 0.42235753672912535), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 2, 'class_weight': None, 'n_estimators': 300}, 0.4234878058856233), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 100}, 0.4166677687082584), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 200}, 0.42227894657701326), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced', 'n_estimators': 300}, 0.423489745117847), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 100}, 0.41765264178929706), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 200}, 0.42160290623154173), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': 'balanced_subsample', 'n_estimators': 300}, 0.4228106878990546), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 100}, 0.41771827528125083), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 200}, 0.42187126425041543), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'log2', 'min_samples_split': 10, 'class_weight': None, 'n_estimators': 300}, 0.4240389209268285), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 100}, 0.42004086804876617), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 200}, 0.4234086671400836), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 300}, 0.4242509945715972), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 100}, 0.41899502868010297), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 200}, 0.42259867728957057), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': 'balanced_subsample', 'n_estimators': 300}, 0.4231447646816028), ({'criterion': 'gini', 'max_depth': 35, 'max_features': 'sqrt', 'min_samples_split': 2, 'class_weight': Non ...

# %%
sorted(params_and_score,key=lambda x:(-x[1],x[0]))
# Out:
# [({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4297846249129419),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.42912782104665137),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4285003160562595),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.42844265073097276),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.428351471627776),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.42830920144131635),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.428272909073351),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4282288044739664),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.42800238490444475),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4275442770533484),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4272640436107519),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4272090549850909),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.42648938430838723),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.426401075665236),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.42630796503729795),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4262018703124928),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4250756963035235),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4243312297480667),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4242509945715972),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.42414247420631856),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4240389209268285),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4239563368384458),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.42362337168847497),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.423505586632007),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.423489745117847),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4234878058856233),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4234808351146516),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4234086671400836),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.42338165325496835),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4233324801932614),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4231797056282002),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4231447646816028),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.42298641261833736),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4228106878990546),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.42259867728957057),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4225814138477323),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4225426033011246),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4224293115154383),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.42235753672912535),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.42227894657701326),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.42223543015834397),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.42187126425041543),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.42171013302790417),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.42167675490560996),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.42167316355549656),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4216097786456038),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.42160290623154173),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4213258676656171),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.42046788684580394),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.42004086804876617),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.41956796982286537),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.41939611364008256),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.41928090416720065),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4191904378111052),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.41899502868010297),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4188043092870435),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4186257557416586),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4185200478297456),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4184587798681445),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.41812134703190096),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.41792188681053755),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4177963646521502),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4177492972893163),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.41771827528125083),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.41765441554749516),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.41765264178929706),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4166677687082584),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4165142261614381),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.41562586501854504),
#  ({'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.41449874218374727),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.41378381457310864),
#  ({'criterion': 'gini',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4136096987574258),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.40840269032095877),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4078843538556399),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4078202435490218),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4076675051203825),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4074898856626491),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4074168469719611),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.40733981879794245),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.40733284762414157),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40729831851297327),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40729115100224744),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.40729074943396637),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.40726799892276344),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4071627621974976),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4071379428993964),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40710751589111493),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.40699207251132097),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.40696133900319875),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4069435779050202),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4067281620185049),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.40658412270854416),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40658377126645284),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4065806677881698),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4064922739568928),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4064857304414883),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40645237745736984),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.4064221597416964),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.40633764523568616),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.40631070142649006),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4062406743295781),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.40623262337253585),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.4061551859360888),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4061283890066525),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.40605155391143943),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.40591269288729015),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.4057799775696368),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 300},
#   0.40574530799470887),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.40572789897501726),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.40568905716545434),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4055911895708546),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.40558211128764277),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.40547909011714833),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4054180194134569),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4053432805321361),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 200},
#   0.4052907275760823),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.40527510736931005),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 300},
#   0.40507801553006184),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4047354682464358),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.40472801554279536),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.40466690981025544),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 200},
#   0.40415477811236433),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.40414621556716024),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4041114999652273),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 300},
#   0.4038606045985085),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 200},
#   0.4038591508263386),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4036095460780247),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4035632590067222),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.40349981020852466),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.40348878138207),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4032378187148019),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4032201346813111),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4030982758464965),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.4029180264572312),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4024671033783723),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 10,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.40245484546922417),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'sqrt',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.40233694149556787),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.4020902418873048),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.402074632726221),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4019431196087335),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': None,
#    'n_estimators': 100},
#   0.40185224856744506),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.40111220446016305),
#  ({'criterion': 'entropy',
#    'max_depth': 35,
#    'max_features': 'log2',
#    'min_samples_split': 2,
#    'class_weight': 'balanced_subsample',
#    'n_estimators': 100},
#   0.4006163120712959),
#  ({'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 'log2',
#    'min_samples_split': 10,
#    'class_weight': 'balanced',
#    'n_estimators': 100},
#   0.40016900278506706)]
