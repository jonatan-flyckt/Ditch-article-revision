# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix, cohen_kappa_score, precision_score, recall_score
from sklearn.metrics import precision_recall_curve, auc, average_precision_score, f1_score, roc_auc_score, roc_curve
import pandas as pd
import math
from joblib import dump, load
import random
import pickle
import scipy.stats
from PIL import Image
import scipy.stats as stats

from Functions import post_processing
from Functions import general_functions
from Functions import feature_creation

from skimage.restoration import denoise_bilateral

import operator

# %%
zone_1_path = "dataset/zone_4.pickle"
zone_2_path = "dataset/zone_6.pickle"
zone_3_path = "dataset/zone_9.pickle"

# %%
file = open(zone_1_path, "rb")
zone_1 = pickle.load(file)

file = open(zone_2_path, "rb")
zone_2 = pickle.load(file)

file = open(zone_3_path, "rb")
zone_3 = pickle.load(file)

file = None

# %%
#zone_1_resampled = general_functions.create_balanced_dataset([zone_1_path])
#zone_2_resampled = general_functions.create_balanced_dataset([zone_2_path])
#zone_3_resampled = general_functions.create_balanced_dataset([zone_3_path])

#with open("dataset/zone_1_resampled.pickle", "wb") as file:
#    pickle.dump(zone_1_resampled, file)
#with open("dataset/zone_2_resampled.pickle", "wb") as file:
#    pickle.dump(zone_2_resampled, file)
#with open("dataset/zone_3_resampled.pickle", "wb") as file:
#    pickle.dump(zone_3_resampled, file)

# %%
with open("dataset/zone_1_resampled.pickle", "rb") as file:
    zone_1_resampled = pickle.load(file)
with open("dataset/zone_2_resampled.pickle", "rb") as file:
    zone_2_resampled = pickle.load(file)
with open("dataset/zone_3_resampled.pickle", "rb") as file:
    zone_3_resampled = pickle.load(file)

# %%
zone_1.shape
# Out:
# (7852140, 82)

# %%
experiment_arr = [(pd.concat([zone_1_resampled, zone_3_resampled], ignore_index=True), zone_2),
                  (pd.concat([zone_1_resampled, zone_2_resampled], ignore_index=True), zone_3)]

# %%
zone_1 = None
zone_2 = None
zone_3 = None
zone_1_resampled = None
zone_2_resampled = None
zone_3_resampled = None

# %%
most_important_features = experiment_arr[0][0].columns.tolist()[1:]
for num_features in [81, 70, 60, 50, 40]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features,
                                     random_state=42, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(np.array(y_test).reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['hpmf_raw', 'skyview_raw', 'impundment_raw', 'slope_raw', 'DEM_ditch_detection', 'DEM_ditch_detection_no_streams', 'conic_mean', 'skyview_non_ditch', 'skyview_gabor', 'conic_mean_no_streams', 'skyview_gabor_no_streams', 'skyview_mean_2', 'skyview_mean_3', 'skyview_mean_4', 'skyview_mean_6', 'skyview_median_2', 'skyview_median_4', 'skyview_median_6', 'skyview_min_2', 'skyview_min_4', 'skyview_min_6', 'skyview_max_2', 'skyview_max_4', 'skyview_max_6', 'skyview_std_2', 'skyview_std_4', 'skyview_std_6', 'impundment_amplified', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'impundment_mean_3', 'impundment_mean_4', 'impundment_mean_6', 'impundment_median_2', 'impundment_median_4', 'impundment_median_6', 'impundment_min_2', 'impundment_min_4', 'impundment_min_6', 'impundment_max_2', 'impundment_max_4', 'impundment_max_6', 'impundment_std_2', 'impundment_std_4', 'impundment_std_6', 'hpmf_filter', 'hpmf_gabor', 'hpmf_gabor_no_streams', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'hpmf_mean_3', 'hpmf_mean_4', 'hpmf_mean_6', 'hpmf_median_2', 'hpmf_median_4', 'hpmf_median_6', 'hpmf_min_2', 'hpmf_min_4', 'hpmf_min_6', 'hpmf_max_2', 'hpmf_max_4', 'hpmf_max_6', 'hpmf_std_2', 'hpmf_std_4', 'hpmf_std_6', 'slope_non_ditch', 'slope_mean_2', 'slope_mean_3', 'slope_mean_4', 'slope_mean_6', 'slope_median_2', 'slope_median_4', 'slope_median_6', 'slope_min_2', 'slope_min_4', 'slope_min_6', 'slope_max_2', 'slope_max_4', 'slope_std_2', 'slope_std_4', 'slope_std_6']
#
#
# Amount of features X_train: 81, X_test: 81
# Amount of features X_train: 81, X_test: 81
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1387769866110689
# impundment_mean_4  -  0.08884841728550347
# hpmf_mean_4  -  0.045297542310717115
# impundment_mean_2  -  0.04108911733626136
# hpmf_mean_3  -  0.0329467698434946
# impundment_median_4  -  0.031608512025810206
# hpmf_min_2  -  0.026215341362495603
# impundment_amplified  -  0.0214626244178616
# impoundment_amplified_no_streams  -  0.019806846560324866
# hpmf_median_4  -  0.01785173891428768
# impundment_max_2  -  0.015842185477983873
# skyview_max_6  -  0.01422078265458162
# skyview_gabor  -  0.01351417858459364
# impundment_std_4  -  0.012826605268227218
# skyview_gabor_no_streams  -  0.0123838176889067
# impundment_median_2  -  0.012342285374639297
# slope_std_6  -  0.0118522134350901
# hpmf_mean_6  -  0.011663524639987377
# skyview_max_4  -  0.011604821992781313
# hpmf_mean_2  -  0.011512655107277694
# slope_min_6  -  0.011452812979104563
# impundment_mean_6  -  0.010532979418914873
# skyview_non_ditch  -  0.01049655888453815
# impundment_max_6  -  0.010396697162921424
# slope_min_4  -  0.010393327389227193
# impundment_std_6  -  0.009934851818750992
# hpmf_min_4  -  0.009790447516825864
# slope_median_6  -  0.00967632540927011
# slope_non_ditch  -  0.00935779014918956
# hpmf_filter  -  0.009293253766725398
# impundment_median_6  -  0.009209267892527396
# impundment_max_4  -  0.009129840769802666
# hpmf_filter_no_streams  -  0.009015550780690211
# skyview_min_6  -  0.008871872264559632
# skyview_max_2  -  0.008862368057485772
# hpmf_gabor_no_streams  -  0.008693032282969252
# slope_mean_6  -  0.008386305470862283
# slope_std_4  -  0.008360964860609674
# hpmf_median_2  -  0.00835509801437226
# impundment_std_2  -  0.008283567229761781
# skyview_std_6  -  0.008068236480520448
# skyview_median_6  -  0.008032411485601167
# hpmf_gabor  -  0.00796903366351264
# slope_min_2  -  0.00794031350776082
# hpmf_std_6  -  0.007795338306929356
# hpmf_min_6  -  0.007417878672464401
# slope_max_4  -  0.007303304373549617
# skyview_mean_6  -  0.007181889665205155
# skyview_std_4  -  0.006747370409314808
# skyview_min_4  -  0.006720139708455716
# hpmf_std_4  -  0.006698703660401753
# hpmf_max_6  -  0.0066621526938600295
# skyview_median_4  -  0.006439437915516851
# slope_median_4  -  0.0063387575939960385
# hpmf_std_2  -  0.00624826229071105
# slope_std_2  -  0.006216331476464833
# hpmf_median_6  -  0.00616549108109175
# slope_median_2  -  0.005915877390310553
# slope_mean_4  -  0.0058771107739699156
# skyview_median_2  -  0.0055717709378821055
# skyview_std_2  -  0.005489716855721125
# slope_mean_2  -  0.005481862483434701
# slope_raw  -  0.005363667844462329
# slope_max_2  -  0.005176825950856862
# slope_mean_3  -  0.005110193517902284
# skyview_mean_4  -  0.005031472560263263
# skyview_min_2  -  0.00500262133685189
# conic_mean_no_streams  -  0.004863600554786409
# hpmf_max_4  -  0.004749571422710546
# conic_mean  -  0.004725376271465893
# skyview_raw  -  0.004679492014476652
# skyview_mean_2  -  0.0046535266188380865
# skyview_mean_3  -  0.004597573518156626
# impundment_raw  -  0.00448118210054719
# hpmf_raw  -  0.003754481055701006
# hpmf_max_2  -  0.0034633248921129784
# DEM_ditch_detection_no_streams  -  0.0023129649346533337
# DEM_ditch_detection  -  0.0019661596555782387
# impundment_min_2  -  0.0014540898247051082
# impundment_min_4  -  0.00017251243557193257
# impundment_min_6  -  9.305268132857959e-08
#
#
# Amount of features used:   81
# Cohen's kappa score         0.5995907016193438
# Accuracy score              0.9840752966707165
# Recall score                0.566862762314514
# Precision score             0.6548198636806232
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'impundment_max_2', 'skyview_max_6', 'skyview_gabor', 'impundment_std_4', 'skyview_gabor_no_streams', 'impundment_median_2', 'slope_std_6', 'hpmf_mean_6', 'skyview_max_4', 'hpmf_mean_2', 'slope_min_6', 'impundment_mean_6', 'skyview_non_ditch', 'impundment_max_6', 'slope_min_4', 'impundment_std_6', 'hpmf_min_4', 'slope_median_6', 'slope_non_ditch', 'hpmf_filter', 'impundment_median_6', 'impundment_max_4', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_max_2', 'hpmf_gabor_no_streams', 'slope_mean_6', 'slope_std_4', 'hpmf_median_2', 'impundment_std_2', 'skyview_std_6', 'skyview_median_6', 'hpmf_gabor', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'skyview_mean_6', 'skyview_std_4', 'skyview_min_4', 'hpmf_std_4', 'hpmf_max_6', 'skyview_median_4', 'slope_median_4', 'hpmf_std_2', 'slope_std_2', 'hpmf_median_6', 'slope_median_2', 'slope_mean_4', 'skyview_median_2', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'slope_max_2', 'slope_mean_3', 'skyview_mean_4', 'skyview_min_2', 'conic_mean_no_streams', 'hpmf_max_4', 'conic_mean']
#
#
# Amount of features X_train: 70, X_test: 70
# Amount of features X_train: 70, X_test: 70
#
#
# Importances for experiment:
# impundment_mean_3  -  0.14473881709428432
# impundment_mean_4  -  0.09960222233958155
# impundment_mean_2  -  0.04160774937070659
# hpmf_mean_4  -  0.04072656368010266
# hpmf_mean_3  -  0.034614740733743696
# impundment_median_4  -  0.0313521211374753
# hpmf_min_2  -  0.026589427572943546
# impundment_amplified  -  0.022286531183687473
# impoundment_amplified_no_streams  -  0.020494616134479005
# hpmf_median_4  -  0.020259462206859827
# skyview_max_6  -  0.015238532010414193
# skyview_gabor  -  0.013973600600737327
# impundment_std_4  -  0.013051140298119802
# skyview_gabor_no_streams  -  0.012878661098844436
# slope_std_6  -  0.012432318372747487
# impundment_median_2  -  0.012357041826976837
# skyview_max_4  -  0.012110383080756047
# slope_min_6  -  0.012099937293821599
# hpmf_mean_6  -  0.01184205753438788
# impundment_mean_6  -  0.011229194844813665
# skyview_non_ditch  -  0.01118531345957011
# slope_min_4  -  0.010929637055807982
# impundment_max_6  -  0.010892006659798935
# impundment_max_2  -  0.010690665697711012
# hpmf_min_4  -  0.010690277795083445
# hpmf_mean_2  -  0.010334880998291818
# slope_median_6  -  0.010111085461354544
# slope_non_ditch  -  0.010024452483528047
# impundment_std_6  -  0.009899138098518383
# hpmf_filter  -  0.00976031663887095
# impundment_median_6  -  0.009672936561349127
# skyview_max_2  -  0.009650797256231138
# hpmf_filter_no_streams  -  0.009453807366642801
# skyview_min_6  -  0.009265456427810757
# impundment_max_4  -  0.008886474206097244
# hpmf_gabor_no_streams  -  0.008740124578914318
# slope_mean_6  -  0.00870125601600974
# slope_std_4  -  0.008659172605090611
# skyview_median_6  -  0.008557527211057955
# skyview_std_6  -  0.008342879226466017
# slope_min_2  -  0.008311071431744742
# hpmf_std_6  -  0.00826062469195073
# hpmf_min_6  -  0.007681231607013419
# slope_max_4  -  0.007570465578703245
# skyview_mean_6  -  0.007482065571216133
# hpmf_gabor  -  0.007351959669583401
# hpmf_median_2  -  0.007223224544449111
# hpmf_std_4  -  0.007079403133131249
# hpmf_max_6  -  0.007075012913261326
# skyview_std_4  -  0.007060659712162194
# skyview_min_4  -  0.00704693684864202
# impundment_std_2  -  0.007005863206152874
# skyview_median_4  -  0.0069987022788296285
# slope_median_4  -  0.0066946652751673505
# hpmf_std_2  -  0.006670758489352924
# skyview_median_2  -  0.006608925695053117
# slope_std_2  -  0.006515199146529821
# slope_median_2  -  0.006157468937004399
# slope_mean_4  -  0.006129788082347655
# hpmf_median_6  -  0.005963640237919042
# slope_raw  -  0.005912391160587753
# skyview_std_2  -  0.005860888746413865
# slope_mean_2  -  0.005804257760535874
# skyview_mean_4  -  0.005695068384727147
# skyview_min_2  -  0.005571224176814216
# slope_max_2  -  0.0054450968703663016
# conic_mean  -  0.005360412379064166
# conic_mean_no_streams  -  0.005284126969017442
# slope_mean_3  -  0.005179246107236857
# hpmf_max_4  -  0.005066296175333889
#
#
# Amount of features used:   70
# Cohen's kappa score         0.6074974677335433
# Accuracy score              0.9842839022228336
# Recall score                0.5781367986653789
# Precision score             0.6579925650557621
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'impundment_std_4', 'skyview_gabor_no_streams', 'slope_std_6', 'impundment_median_2', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_mean_6', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'impundment_max_2', 'hpmf_min_4', 'hpmf_mean_2', 'slope_median_6', 'slope_non_ditch', 'impundment_std_6', 'hpmf_filter', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter_no_streams', 'skyview_min_6', 'impundment_max_4', 'hpmf_gabor_no_streams', 'slope_mean_6', 'slope_std_4', 'skyview_median_6', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'skyview_mean_6', 'hpmf_gabor', 'hpmf_median_2', 'hpmf_std_4', 'hpmf_max_6', 'skyview_std_4', 'skyview_min_4', 'impundment_std_2', 'skyview_median_4', 'slope_median_4', 'hpmf_std_2', 'skyview_median_2', 'slope_std_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6']
#
#
# Amount of features X_train: 60, X_test: 60
# Amount of features X_train: 60, X_test: 60
#
#
# Importances for experiment:
# impundment_mean_3  -  0.16128612358498867
# impundment_mean_4  -  0.10047162343378929
# impundment_mean_2  -  0.043721963290966115
# hpmf_mean_4  -  0.04061972615927137
# hpmf_mean_3  -  0.03402230603221488
# impundment_median_4  -  0.02747403834490798
# impundment_amplified  -  0.02405380746612721
# impoundment_amplified_no_streams  -  0.02103762181915179
# hpmf_median_4  -  0.020714925532103485
# hpmf_min_2  -  0.019919602165755872
# skyview_max_6  -  0.01653663844039415
# skyview_gabor  -  0.014946324970637359
# skyview_gabor_no_streams  -  0.013845065639526963
# slope_std_6  -  0.01362867406522857
# skyview_max_4  -  0.013500195098413202
# slope_min_6  -  0.013312419232508942
# hpmf_mean_6  -  0.012942619583823603
# impundment_median_2  -  0.012874137526381623
# impundment_max_2  -  0.012523709022577798
# skyview_non_ditch  -  0.01227199465810564
# slope_min_4  -  0.011752150078156005
# impundment_max_6  -  0.011679691569246763
# impundment_std_4  -  0.011644764381380023
# impundment_mean_6  -  0.011336762955984118
# hpmf_min_4  -  0.011316997484286452
# slope_median_6  -  0.011185903240029233
# slope_non_ditch  -  0.010694268968671834
# skyview_max_2  -  0.010690041586785576
# impundment_median_6  -  0.01066055347787596
# hpmf_filter  -  0.010650841292169814
# impundment_std_6  -  0.01036440412478598
# hpmf_filter_no_streams  -  0.010360522197528695
# skyview_min_6  -  0.010194548147496589
# hpmf_mean_2  -  0.010174972850470539
# skyview_median_6  -  0.009894256326601538
# slope_mean_6  -  0.009648259298492882
# slope_std_4  -  0.009603414599548218
# slope_min_2  -  0.009453110375305846
# impundment_max_4  -  0.009337577921549158
# hpmf_gabor_no_streams  -  0.009190959629567862
# skyview_std_6  -  0.009148526974119608
# hpmf_std_6  -  0.00910017776916184
# slope_median_2  -  0.008792052683963818
# slope_max_4  -  0.00853887237916106
# skyview_mean_6  -  0.00850590955779975
# skyview_median_2  -  0.008320659142835913
# skyview_median_4  -  0.008252869649345207
# slope_std_2  -  0.008223104772148711
# skyview_std_4  -  0.008187675322866373
# hpmf_max_6  -  0.008166478070860746
# hpmf_min_6  -  0.008143214987414587
# skyview_min_4  -  0.008082424286504073
# hpmf_gabor  -  0.007930424650940158
# hpmf_std_4  -  0.007899292425138031
# slope_median_4  -  0.007878134162847897
# slope_mean_4  -  0.007688361295807851
# hpmf_std_2  -  0.007515135655265093
# impundment_std_2  -  0.0073515625563228435
# hpmf_median_2  -  0.006373777534099515
# hpmf_median_6  -  0.006363829550589263
#
#
# Amount of features used:   60
# Cohen's kappa score         0.6021757723383787
# Accuracy score              0.9841624066814907
# Recall score                0.5698129774343665
# Precision score             0.6567889239737673
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_min_2', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_median_2', 'impundment_max_2', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'impundment_std_4', 'impundment_mean_6', 'hpmf_min_4', 'slope_median_6', 'slope_non_ditch', 'skyview_max_2', 'impundment_median_6', 'hpmf_filter', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'hpmf_mean_2', 'skyview_median_6', 'slope_mean_6', 'slope_std_4', 'slope_min_2', 'impundment_max_4', 'hpmf_gabor_no_streams', 'skyview_std_6', 'hpmf_std_6', 'slope_median_2', 'slope_max_4', 'skyview_mean_6', 'skyview_median_2', 'skyview_median_4', 'slope_std_2', 'skyview_std_4', 'hpmf_max_6']
#
#
# Amount of features X_train: 50, X_test: 50
# Amount of features X_train: 50, X_test: 50
#
#
# Importances for experiment:
# impundment_mean_3  -  0.16861122450017546
# impundment_mean_4  -  0.11929524528771007
# hpmf_mean_4  -  0.04392048136714051
# impundment_mean_2  -  0.03987504421300214
# hpmf_mean_3  -  0.026901129194438777
# impundment_median_4  -  0.02646079336388269
# impundment_amplified  -  0.02567978346610625
# impoundment_amplified_no_streams  -  0.022603196679020325
# hpmf_median_4  -  0.02077762559454345
# hpmf_min_2  -  0.01938798012939056
# skyview_max_6  -  0.018367699135186027
# slope_std_6  -  0.015412500706367706
# skyview_gabor  -  0.015341342033815292
# skyview_gabor_no_streams  -  0.015035623187011123
# hpmf_mean_6  -  0.015022910182092938
# slope_min_6  -  0.014695851375249393
# skyview_max_4  -  0.014689795141127414
# impundment_median_2  -  0.014053888765609819
# skyview_non_ditch  -  0.013712639790513055
# impundment_std_4  -  0.013571408110367462
# slope_median_6  -  0.01354964012759324
# hpmf_min_4  -  0.013514693618327476
# slope_min_4  -  0.01336724405805409
# impundment_max_6  -  0.012953394249950841
# impundment_mean_6  -  0.012532081124993566
# hpmf_gabor_no_streams  -  0.012300843659674713
# impundment_median_6  -  0.01224627110153452
# skyview_min_6  -  0.012092826757043904
# skyview_max_2  -  0.011998943063180853
# hpmf_filter  -  0.011957007678578647
# slope_non_ditch  -  0.011789023241619581
# hpmf_std_6  -  0.011591761705168397
# slope_mean_6  -  0.011526681433712743
# hpmf_mean_2  -  0.011426595335023618
# hpmf_filter_no_streams  -  0.011423045135183739
# impundment_std_6  -  0.011169217511207696
# skyview_median_6  -  0.011024678201224393
# slope_median_2  -  0.01088521295819347
# slope_min_2  -  0.010827820531011513
# skyview_std_6  -  0.010632015027767875
# slope_std_4  -  0.010585754617870551
# slope_max_4  -  0.010087305491623962
# skyview_std_4  -  0.009985243641739219
# impundment_max_4  -  0.009795187086119334
# skyview_mean_6  -  0.009715204674314474
# impundment_max_2  -  0.00970907246816623
# slope_std_2  -  0.009669644121429597
# hpmf_max_6  -  0.009457456640216948
# skyview_median_4  -  0.009437198465589887
# skyview_median_2  -  0.009332774051134444
#
#
# Amount of features used:   50
# Cohen's kappa score         0.6030096246317408
# Accuracy score              0.984199084580764
# Recall score                0.5704451663886206
# Precision score             0.6578371810449575
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_min_2', 'skyview_max_6', 'slope_std_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'hpmf_mean_6', 'slope_min_6', 'skyview_max_4', 'impundment_median_2', 'skyview_non_ditch', 'impundment_std_4', 'slope_median_6', 'hpmf_min_4', 'slope_min_4', 'impundment_max_6', 'impundment_mean_6', 'hpmf_gabor_no_streams', 'impundment_median_6', 'skyview_min_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'hpmf_std_6', 'slope_mean_6', 'hpmf_mean_2', 'hpmf_filter_no_streams', 'impundment_std_6', 'skyview_median_6', 'slope_median_2', 'slope_min_2', 'skyview_std_6']
# Amount of features X_train: 40, X_test: 40
# Amount of features X_train: 40, X_test: 40
#
#
# Importances for experiment:
# impundment_mean_3  -  0.22955582521855084
# impundment_mean_4  -  0.12024382036414162
# hpmf_mean_4  -  0.030181728607523647
# impundment_amplified  -  0.028162619232376652
# hpmf_median_4  -  0.027641721435081604
# impundment_mean_2  -  0.026668935044070093
# impoundment_amplified_no_streams  -  0.02426657240282676
# skyview_max_6  -  0.02189465348457963
# slope_std_6  -  0.020489618137113676
# hpmf_mean_3  -  0.01806767137202291
# skyview_max_4  -  0.01743659389469335
# slope_min_6  -  0.017415744121230314
# hpmf_mean_6  -  0.017250574352831345
# skyview_gabor_no_streams  -  0.017122958016857495
# hpmf_min_4  -  0.016838186083621715
# skyview_gabor  -  0.01675801012920184
# impundment_max_6  -  0.016529549983806343
# skyview_median_6  -  0.01645913950140155
# skyview_non_ditch  -  0.01641407015374431
# slope_median_6  -  0.016371222499315323
# slope_min_4  -  0.01566820129883951
# impundment_median_2  -  0.015433142877658004
# hpmf_min_2  -  0.015381001013422553
# skyview_min_6  -  0.015380690743489729
# skyview_max_2  -  0.015148393043089254
# slope_median_2  -  0.014680244566663114
# impundment_median_6  -  0.014628948008845425
# slope_mean_6  -  0.014628556776891215
# hpmf_std_6  -  0.014561009891102095
# impundment_median_4  -  0.014556643628515987
# impundment_std_4  -  0.01449602863982278
# hpmf_gabor_no_streams  -  0.014407613449509579
# skyview_std_6  -  0.014330563173650935
# hpmf_filter  -  0.013818362528357022
# impundment_mean_6  -  0.013796438615597305
# slope_min_2  -  0.013333545654137515
# hpmf_filter_no_streams  -  0.013058682897235264
# impundment_std_6  -  0.013007610523642237
# slope_non_ditch  -  0.012780056077411072
# hpmf_mean_2  -  0.011135052557128464
#
#
# Amount of features used:   40
# Cohen's kappa score         0.6011091982238425
# Accuracy score              0.9841899151059457
# Recall score                0.56623057336026
# Precision score             0.6590630365464802
#
# ------------------------------------------------------

# %%
most_important_features = experiment_arr[0][0].columns.tolist()[1:]
for num_features in [81, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features,
                                     random_state=42, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(np.array(y_test).reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['hpmf_raw', 'skyview_raw', 'impundment_raw', 'slope_raw', 'DEM_ditch_detection', 'DEM_ditch_detection_no_streams', 'conic_mean', 'skyview_non_ditch', 'skyview_gabor', 'conic_mean_no_streams', 'skyview_gabor_no_streams', 'skyview_mean_2', 'skyview_mean_3', 'skyview_mean_4', 'skyview_mean_6', 'skyview_median_2', 'skyview_median_4', 'skyview_median_6', 'skyview_min_2', 'skyview_min_4', 'skyview_min_6', 'skyview_max_2', 'skyview_max_4', 'skyview_max_6', 'skyview_std_2', 'skyview_std_4', 'skyview_std_6', 'impundment_amplified', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'impundment_mean_3', 'impundment_mean_4', 'impundment_mean_6', 'impundment_median_2', 'impundment_median_4', 'impundment_median_6', 'impundment_min_2', 'impundment_min_4', 'impundment_min_6', 'impundment_max_2', 'impundment_max_4', 'impundment_max_6', 'impundment_std_2', 'impundment_std_4', 'impundment_std_6', 'hpmf_filter', 'hpmf_gabor', 'hpmf_gabor_no_streams', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'hpmf_mean_3', 'hpmf_mean_4', 'hpmf_mean_6', 'hpmf_median_2', 'hpmf_median_4', 'hpmf_median_6', 'hpmf_min_2', 'hpmf_min_4', 'hpmf_min_6', 'hpmf_max_2', 'hpmf_max_4', 'hpmf_max_6', 'hpmf_std_2', 'hpmf_std_4', 'hpmf_std_6', 'slope_non_ditch', 'slope_mean_2', 'slope_mean_3', 'slope_mean_4', 'slope_mean_6', 'slope_median_2', 'slope_median_4', 'slope_median_6', 'slope_min_2', 'slope_min_4', 'slope_min_6', 'slope_max_2', 'slope_max_4', 'slope_std_2', 'slope_std_4', 'slope_std_6']
#
#
# Amount of features X_train: 81, X_test: 81
# Amount of features X_train: 81, X_test: 81
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1387769866110689
# impundment_mean_4  -  0.08884841728550347
# hpmf_mean_4  -  0.045297542310717115
# impundment_mean_2  -  0.04108911733626136
# hpmf_mean_3  -  0.0329467698434946
# impundment_median_4  -  0.031608512025810206
# hpmf_min_2  -  0.026215341362495603
# impundment_amplified  -  0.0214626244178616
# impoundment_amplified_no_streams  -  0.019806846560324866
# hpmf_median_4  -  0.01785173891428768
# impundment_max_2  -  0.015842185477983873
# skyview_max_6  -  0.01422078265458162
# skyview_gabor  -  0.01351417858459364
# impundment_std_4  -  0.012826605268227218
# skyview_gabor_no_streams  -  0.0123838176889067
# impundment_median_2  -  0.012342285374639297
# slope_std_6  -  0.0118522134350901
# hpmf_mean_6  -  0.011663524639987377
# skyview_max_4  -  0.011604821992781313
# hpmf_mean_2  -  0.011512655107277694
# slope_min_6  -  0.011452812979104563
# impundment_mean_6  -  0.010532979418914873
# skyview_non_ditch  -  0.01049655888453815
# impundment_max_6  -  0.010396697162921424
# slope_min_4  -  0.010393327389227193
# impundment_std_6  -  0.009934851818750992
# hpmf_min_4  -  0.009790447516825864
# slope_median_6  -  0.00967632540927011
# slope_non_ditch  -  0.00935779014918956
# hpmf_filter  -  0.009293253766725398
# impundment_median_6  -  0.009209267892527396
# impundment_max_4  -  0.009129840769802666
# hpmf_filter_no_streams  -  0.009015550780690211
# skyview_min_6  -  0.008871872264559632
# skyview_max_2  -  0.008862368057485772
# hpmf_gabor_no_streams  -  0.008693032282969252
# slope_mean_6  -  0.008386305470862283
# slope_std_4  -  0.008360964860609674
# hpmf_median_2  -  0.00835509801437226
# impundment_std_2  -  0.008283567229761781
# skyview_std_6  -  0.008068236480520448
# skyview_median_6  -  0.008032411485601167
# hpmf_gabor  -  0.00796903366351264
# slope_min_2  -  0.00794031350776082
# hpmf_std_6  -  0.007795338306929356
# hpmf_min_6  -  0.007417878672464401
# slope_max_4  -  0.007303304373549617
# skyview_mean_6  -  0.007181889665205155
# skyview_std_4  -  0.006747370409314808
# skyview_min_4  -  0.006720139708455716
# hpmf_std_4  -  0.006698703660401753
# hpmf_max_6  -  0.0066621526938600295
# skyview_median_4  -  0.006439437915516851
# slope_median_4  -  0.0063387575939960385
# hpmf_std_2  -  0.00624826229071105
# slope_std_2  -  0.006216331476464833
# hpmf_median_6  -  0.00616549108109175
# slope_median_2  -  0.005915877390310553
# slope_mean_4  -  0.0058771107739699156
# skyview_median_2  -  0.0055717709378821055
# skyview_std_2  -  0.005489716855721125
# slope_mean_2  -  0.005481862483434701
# slope_raw  -  0.005363667844462329
# slope_max_2  -  0.005176825950856862
# slope_mean_3  -  0.005110193517902284
# skyview_mean_4  -  0.005031472560263263
# skyview_min_2  -  0.00500262133685189
# conic_mean_no_streams  -  0.004863600554786409
# hpmf_max_4  -  0.004749571422710546
# conic_mean  -  0.004725376271465893
# skyview_raw  -  0.004679492014476652
# skyview_mean_2  -  0.0046535266188380865
# skyview_mean_3  -  0.004597573518156626
# impundment_raw  -  0.00448118210054719
# hpmf_raw  -  0.003754481055701006
# hpmf_max_2  -  0.0034633248921129784
# DEM_ditch_detection_no_streams  -  0.0023129649346533337
# DEM_ditch_detection  -  0.0019661596555782387
# impundment_min_2  -  0.0014540898247051082
# impundment_min_4  -  0.00017251243557193257
# impundment_min_6  -  9.305268132857959e-08
#
#
# Amount of features used:   81
# Cohen's kappa score         0.5995907016193438
# Accuracy score              0.9840752966707165
# Recall score                0.566862762314514
# Precision score             0.6548198636806232
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'impundment_max_2', 'skyview_max_6', 'skyview_gabor', 'impundment_std_4', 'skyview_gabor_no_streams', 'impundment_median_2', 'slope_std_6', 'hpmf_mean_6', 'skyview_max_4', 'hpmf_mean_2', 'slope_min_6', 'impundment_mean_6', 'skyview_non_ditch', 'impundment_max_6', 'slope_min_4', 'impundment_std_6', 'hpmf_min_4', 'slope_median_6', 'slope_non_ditch', 'hpmf_filter', 'impundment_median_6', 'impundment_max_4', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_max_2', 'hpmf_gabor_no_streams', 'slope_mean_6', 'slope_std_4', 'hpmf_median_2', 'impundment_std_2', 'skyview_std_6', 'skyview_median_6', 'hpmf_gabor', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'skyview_mean_6', 'skyview_std_4', 'skyview_min_4', 'hpmf_std_4', 'hpmf_max_6', 'skyview_median_4', 'slope_median_4', 'hpmf_std_2', 'slope_std_2', 'hpmf_median_6', 'slope_median_2', 'slope_mean_4', 'skyview_median_2', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'slope_max_2', 'slope_mean_3', 'skyview_mean_4', 'skyview_min_2', 'conic_mean_no_streams', 'hpmf_max_4', 'conic_mean', 'skyview_raw', 'skyview_mean_2', 'skyview_mean_3', 'impundment_raw', 'hpmf_raw', 'hpmf_max_2', 'DEM_ditch_detection_no_streams', 'DEM_ditch_detection']
#
#
# Amount of features X_train: 78, X_test: 78
# Amount of features X_train: 78, X_test: 78
#
#
# Importances for experiment:
# impundment_mean_3  -  0.13024446937711087
# impundment_mean_4  -  0.09197601924293355
# impundment_median_4  -  0.04487340907545874
# impundment_mean_2  -  0.04342048502749819
# hpmf_mean_4  -  0.04013357970798778
# hpmf_mean_3  -  0.035588575164313865
# hpmf_min_2  -  0.02202371006326069
# impundment_amplified  -  0.021784234143536762
# impoundment_amplified_no_streams  -  0.019699204721172925
# hpmf_median_4  -  0.016527060525634265
# hpmf_mean_2  -  0.015522962036231061
# skyview_max_6  -  0.014396466441621916
# impundment_std_4  -  0.01357094589343193
# skyview_gabor  -  0.013389180093822452
# impundment_median_2  -  0.013208708468845788
# skyview_gabor_no_streams  -  0.012555761523906809
# impundment_max_2  -  0.012352096816675678
# slope_std_6  -  0.01192191110322387
# slope_min_6  -  0.011651101902771984
# skyview_max_4  -  0.011647403538692145
# hpmf_mean_6  -  0.011152783123830463
# impundment_mean_6  -  0.010930232755666708
# skyview_non_ditch  -  0.010689690243424945
# slope_min_4  -  0.010534428812965065
# impundment_max_6  -  0.010455463713752122
# slope_median_6  -  0.009769293851948488
# impundment_std_6  -  0.009671210787291223
# slope_non_ditch  -  0.009536741088400996
# hpmf_min_4  -  0.009369490024049347
# hpmf_filter  -  0.009310831166865373
# hpmf_filter_no_streams  -  0.009087690243761395
# impundment_median_6  -  0.009086492286844144
# impundment_max_4  -  0.009034157193556144
# skyview_min_6  -  0.008901973679750819
# skyview_max_2  -  0.00887894582051908
# hpmf_median_2  -  0.008626430776468859
# slope_std_4  -  0.008398980467612505
# slope_mean_6  -  0.008362770470715219
# hpmf_gabor_no_streams  -  0.008289826336233154
# skyview_median_6  -  0.008246403967436927
# skyview_std_6  -  0.008147452719913982
# slope_min_2  -  0.007959652997445475
# hpmf_std_6  -  0.007860780718649478
# hpmf_min_6  -  0.007442125680257957
# slope_max_4  -  0.0072811205551167255
# hpmf_gabor  -  0.007249349104390888
# skyview_mean_6  -  0.006925693007484168
# impundment_std_2  -  0.006846488377664991
# hpmf_max_6  -  0.006726219829827703
# skyview_min_4  -  0.006688851569224585
# hpmf_std_4  -  0.006680840667371256
# skyview_std_4  -  0.006657946254939951
# slope_median_4  -  0.006413080279743386
# skyview_median_4  -  0.006313892684681332
# hpmf_std_2  -  0.006235541811632666
# slope_std_2  -  0.006215167262042139
# slope_median_2  -  0.005952937071419815
# slope_mean_4  -  0.005951431149303112
# hpmf_median_6  -  0.005755401407483784
# skyview_median_2  -  0.005585057488213667
# slope_mean_2  -  0.005482504935072761
# skyview_std_2  -  0.005479723513361139
# slope_raw  -  0.005403078852582322
# slope_max_2  -  0.0051830794854131335
# slope_mean_3  -  0.0050130950687265145
# skyview_min_2  -  0.004985163765301163
# skyview_mean_4  -  0.004946809468893851
# conic_mean_no_streams  -  0.004919002360643081
# hpmf_max_4  -  0.00470091676496223
# conic_mean  -  0.004675982304713203
# skyview_raw  -  0.0046624889929850755
# skyview_mean_3  -  0.004630959513197292
# skyview_mean_2  -  0.004536152342807182
# impundment_raw  -  0.0042026276437194
# hpmf_raw  -  0.0037166068065734295
# hpmf_max_2  -  0.0034396137387645905
# DEM_ditch_detection_no_streams  -  0.0022940994432602453
# DEM_ditch_detection  -  0.0020179426829921515
#
#
# Amount of features used:   78
# Cohen's kappa score         0.6035136831363332
# Accuracy score              0.9841417753631494
# Recall score                0.5738168408113091
# Precision score             0.6546459911047001
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_mean_2', 'skyview_max_6', 'impundment_std_4', 'skyview_gabor', 'impundment_median_2', 'skyview_gabor_no_streams', 'impundment_max_2', 'slope_std_6', 'slope_min_6', 'skyview_max_4', 'hpmf_mean_6', 'impundment_mean_6', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'impundment_std_6', 'slope_non_ditch', 'hpmf_min_4', 'hpmf_filter', 'hpmf_filter_no_streams', 'impundment_median_6', 'impundment_max_4', 'skyview_min_6', 'skyview_max_2', 'hpmf_median_2', 'slope_std_4', 'slope_mean_6', 'hpmf_gabor_no_streams', 'skyview_median_6', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'hpmf_gabor', 'skyview_mean_6', 'impundment_std_2', 'hpmf_max_6', 'skyview_min_4', 'hpmf_std_4', 'skyview_std_4', 'slope_median_4', 'skyview_median_4', 'hpmf_std_2', 'slope_std_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6', 'skyview_median_2', 'slope_mean_2', 'skyview_std_2', 'slope_raw', 'slope_max_2', 'slope_mean_3', 'skyview_min_2', 'skyview_mean_4', 'conic_mean_no_streams', 'hpmf_max_4', 'conic_mean', 'skyview_raw', 'skyview_mean_3', 'skyview_mean_2', 'impundment_raw', 'hpmf_raw', 'hpmf_max_2']
#
#
# Amount of features X_train: 76, X_test: 76
# Amount of features X_train: 76, X_test: 76
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1300534326908678
# impundment_mean_4  -  0.10240457576181801
# hpmf_mean_4  -  0.0555150989973861
# impundment_mean_2  -  0.043010248320185275
# hpmf_mean_3  -  0.0288773418224375
# impundment_median_4  -  0.028418973324674714
# hpmf_min_2  -  0.026669159988238537
# impundment_amplified  -  0.021970651672500154
# impoundment_amplified_no_streams  -  0.01988894618633382
# hpmf_median_4  -  0.018788189087990518
# skyview_max_6  -  0.014406334953592274
# impundment_median_2  -  0.013416922383911588
# skyview_gabor  -  0.013269811792356399
# skyview_gabor_no_streams  -  0.01283570758229692
# impundment_std_4  -  0.012764824703961125
# slope_std_6  -  0.011955665527881404
# skyview_max_4  -  0.011900957038517679
# slope_min_6  -  0.01163813101981405
# hpmf_mean_6  -  0.011428727667591124
# impundment_max_2  -  0.010942722844263557
# skyview_non_ditch  -  0.0107461379961699
# impundment_max_6  -  0.010562113081787361
# slope_min_4  -  0.010496452364484361
# impundment_mean_6  -  0.01025702035456959
# slope_median_6  -  0.009832281552742746
# impundment_std_6  -  0.009825584488165211
# slope_non_ditch  -  0.009740392780225184
# impundment_max_4  -  0.009600638112489401
# hpmf_min_4  -  0.00945731137566366
# hpmf_filter  -  0.00941090476770002
# hpmf_mean_2  -  0.009361204829262268
# impundment_median_6  -  0.009316896618993783
# hpmf_filter_no_streams  -  0.009110446734203241
# skyview_max_2  -  0.009016236057499974
# skyview_min_6  -  0.008915561934173512
# hpmf_gabor_no_streams  -  0.00880794664870069
# slope_mean_6  -  0.008544497103360365
# slope_std_4  -  0.00837429154325384
# skyview_median_6  -  0.008233902594573708
# hpmf_median_2  -  0.008148669726626319
# skyview_std_6  -  0.008086490202099658
# slope_min_2  -  0.007976512381535142
# hpmf_std_6  -  0.007919085179533988
# hpmf_min_6  -  0.007427577066345192
# slope_max_4  -  0.007282215004246364
# hpmf_gabor  -  0.007129973562680468
# skyview_mean_6  -  0.007084646522203783
# impundment_std_2  -  0.006853948044930364
# hpmf_max_6  -  0.006780338568850245
# skyview_std_4  -  0.006722408179444347
# skyview_min_4  -  0.006709261832732041
# hpmf_std_4  -  0.006691468438014754
# slope_median_4  -  0.006428949168862771
# skyview_median_4  -  0.006383021863635558
# slope_std_2  -  0.006278053079469631
# hpmf_std_2  -  0.006243615281488667
# slope_mean_4  -  0.006022198158233127
# slope_median_2  -  0.005857309934570478
# hpmf_median_6  -  0.005650388036766223
# skyview_median_2  -  0.005587647219440404
# skyview_std_2  -  0.005502630313695975
# slope_mean_2  -  0.005488681916219162
# slope_raw  -  0.005427136902901146
# slope_max_2  -  0.0052287729684145755
# slope_mean_3  -  0.005066965232591751
# skyview_min_2  -  0.005044394447536233
# skyview_mean_4  -  0.004981997939003317
# conic_mean_no_streams  -  0.004860553297606914
# hpmf_max_4  -  0.0047459231270614004
# conic_mean  -  0.004719430612529035
# skyview_raw  -  0.004701072447757422
# impundment_raw  -  0.004697817042259097
# skyview_mean_3  -  0.004585495879407966
# skyview_mean_2  -  0.0045494899997859575
# hpmf_raw  -  0.003852134010192391
# hpmf_max_2  -  0.0035174821066906664
#
#
# Amount of features used:   76
# Cohen's kappa score         0.6099788272295439
# Accuracy score              0.984368719864903
# Recall score                0.5809816489595223
# Precision score             0.6598851124940163
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'impundment_median_2', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_std_4', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_max_2', 'skyview_non_ditch', 'impundment_max_6', 'slope_min_4', 'impundment_mean_6', 'slope_median_6', 'impundment_std_6', 'slope_non_ditch', 'impundment_max_4', 'hpmf_min_4', 'hpmf_filter', 'hpmf_mean_2', 'impundment_median_6', 'hpmf_filter_no_streams', 'skyview_max_2', 'skyview_min_6', 'hpmf_gabor_no_streams', 'slope_mean_6', 'slope_std_4', 'skyview_median_6', 'hpmf_median_2', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'hpmf_gabor', 'skyview_mean_6', 'impundment_std_2', 'hpmf_max_6', 'skyview_std_4', 'skyview_min_4', 'hpmf_std_4', 'slope_median_4', 'skyview_median_4', 'slope_std_2', 'hpmf_std_2', 'slope_mean_4', 'slope_median_2', 'hpmf_median_6', 'skyview_median_2', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'slope_max_2', 'slope_mean_3', 'skyview_min_2', 'skyview_mean_4', 'conic_mean_no_streams', 'hpmf_max_4', 'conic_mean', 'skyview_raw', 'impundment_raw', 'skyview_mean_3', 'skyview_mean_2']
#
#
# Amount of features X_train: 74, X_test: 74
# Amount of features X_train: 74, X_test: 74
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1300631556561655
# impundment_mean_4  -  0.09870780859654349
# impundment_mean_2  -  0.04260914342916938
# hpmf_mean_3  -  0.040366949287880705
# hpmf_mean_4  -  0.036441393365063926
# impundment_median_4  -  0.03286688478953871
# hpmf_min_2  -  0.02521095906851082
# impundment_amplified  -  0.022171172505304086
# impoundment_amplified_no_streams  -  0.01997137565461777
# impundment_max_2  -  0.019272402133012775
# hpmf_median_4  -  0.018776664561695494
# skyview_max_6  -  0.014597677563534521
# skyview_gabor  -  0.013577155554778798
# impundment_std_4  -  0.013231489107438307
# skyview_gabor_no_streams  -  0.012770320671552707
# impundment_median_2  -  0.012330260863487937
# slope_std_6  -  0.01220202818026185
# skyview_max_4  -  0.011960555383659248
# hpmf_mean_6  -  0.011927149101251151
# slope_min_6  -  0.011767412126621007
# impundment_mean_6  -  0.011041535419725943
# skyview_non_ditch  -  0.010987628896100016
# slope_min_4  -  0.01073171062706445
# hpmf_min_4  -  0.010708375805186526
# impundment_max_6  -  0.010567945812527827
# hpmf_mean_2  -  0.010141656063686158
# slope_median_6  -  0.00990051856790509
# impundment_std_2  -  0.009848105283144924
# impundment_std_6  -  0.009807315616250166
# slope_non_ditch  -  0.009676978316971147
# hpmf_filter  -  0.009517291676672535
# impundment_median_6  -  0.009303633386931909
# hpmf_filter_no_streams  -  0.009216096159827318
# skyview_min_6  -  0.009043215532486135
# skyview_max_2  -  0.008994132978729138
# impundment_max_4  -  0.008895819457385521
# slope_mean_6  -  0.00848433770474917
# slope_std_4  -  0.008397621416918487
# skyview_median_6  -  0.00832891917637229
# skyview_std_6  -  0.008243370059025134
# hpmf_gabor_no_streams  -  0.00822212367820805
# slope_min_2  -  0.008086618809348307
# hpmf_std_6  -  0.008058009424864362
# hpmf_min_6  -  0.007518507033956322
# hpmf_gabor  -  0.007392198063887577
# slope_max_4  -  0.007341597391675114
# skyview_mean_6  -  0.0071212422333166185
# hpmf_median_2  -  0.007089795585275126
# hpmf_std_4  -  0.006938552245501191
# hpmf_max_6  -  0.0068797260933640934
# skyview_min_4  -  0.006838125701504105
# skyview_std_4  -  0.006761158994540015
# hpmf_std_2  -  0.0064873544273198434
# slope_median_4  -  0.00645493411192023
# skyview_median_4  -  0.006437780969267625
# slope_std_2  -  0.006365819699620977
# slope_median_2  -  0.005930017382321746
# slope_mean_4  -  0.0059284743298783854
# hpmf_median_6  -  0.005789721477386795
# skyview_median_2  -  0.005665083456653271
# skyview_std_2  -  0.005612450266821744
# slope_mean_2  -  0.005545183552861732
# slope_raw  -  0.00548149327095521
# slope_max_2  -  0.005260045587176283
# skyview_min_2  -  0.005089211510606588
# slope_mean_3  -  0.005059382135665711
# skyview_mean_4  -  0.004949843741360821
# conic_mean_no_streams  -  0.004936893697705774
# hpmf_max_4  -  0.0049118391909697915
# skyview_raw  -  0.004825026688447481
# conic_mean  -  0.00475690745485465
# skyview_mean_3  -  0.004575360151720498
# skyview_mean_2  -  0.004567361451432255
# impundment_raw  -  0.004463994631863746
#
#
# Amount of features used:   74
# Cohen's kappa score         0.6037633512992364
# Accuracy score              0.9841830379998319
# Recall score                0.572868557379928
# Precision score             0.6564046842931305
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'hpmf_mean_4', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'impundment_max_2', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'impundment_std_4', 'skyview_gabor_no_streams', 'impundment_median_2', 'slope_std_6', 'skyview_max_4', 'hpmf_mean_6', 'slope_min_6', 'impundment_mean_6', 'skyview_non_ditch', 'slope_min_4', 'hpmf_min_4', 'impundment_max_6', 'hpmf_mean_2', 'slope_median_6', 'impundment_std_2', 'impundment_std_6', 'slope_non_ditch', 'hpmf_filter', 'impundment_median_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_max_2', 'impundment_max_4', 'slope_mean_6', 'slope_std_4', 'skyview_median_6', 'skyview_std_6', 'hpmf_gabor_no_streams', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'hpmf_gabor', 'slope_max_4', 'skyview_mean_6', 'hpmf_median_2', 'hpmf_std_4', 'hpmf_max_6', 'skyview_min_4', 'skyview_std_4', 'hpmf_std_2', 'slope_median_4', 'skyview_median_4', 'slope_std_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6', 'skyview_median_2', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'slope_max_2', 'skyview_min_2', 'slope_mean_3', 'skyview_mean_4', 'conic_mean_no_streams', 'hpmf_max_4', 'skyview_raw', 'conic_mean', 'skyview_mean_3']
#
#
# Amount of features X_train: 72, X_test: 72
# Amount of features X_train: 72, X_test: 72
#
#
# Importances for experiment:
# impundment_mean_3  -  0.12837997234776177
# impundment_mean_4  -  0.11615895966217224
# hpmf_mean_4  -  0.04431855135366464
# impundment_mean_2  -  0.04013397311089603
# hpmf_mean_3  -  0.03422767460774824
# impundment_median_4  -  0.028423613326864078
# hpmf_min_2  -  0.02458047492251204
# impundment_amplified  -  0.022471042486781986
# impoundment_amplified_no_streams  -  0.020184462118019417
# hpmf_median_4  -  0.016658515115907394
# skyview_max_6  -  0.014864488187469646
# skyview_gabor  -  0.013743853556530359
# impundment_median_2  -  0.012816319417743237
# skyview_gabor_no_streams  -  0.012799299368007585
# impundment_std_4  -  0.012738688797709459
# hpmf_mean_2  -  0.012714176224243007
# hpmf_mean_6  -  0.012242468509174622
# slope_std_6  -  0.01215529247446501
# skyview_max_4  -  0.012083735204393263
# impundment_max_2  -  0.01204574578702295
# slope_min_6  -  0.011969910617682697
# skyview_non_ditch  -  0.011087569501219752
# impundment_mean_6  -  0.01103942720744145
# hpmf_min_4  -  0.010711948756875119
# slope_min_4  -  0.010675456684445438
# impundment_max_6  -  0.010668994530163843
# slope_median_6  -  0.010024084095770974
# slope_non_ditch  -  0.00995694588159646
# impundment_std_6  -  0.009848663910107362
# hpmf_filter  -  0.009624885235638134
# impundment_median_6  -  0.009412245394231406
# hpmf_filter_no_streams  -  0.009371856667814416
# skyview_max_2  -  0.009366366466273273
# skyview_min_6  -  0.009148065531580159
# impundment_max_4  -  0.008756269324946511
# slope_std_4  -  0.008620126612842716
# slope_mean_6  -  0.008603464106031475
# hpmf_gabor_no_streams  -  0.008463386527335436
# impundment_std_2  -  0.008453830473012638
# skyview_median_6  -  0.008395794619811981
# skyview_std_6  -  0.00830781086901158
# slope_min_2  -  0.008172900576817098
# hpmf_std_6  -  0.008089634818822213
# hpmf_min_6  -  0.0075644024867030125
# slope_max_4  -  0.0074521785323507315
# hpmf_gabor  -  0.0074158985489209545
# skyview_mean_6  -  0.00723256327434261
# hpmf_median_2  -  0.007036043746552956
# hpmf_max_6  -  0.006988703910504939
# hpmf_std_4  -  0.006976582578400637
# skyview_min_4  -  0.006964185551488071
# skyview_std_4  -  0.006964032250355823
# skyview_median_4  -  0.00673532186954497
# slope_median_4  -  0.006605678636358268
# hpmf_std_2  -  0.006568591333846208
# slope_std_2  -  0.006424891995530943
# skyview_median_2  -  0.0060836630379850305
# slope_median_2  -  0.006060849818796877
# slope_mean_4  -  0.006013777674091525
# hpmf_median_6  -  0.005832475875781649
# skyview_std_2  -  0.005713123258170743
# slope_mean_2  -  0.005648641601470973
# slope_raw  -  0.005591606509661799
# skyview_min_2  -  0.005328303548062956
# slope_max_2  -  0.00531821837686868
# skyview_mean_4  -  0.0051079852395094945
# slope_mean_3  -  0.0050890275636828455
# conic_mean_no_streams  -  0.005068683904504653
# hpmf_max_4  -  0.004996409213389867
# skyview_raw  -  0.0049945775792389225
# skyview_mean_3  -  0.00489757828680773
# conic_mean  -  0.004815058808517042
#
#
# Amount of features used:   72
# Cohen's kappa score         0.6054731593673217
# Accuracy score              0.984242639586151
# Recall score                0.5747651242426903
# Precision score             0.6577836729772097
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'impundment_median_2', 'skyview_gabor_no_streams', 'impundment_std_4', 'hpmf_mean_2', 'hpmf_mean_6', 'slope_std_6', 'skyview_max_4', 'impundment_max_2', 'slope_min_6', 'skyview_non_ditch', 'impundment_mean_6', 'hpmf_min_4', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'slope_non_ditch', 'impundment_std_6', 'hpmf_filter', 'impundment_median_6', 'hpmf_filter_no_streams', 'skyview_max_2', 'skyview_min_6', 'impundment_max_4', 'slope_std_4', 'slope_mean_6', 'hpmf_gabor_no_streams', 'impundment_std_2', 'skyview_median_6', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'hpmf_gabor', 'skyview_mean_6', 'hpmf_median_2', 'hpmf_max_6', 'hpmf_std_4', 'skyview_min_4', 'skyview_std_4', 'skyview_median_4', 'slope_median_4', 'hpmf_std_2', 'slope_std_2', 'skyview_median_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'skyview_min_2', 'slope_max_2', 'skyview_mean_4', 'slope_mean_3', 'conic_mean_no_streams', 'hpmf_max_4', 'skyview_raw']
#
#
# Amount of features X_train: 70, X_test: 70
# Amount of features X_train: 70, X_test: 70
#
#
# Importances for experiment:
# impundment_mean_3  -  0.14485001723053625
# impundment_mean_4  -  0.0989785793268907
# impundment_mean_2  -  0.041822748920900654
# hpmf_mean_4  -  0.04028716374226453
# hpmf_mean_3  -  0.0342760663863152
# impundment_median_4  -  0.031795821402786
# hpmf_min_2  -  0.02615487128879259
# impundment_amplified  -  0.0225420436831324
# impoundment_amplified_no_streams  -  0.02018851146085756
# hpmf_median_4  -  0.019367699097235902
# skyview_max_6  -  0.015167866290547725
# skyview_gabor  -  0.013525280818869927
# impundment_max_2  -  0.013258059403455917
# skyview_gabor_no_streams  -  0.013163958061959928
# impundment_std_4  -  0.013000823452060287
# slope_std_6  -  0.01261548685262283
# skyview_max_4  -  0.012253348058562399
# hpmf_mean_6  -  0.012230625354368755
# slope_min_6  -  0.012131923130195753
# impundment_median_2  -  0.012058220875104005
# skyview_non_ditch  -  0.011179312993908456
# impundment_max_6  -  0.010908429556620903
# impundment_mean_6  -  0.010827032577373111
# slope_min_4  -  0.010807429994200589
# hpmf_min_4  -  0.010410558067516406
# slope_median_6  -  0.01011705468136083
# impundment_std_6  -  0.010045803981221544
# hpmf_mean_2  -  0.009991765281345957
# slope_non_ditch  -  0.009990996638942033
# hpmf_filter  -  0.00980511309869457
# impundment_median_6  -  0.00958386280347559
# skyview_max_2  -  0.009545092751590425
# hpmf_filter_no_streams  -  0.009422644517361523
# skyview_min_6  -  0.00936484906315136
# impundment_max_4  -  0.009331127874108907
# skyview_median_6  -  0.008751638188737546
# slope_mean_6  -  0.008716088692439231
# slope_std_4  -  0.008522395046447421
# hpmf_gabor_no_streams  -  0.008460189787124603
# skyview_std_6  -  0.008373242664073691
# slope_min_2  -  0.008301529454965737
# hpmf_std_6  -  0.008248588263263442
# hpmf_min_6  -  0.007647716085735534
# slope_max_4  -  0.00753509401837515
# skyview_mean_6  -  0.007491505135814893
# hpmf_gabor  -  0.0073966352030983545
# hpmf_median_2  -  0.00717224475968143
# skyview_min_4  -  0.007091763057069817
# hpmf_max_6  -  0.007081449268211729
# hpmf_std_4  -  0.007075080542073763
# skyview_std_4  -  0.007024795395891353
# impundment_std_2  -  0.00701413011221487
# skyview_median_4  -  0.006975958474333075
# hpmf_std_2  -  0.006703563790249235
# slope_median_4  -  0.006638434134146426
# slope_std_2  -  0.0065117757350349765
# skyview_median_2  -  0.006365961666798935
# slope_median_2  -  0.006168308243782181
# slope_mean_4  -  0.006101930225679855
# hpmf_median_6  -  0.005950545188640999
# conic_mean_no_streams  -  0.0059168500228508345
# skyview_std_2  -  0.005840387239708958
# slope_mean_2  -  0.005745454116378031
# slope_raw  -  0.005743598907198437
# skyview_mean_4  -  0.005651080598348252
# skyview_min_2  -  0.005551258434924161
# skyview_raw  -  0.005485160716171844
# slope_max_2  -  0.005440725295081649
# slope_mean_3  -  0.005246456362212472
# hpmf_max_4  -  0.005058276454909621
#
#
# Amount of features used:   70
# Cohen's kappa score         0.5959455126570885
# Accuracy score              0.9838621063811903
# Recall score                0.5660198437088418
# Precision score             0.6477752321234777
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'impundment_median_4', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'impundment_max_2', 'skyview_gabor_no_streams', 'impundment_std_4', 'slope_std_6', 'skyview_max_4', 'hpmf_mean_6', 'slope_min_6', 'impundment_median_2', 'skyview_non_ditch', 'impundment_max_6', 'impundment_mean_6', 'slope_min_4', 'hpmf_min_4', 'slope_median_6', 'impundment_std_6', 'hpmf_mean_2', 'slope_non_ditch', 'hpmf_filter', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter_no_streams', 'skyview_min_6', 'impundment_max_4', 'skyview_median_6', 'slope_mean_6', 'slope_std_4', 'hpmf_gabor_no_streams', 'skyview_std_6', 'slope_min_2', 'hpmf_std_6', 'hpmf_min_6', 'slope_max_4', 'skyview_mean_6', 'hpmf_gabor', 'hpmf_median_2', 'skyview_min_4', 'hpmf_max_6', 'hpmf_std_4', 'skyview_std_4', 'impundment_std_2', 'skyview_median_4', 'hpmf_std_2', 'slope_median_4', 'slope_std_2', 'skyview_median_2', 'slope_median_2', 'slope_mean_4', 'hpmf_median_6', 'conic_mean_no_streams', 'skyview_std_2', 'slope_mean_2', 'slope_raw', 'skyview_mean_4', 'skyview_min_2', 'skyview_raw', 'slope_max_2']
#
#
# Amount of features X_train: 68, X_test: 68
# Amount of features X_train: 68, X_test: 68
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1415461898650655
# impundment_mean_4  -  0.09390613859725935
# impundment_median_4  -  0.044485360001917204
# hpmf_mean_4  -  0.04186232966713319
# impundment_mean_2  -  0.039418138822197496
# hpmf_mean_3  -  0.03895143712377206
# hpmf_min_2  -  0.02391938127072564
# impundment_amplified  -  0.022674879822513046
# impoundment_amplified_no_streams  -  0.020336508723112063
# hpmf_median_4  -  0.019263973473933292
# skyview_max_6  -  0.01515880754605641
# skyview_gabor  -  0.014041947071143708
# skyview_gabor_no_streams  -  0.013169043944262274
# impundment_median_2  -  0.012984494202342559
# slope_std_6  -  0.012605564342801023
# skyview_max_4  -  0.012516810431460483
# impundment_std_4  -  0.01239209476609848
# hpmf_mean_6  -  0.012383211577375694
# slope_min_6  -  0.012208631746419157
# skyview_non_ditch  -  0.01129081151181364
# impundment_mean_6  -  0.011183842306788316
# slope_min_4  -  0.011054054112778796
# impundment_max_6  -  0.011018870400218596
# slope_median_6  -  0.010317578132216298
# hpmf_min_4  -  0.010300077074240388
# slope_non_ditch  -  0.010109385188672614
# impundment_std_6  -  0.009973120039669117
# hpmf_filter  -  0.009942962122500789
# impundment_median_6  -  0.009762985275198803
# skyview_max_2  -  0.009559859642835965
# hpmf_filter_no_streams  -  0.009534713554037698
# skyview_min_6  -  0.009473297785812004
# impundment_max_4  -  0.00919533512213963
# hpmf_mean_2  -  0.009085494781932543
# impundment_max_2  -  0.008943643509531874
# slope_mean_6  -  0.008841135353004806
# skyview_median_6  -  0.008747791120766513
# slope_std_4  -  0.008646111984880729
# skyview_std_6  -  0.008518789987955674
# hpmf_gabor_no_streams  -  0.008482805141050313
# slope_min_2  -  0.008477394246899268
# hpmf_std_6  -  0.008459099235650929
# impundment_std_2  -  0.008441783777916522
# hpmf_gabor  -  0.007788044227011055
# slope_max_4  -  0.00775431855519597
# hpmf_min_6  -  0.007641348845734375
# skyview_mean_6  -  0.007610641426497951
# hpmf_max_6  -  0.007600967367883458
# hpmf_std_4  -  0.007269188151592112
# skyview_min_4  -  0.007191618196087969
# skyview_std_4  -  0.007134581824746832
# skyview_median_4  -  0.007058966682786683
# hpmf_median_2  -  0.007004287540441044
# slope_median_4  -  0.007000712500717598
# hpmf_std_2  -  0.006830271260485042
# slope_std_2  -  0.0066391288404767865
# slope_mean_4  -  0.0065781494985990945
# skyview_median_2  -  0.006524818618103485
# slope_median_2  -  0.00649943194594597
# slope_mean_2  -  0.006151596199182736
# hpmf_median_6  -  0.006027506618706868
# conic_mean_no_streams  -  0.005979004355008049
# skyview_std_2  -  0.005934331640018919
# slope_raw  -  0.005907991647025931
# skyview_mean_4  -  0.0057529303030455885
# slope_max_2  -  0.005705089531087415
# skyview_min_2  -  0.005660176372973669
# skyview_raw  -  0.005569013446544898
#
#
# Amount of features used:   68
# Cohen's kappa score         0.6023949419694287
# Accuracy score              0.9840386187714432
# Recall score                0.5749758538941083
# Precision score             0.6507274028142142
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_median_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'hpmf_min_2', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_median_2', 'slope_std_6', 'skyview_max_4', 'impundment_std_4', 'hpmf_mean_6', 'slope_min_6', 'skyview_non_ditch', 'impundment_mean_6', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'hpmf_min_4', 'slope_non_ditch', 'impundment_std_6', 'hpmf_filter', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter_no_streams', 'skyview_min_6', 'impundment_max_4', 'hpmf_mean_2', 'impundment_max_2', 'slope_mean_6', 'skyview_median_6', 'slope_std_4', 'skyview_std_6', 'hpmf_gabor_no_streams', 'slope_min_2', 'hpmf_std_6', 'impundment_std_2', 'hpmf_gabor', 'slope_max_4', 'hpmf_min_6', 'skyview_mean_6', 'hpmf_max_6', 'hpmf_std_4', 'skyview_min_4', 'skyview_std_4', 'skyview_median_4', 'hpmf_median_2', 'slope_median_4', 'hpmf_std_2', 'slope_std_2', 'slope_mean_4', 'skyview_median_2', 'slope_median_2', 'slope_mean_2', 'hpmf_median_6', 'conic_mean_no_streams', 'skyview_std_2', 'slope_raw', 'skyview_mean_4', 'slope_max_2']
#
#
# Amount of features X_train: 66, X_test: 66
# Amount of features X_train: 66, X_test: 66
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1590355541213641
# impundment_mean_4  -  0.1115221056426609
# hpmf_mean_4  -  0.05221990706092884
# impundment_mean_2  -  0.03442280043885016
# hpmf_mean_3  -  0.026432702162494902
# impundment_amplified  -  0.0228648488816693
# impundment_median_4  -  0.02199489921800812
# impoundment_amplified_no_streams  -  0.02079114032860667
# hpmf_median_4  -  0.018222164559449017
# hpmf_min_2  -  0.016697280656255906
# skyview_max_6  -  0.015570639132985096
# impundment_median_2  -  0.015236604078944446
# skyview_gabor  -  0.013652372057917814
# skyview_gabor_no_streams  -  0.013228314769863025
# slope_std_6  -  0.012863686524666889
# impundment_std_4  -  0.012650816513452186
# skyview_max_4  -  0.01264264789826645
# slope_min_6  -  0.012572574298853697
# impundment_max_2  -  0.012121000948352216
# hpmf_mean_6  -  0.012091966669732146
# skyview_non_ditch  -  0.011577146431504525
# impundment_mean_6  -  0.011360017214289293
# slope_min_4  -  0.011247062152471243
# hpmf_min_4  -  0.011165393024157862
# impundment_max_6  -  0.01109879772482128
# slope_median_6  -  0.010491058032276946
# slope_non_ditch  -  0.010352074884792716
# impundment_median_6  -  0.010067179646048523
# hpmf_filter  -  0.010048046647518322
# impundment_std_6  -  0.01003708808739604
# skyview_max_2  -  0.009893363650913853
# hpmf_filter_no_streams  -  0.009741343667558399
# skyview_min_6  -  0.009584132746062478
# impundment_max_4  -  0.009295319772098439
# skyview_median_6  -  0.009093930030245057
# slope_mean_6  -  0.008961243878478268
# slope_std_4  -  0.008790418863598218
# hpmf_mean_2  -  0.008737756888670335
# slope_min_2  -  0.00862999308159693
# skyview_std_6  -  0.008584005299750334
# hpmf_gabor_no_streams  -  0.008582183822673908
# hpmf_std_6  -  0.00853257355982805
# slope_max_4  -  0.007815026816596305
# hpmf_max_6  -  0.007741534486074076
# hpmf_min_6  -  0.007734254646618596
# skyview_mean_6  -  0.007594178048203472
# hpmf_gabor  -  0.0075479292752470934
# hpmf_std_4  -  0.00742571060580542
# skyview_min_4  -  0.007375299919031879
# hpmf_median_2  -  0.007304338965506868
# skyview_median_4  -  0.0072839839098790896
# skyview_std_4  -  0.0072680485988519524
# impundment_std_2  -  0.007154529718668991
# slope_median_4  -  0.0071322120408398755
# skyview_median_2  -  0.007027249767717055
# hpmf_std_2  -  0.006991690169040389
# slope_std_2  -  0.006906777908774231
# skyview_std_2  -  0.006663731684001035
# slope_mean_4  -  0.006658655140236894
# slope_median_2  -  0.006636128156536207
# conic_mean_no_streams  -  0.00648291857403098
# slope_mean_2  -  0.006348521443745423
# slope_raw  -  0.006181945979228065
# hpmf_median_6  -  0.006086886198739342
# skyview_mean_4  -  0.0060236942885754565
# slope_max_2  -  0.005910598587978422
#
#
# Amount of features used:   66
# Cohen's kappa score         0.6063989150532858
# Accuracy score              0.9842770251167198
# Recall score                0.5757134076740714
# Precision score             0.6586306653809064
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_amplified', 'impundment_median_4', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_min_2', 'skyview_max_6', 'impundment_median_2', 'skyview_gabor', 'skyview_gabor_no_streams', 'slope_std_6', 'impundment_std_4', 'skyview_max_4', 'slope_min_6', 'impundment_max_2', 'hpmf_mean_6', 'skyview_non_ditch', 'impundment_mean_6', 'slope_min_4', 'hpmf_min_4', 'impundment_max_6', 'slope_median_6', 'slope_non_ditch', 'impundment_median_6', 'hpmf_filter', 'impundment_std_6', 'skyview_max_2', 'hpmf_filter_no_streams', 'skyview_min_6', 'impundment_max_4', 'skyview_median_6', 'slope_mean_6', 'slope_std_4', 'hpmf_mean_2', 'slope_min_2', 'skyview_std_6', 'hpmf_gabor_no_streams', 'hpmf_std_6', 'slope_max_4', 'hpmf_max_6', 'hpmf_min_6', 'skyview_mean_6', 'hpmf_gabor', 'hpmf_std_4', 'skyview_min_4', 'hpmf_median_2', 'skyview_median_4', 'skyview_std_4', 'impundment_std_2', 'slope_median_4', 'skyview_median_2', 'hpmf_std_2', 'slope_std_2', 'skyview_std_2', 'slope_mean_4', 'slope_median_2', 'conic_mean_no_streams', 'slope_mean_2', 'slope_raw', 'hpmf_median_6']
#
#
# Amount of features X_train: 64, X_test: 64
# Amount of features X_train: 64, X_test: 64
#
#
# Importances for experiment:
# impundment_mean_3  -  0.15311063551776796
# impundment_mean_4  -  0.1035896260904492
# impundment_mean_2  -  0.04912620066447426
# hpmf_mean_4  -  0.04303172723039607
# impundment_median_4  -  0.031550035478278574
# impundment_amplified  -  0.02345314306898071
# hpmf_mean_3  -  0.02243183111652129
# impoundment_amplified_no_streams  -  0.0206764525694798
# hpmf_min_2  -  0.018469639512404885
# hpmf_median_4  -  0.01611327870763526
# skyview_max_6  -  0.015937334951306847
# hpmf_mean_2  -  0.015623749874383253
# skyview_gabor  -  0.014215748332609366
# impundment_median_2  -  0.013755072691313368
# skyview_gabor_no_streams  -  0.013391384613449707
# slope_std_6  -  0.013062876337335633
# skyview_max_4  -  0.012926486588419793
# slope_min_6  -  0.012809778573807714
# hpmf_mean_6  -  0.012717329105068004
# impundment_std_4  -  0.011876493314905628
# skyview_non_ditch  -  0.011824221138875561
# slope_min_4  -  0.011418535171420725
# hpmf_min_4  -  0.011348755302818475
# impundment_max_6  -  0.01131300607836981
# impundment_mean_6  -  0.01091846275714468
# slope_median_6  -  0.010677625537070166
# impundment_max_2  -  0.010559170587683294
# slope_non_ditch  -  0.010405946923938696
# skyview_max_2  -  0.010249966825624542
# hpmf_filter  -  0.010235025077370192
# impundment_std_6  -  0.010123960068047055
# impundment_median_6  -  0.010082615555521129
# hpmf_filter_no_streams  -  0.00988483557656907
# skyview_min_6  -  0.00980478708542195
# skyview_median_6  -  0.009369580702919865
# slope_std_4  -  0.0091303934971914
# slope_mean_6  -  0.009116433372651028
# impundment_max_4  -  0.00901465907792017
# slope_min_2  -  0.008777947737680678
# hpmf_std_6  -  0.008746596768176764
# hpmf_gabor_no_streams  -  0.008723496499489619
# skyview_std_6  -  0.008711393823562332
# impundment_std_2  -  0.008475050263705174
# slope_max_4  -  0.008196727120747808
# skyview_mean_6  -  0.008147884100747842
# hpmf_gabor  -  0.007904935210571768
# hpmf_min_6  -  0.00787309916307092
# hpmf_max_6  -  0.007839881501305426
# skyview_median_4  -  0.007823680968597285
# skyview_min_4  -  0.00771810583548799
# hpmf_std_4  -  0.0075713868525111964
# skyview_std_4  -  0.007524529343258308
# slope_std_2  -  0.007336840491675014
# skyview_median_2  -  0.007287144953632118
# slope_median_4  -  0.0072387148846299485
# hpmf_median_2  -  0.007049456190867272
# hpmf_std_2  -  0.007006220262413571
# slope_mean_4  -  0.007001394750354731
# skyview_std_2  -  0.006992607195664732
# slope_median_2  -  0.006860568090632085
# slope_mean_2  -  0.006688274134290035
# conic_mean_no_streams  -  0.0065651585237193645
# slope_raw  -  0.006368431844054834
# hpmf_median_6  -  0.006223668813608047
#
#
# Amount of features used:   64
# Cohen's kappa score         0.6056769337195882
# Accuracy score              0.9841807456311273
# Recall score                0.5776099745368338
# Precision score             0.6546453307857655
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'impundment_median_4', 'impundment_amplified', 'hpmf_mean_3', 'impoundment_amplified_no_streams', 'hpmf_min_2', 'hpmf_median_4', 'skyview_max_6', 'hpmf_mean_2', 'skyview_gabor', 'impundment_median_2', 'skyview_gabor_no_streams', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_std_4', 'skyview_non_ditch', 'slope_min_4', 'hpmf_min_4', 'impundment_max_6', 'impundment_mean_6', 'slope_median_6', 'impundment_max_2', 'slope_non_ditch', 'skyview_max_2', 'hpmf_filter', 'impundment_std_6', 'impundment_median_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_median_6', 'slope_std_4', 'slope_mean_6', 'impundment_max_4', 'slope_min_2', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'impundment_std_2', 'slope_max_4', 'skyview_mean_6', 'hpmf_gabor', 'hpmf_min_6', 'hpmf_max_6', 'skyview_median_4', 'skyview_min_4', 'hpmf_std_4', 'skyview_std_4', 'slope_std_2', 'skyview_median_2', 'slope_median_4', 'hpmf_median_2', 'hpmf_std_2', 'slope_mean_4', 'skyview_std_2', 'slope_median_2', 'slope_mean_2', 'conic_mean_no_streams']
#
#
# Amount of features X_train: 62, X_test: 62
# Amount of features X_train: 62, X_test: 62
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1662887823844338
# impundment_mean_4  -  0.09671039316182958
# hpmf_mean_4  -  0.05570141728023621
# impundment_mean_2  -  0.037628488191188594
# hpmf_mean_3  -  0.026336743324700235
# impundment_median_4  -  0.025732453363941345
# impundment_amplified  -  0.023152772518584705
# impoundment_amplified_no_streams  -  0.021444251051448204
# hpmf_min_2  -  0.0202144150108517
# hpmf_median_4  -  0.020214148598596965
# skyview_max_6  -  0.01624785282955136
# skyview_gabor  -  0.01430347568311083
# skyview_gabor_no_streams  -  0.01353423549345844
# impundment_std_4  -  0.013383270391745932
# slope_std_6  -  0.013293575483202733
# skyview_max_4  -  0.013092069871518466
# slope_min_6  -  0.012916529462658484
# hpmf_mean_6  -  0.012798825595425067
# impundment_median_2  -  0.012581786936835232
# skyview_non_ditch  -  0.012218926580599379
# slope_min_4  -  0.011638397176486213
# impundment_max_6  -  0.011419518881405015
# impundment_mean_6  -  0.011218555883712643
# hpmf_min_4  -  0.011004331316297574
# slope_median_6  -  0.010850153572644704
# skyview_max_2  -  0.010562309051511107
# impundment_median_6  -  0.010519542603192003
# slope_non_ditch  -  0.010505193553129896
# hpmf_mean_2  -  0.010461838973514066
# hpmf_filter  -  0.010428695311892666
# impundment_std_6  -  0.010278798654960997
# hpmf_filter_no_streams  -  0.010096031479259308
# skyview_min_6  -  0.009961767442437965
# skyview_median_6  -  0.009495539181263848
# slope_std_4  -  0.009366983623017492
# slope_mean_6  -  0.009361040207540916
# hpmf_gabor  -  0.009299509287922194
# impundment_max_4  -  0.009056106057947499
# slope_min_2  -  0.009044841327300074
# hpmf_std_6  -  0.008941153942129923
# skyview_std_6  -  0.008905913762263561
# hpmf_gabor_no_streams  -  0.008825876889093878
# slope_max_4  -  0.008286608770218789
# skyview_mean_6  -  0.008252876472881586
# hpmf_min_6  -  0.008121109188084629
# skyview_median_4  -  0.008006289142729939
# hpmf_max_6  -  0.0079820131055863
# skyview_min_4  -  0.00782411045872947
# skyview_std_4  -  0.007711514683653493
# hpmf_std_4  -  0.007691598887290565
# impundment_max_2  -  0.007551760393714866
# slope_std_2  -  0.007530015987438465
# skyview_median_2  -  0.007473159185418169
# impundment_std_2  -  0.007421042343103909
# slope_median_4  -  0.007395103979867157
# slope_median_2  -  0.007379641944445658
# hpmf_std_2  -  0.007306091168114125
# slope_mean_2  -  0.007174222653760478
# skyview_std_2  -  0.00714678670712653
# slope_mean_4  -  0.007105143777703804
# conic_mean_no_streams  -  0.00682545981398522
# hpmf_median_2  -  0.0067789399433061896
#
#
# Amount of features used:   62
# Cohen's kappa score         0.6016658284447876
# Accuracy score              0.9841211440448082
# Recall score                0.5701290719114935
# Precision score             0.6552434003390651
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_min_2', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_std_4', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_median_2', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'impundment_mean_6', 'hpmf_min_4', 'slope_median_6', 'skyview_max_2', 'impundment_median_6', 'slope_non_ditch', 'hpmf_mean_2', 'hpmf_filter', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_median_6', 'slope_std_4', 'slope_mean_6', 'hpmf_gabor', 'impundment_max_4', 'slope_min_2', 'hpmf_std_6', 'skyview_std_6', 'hpmf_gabor_no_streams', 'slope_max_4', 'skyview_mean_6', 'hpmf_min_6', 'skyview_median_4', 'hpmf_max_6', 'skyview_min_4', 'skyview_std_4', 'hpmf_std_4', 'impundment_max_2', 'slope_std_2', 'skyview_median_2', 'impundment_std_2', 'slope_median_4', 'slope_median_2', 'hpmf_std_2', 'slope_mean_2', 'skyview_std_2', 'slope_mean_4']
#
#
# Amount of features X_train: 60, X_test: 60
# Amount of features X_train: 60, X_test: 60
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1612298204118971
# impundment_mean_4  -  0.10070503937959974
# hpmf_mean_4  -  0.04999984957857058
# impundment_mean_2  -  0.03518126041365792
# hpmf_mean_3  -  0.03295525871101122
# impundment_median_4  -  0.027825783853671703
# impundment_amplified  -  0.02377733640575619
# impoundment_amplified_no_streams  -  0.021409469844117013
# hpmf_median_4  -  0.021258084169988624
# hpmf_min_2  -  0.020219070708852736
# skyview_max_6  -  0.01652042930808787
# hpmf_mean_6  -  0.0145380490214444
# skyview_gabor  -  0.014198359921417544
# skyview_gabor_no_streams  -  0.014006581502148039
# impundment_median_2  -  0.013810818085329368
# skyview_max_4  -  0.013579806314576776
# slope_std_6  -  0.013573716733516136
# slope_min_6  -  0.01315166831734674
# skyview_non_ditch  -  0.012402262885210028
# impundment_std_4  -  0.012237623105063183
# slope_min_4  -  0.01177557770961253
# impundment_max_6  -  0.011656790738452327
# impundment_mean_6  -  0.011266900187379008
# slope_median_6  -  0.011150155837705093
# hpmf_mean_2  -  0.011122874401317248
# hpmf_min_4  -  0.011098708679038513
# impundment_median_6  -  0.010819081620194702
# impundment_max_2  -  0.010676344042589173
# skyview_max_2  -  0.010633918180609634
# hpmf_filter  -  0.01061178129680182
# slope_non_ditch  -  0.010582058855802112
# impundment_std_6  -  0.010372222395279254
# hpmf_filter_no_streams  -  0.01036432493431807
# skyview_min_6  -  0.01015057229829562
# skyview_median_6  -  0.009662496806588133
# slope_mean_6  -  0.0095721139917969
# impundment_max_4  -  0.009553494668422393
# slope_std_4  -  0.009419603425538681
# slope_min_2  -  0.00916204377503213
# hpmf_gabor_no_streams  -  0.00913529105297414
# skyview_std_6  -  0.00907671962874666
# hpmf_std_6  -  0.009067624172235039
# skyview_mean_6  -  0.008473875619584308
# slope_max_4  -  0.00843483160738153
# hpmf_min_6  -  0.008233951608278132
# skyview_median_4  -  0.00820914869418921
# hpmf_max_6  -  0.00814305340425929
# hpmf_gabor  -  0.00805835453736338
# skyview_min_4  -  0.007947810179403039
# hpmf_std_4  -  0.007887167864638518
# skyview_median_2  -  0.00788655674821034
# skyview_std_4  -  0.007785992828227703
# slope_std_2  -  0.007639142324821003
# slope_median_4  -  0.007543857507980641
# slope_median_2  -  0.007491049064480134
# hpmf_std_2  -  0.00747711725137596
# impundment_std_2  -  0.007432660763285183
# slope_mean_2  -  0.007289690149857048
# skyview_std_2  -  0.0072790240398092135
# slope_mean_4  -  0.007275728436863407
#
#
# Amount of features used:   60
# Cohen's kappa score         0.6091966912598136
# Accuracy score              0.9843022411724702
# Recall score                0.5816138379137764
# Precision score             0.6573776348695963
#
# ------------------------------------------------------

# %%
most_important_features = ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3',
                           'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_min_2',
                           'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_std_4',
                           'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_median_2',
                           'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'impundment_mean_6', 'hpmf_min_4',
                           'slope_median_6', 'skyview_max_2', 'impundment_median_6', 'slope_non_ditch', 'hpmf_mean_2',
                           'hpmf_filter', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_median_6',
                           'slope_std_4', 'slope_mean_6', 'hpmf_gabor', 'impundment_max_4', 'slope_min_2', 'hpmf_std_6',
                           'skyview_std_6', 'hpmf_gabor_no_streams', 'slope_max_4', 'skyview_mean_6', 'hpmf_min_6',
                           'skyview_median_4', 'hpmf_max_6', 'skyview_min_4', 'skyview_std_4', 'hpmf_std_4',
                           'impundment_max_2', 'slope_std_2', 'skyview_median_2', 'impundment_std_2', 'slope_median_4', 
                           'slope_median_2', 'hpmf_std_2', 'slope_mean_2', 'skyview_std_2', 'slope_mean_4']
for num_features in [60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features,
                                     random_state=42, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(np.array(y_test).reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_min_2', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_std_4', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_median_2', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'impundment_mean_6', 'hpmf_min_4', 'slope_median_6', 'skyview_max_2', 'impundment_median_6', 'slope_non_ditch', 'hpmf_mean_2', 'hpmf_filter', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_median_6', 'slope_std_4', 'slope_mean_6', 'hpmf_gabor', 'impundment_max_4', 'slope_min_2', 'hpmf_std_6', 'skyview_std_6', 'hpmf_gabor_no_streams', 'slope_max_4', 'skyview_mean_6', 'hpmf_min_6', 'skyview_median_4', 'hpmf_max_6', 'skyview_min_4', 'skyview_std_4', 'hpmf_std_4', 'impundment_max_2', 'slope_std_2', 'skyview_median_2', 'impundment_std_2', 'slope_median_4', 'slope_median_2', 'hpmf_std_2', 'slope_mean_2', 'skyview_std_2', 'slope_mean_4']
#
#
# Amount of features X_train: 60, X_test: 60
# Amount of features X_train: 60, X_test: 60
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1612298204118971
# impundment_mean_4  -  0.10070503937959974
# hpmf_mean_4  -  0.04999984957857058
# impundment_mean_2  -  0.03518126041365792
# hpmf_mean_3  -  0.03295525871101122
# impundment_median_4  -  0.027825783853671703
# impundment_amplified  -  0.02377733640575619
# impoundment_amplified_no_streams  -  0.021409469844117013
# hpmf_median_4  -  0.021258084169988624
# hpmf_min_2  -  0.020219070708852736
# skyview_max_6  -  0.01652042930808787
# hpmf_mean_6  -  0.0145380490214444
# skyview_gabor  -  0.014198359921417544
# skyview_gabor_no_streams  -  0.014006581502148039
# impundment_median_2  -  0.013810818085329368
# skyview_max_4  -  0.013579806314576776
# slope_std_6  -  0.013573716733516136
# slope_min_6  -  0.01315166831734674
# skyview_non_ditch  -  0.012402262885210028
# impundment_std_4  -  0.012237623105063183
# slope_min_4  -  0.01177557770961253
# impundment_max_6  -  0.011656790738452327
# impundment_mean_6  -  0.011266900187379008
# slope_median_6  -  0.011150155837705093
# hpmf_mean_2  -  0.011122874401317248
# hpmf_min_4  -  0.011098708679038513
# impundment_median_6  -  0.010819081620194702
# impundment_max_2  -  0.010676344042589173
# skyview_max_2  -  0.010633918180609634
# hpmf_filter  -  0.01061178129680182
# slope_non_ditch  -  0.010582058855802112
# impundment_std_6  -  0.010372222395279254
# hpmf_filter_no_streams  -  0.01036432493431807
# skyview_min_6  -  0.01015057229829562
# skyview_median_6  -  0.009662496806588133
# slope_mean_6  -  0.0095721139917969
# impundment_max_4  -  0.009553494668422393
# slope_std_4  -  0.009419603425538681
# slope_min_2  -  0.00916204377503213
# hpmf_gabor_no_streams  -  0.00913529105297414
# skyview_std_6  -  0.00907671962874666
# hpmf_std_6  -  0.009067624172235039
# skyview_mean_6  -  0.008473875619584308
# slope_max_4  -  0.00843483160738153
# hpmf_min_6  -  0.008233951608278132
# skyview_median_4  -  0.00820914869418921
# hpmf_max_6  -  0.00814305340425929
# hpmf_gabor  -  0.00805835453736338
# skyview_min_4  -  0.007947810179403039
# hpmf_std_4  -  0.007887167864638518
# skyview_median_2  -  0.00788655674821034
# skyview_std_4  -  0.007785992828227703
# slope_std_2  -  0.007639142324821003
# slope_median_4  -  0.007543857507980641
# slope_median_2  -  0.007491049064480134
# hpmf_std_2  -  0.00747711725137596
# impundment_std_2  -  0.007432660763285183
# slope_mean_2  -  0.007289690149857048
# skyview_std_2  -  0.0072790240398092135
# slope_mean_4  -  0.007275728436863407
#
#
# Amount of features used:   60
# Cohen's kappa score         0.6091966912598136
# Accuracy score              0.9843022411724702
# Recall score                0.5816138379137764
# Precision score             0.6573776348695963
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_min_2', 'skyview_max_6', 'hpmf_mean_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'impundment_median_2', 'skyview_max_4', 'slope_std_6', 'slope_min_6', 'skyview_non_ditch', 'impundment_std_4', 'slope_min_4', 'impundment_max_6', 'impundment_mean_6', 'slope_median_6', 'hpmf_mean_2', 'hpmf_min_4', 'impundment_median_6', 'impundment_max_2', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'skyview_median_6', 'slope_mean_6', 'impundment_max_4', 'slope_std_4', 'slope_min_2', 'hpmf_gabor_no_streams', 'skyview_std_6', 'hpmf_std_6', 'skyview_mean_6', 'slope_max_4', 'hpmf_min_6', 'skyview_median_4', 'hpmf_max_6', 'hpmf_gabor', 'skyview_min_4', 'hpmf_std_4', 'skyview_median_2', 'skyview_std_4', 'slope_std_2', 'slope_median_4', 'slope_median_2', 'hpmf_std_2', 'impundment_std_2', 'slope_mean_2']
#
#
# Amount of features X_train: 58, X_test: 58
# Amount of features X_train: 58, X_test: 58
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1629088102282522
# impundment_mean_4  -  0.10251290251787729
# hpmf_mean_4  -  0.04512382421951057
# impundment_mean_2  -  0.03961923945639047
# impundment_median_4  -  0.03234284126041987
# hpmf_mean_3  -  0.028460266642017854
# impundment_amplified  -  0.02424623718488034
# hpmf_min_2  -  0.022669111886654443
# impoundment_amplified_no_streams  -  0.021423420961326864
# hpmf_median_4  -  0.020814845202975087
# skyview_max_6  -  0.016857757007866504
# skyview_gabor  -  0.014763993164247043
# skyview_gabor_no_streams  -  0.014267071168612328
# slope_std_6  -  0.013741135122507332
# skyview_max_4  -  0.013730745899400182
# slope_min_6  -  0.013501100018615608
# hpmf_mean_6  -  0.013427555509666693
# skyview_non_ditch  -  0.012534761728718775
# impundment_std_4  -  0.012164211178551172
# impundment_median_2  -  0.012064073490895014
# slope_min_4  -  0.011990437987034537
# impundment_max_6  -  0.011820764616235789
# slope_median_6  -  0.01181996753471137
# impundment_max_2  -  0.011523352047042669
# impundment_mean_6  -  0.011370958940843966
# hpmf_min_4  -  0.011052005832375662
# impundment_median_6  -  0.011034341885648648
# skyview_max_2  -  0.010890052275726852
# hpmf_filter  -  0.010824927580240298
# slope_non_ditch  -  0.010785179605483766
# impundment_std_6  -  0.010569888535418027
# hpmf_filter_no_streams  -  0.010536979775092676
# skyview_min_6  -  0.010437395709468535
# hpmf_mean_2  -  0.010375296949565706
# slope_mean_6  -  0.010127151283185379
# skyview_median_6  -  0.010007933687704695
# slope_std_4  -  0.009839506117870642
# impundment_max_4  -  0.009543965287006094
# slope_min_2  -  0.00938897102630791
# skyview_std_6  -  0.009335445827593242
# hpmf_std_6  -  0.009304622598611725
# hpmf_gabor_no_streams  -  0.00929077819121836
# slope_max_4  -  0.008875659650247239
# skyview_mean_6  -  0.008628041985991045
# skyview_median_4  -  0.008474699857649893
# slope_median_4  -  0.008426464694127351
# slope_std_2  -  0.008345621460212728
# skyview_std_4  -  0.008340279494924234
# hpmf_max_6  -  0.008316235212858219
# hpmf_min_6  -  0.008301171944861518
# skyview_min_4  -  0.00818000636557729
# hpmf_gabor  -  0.008177595101012108
# skyview_median_2  -  0.008175058885902427
# hpmf_std_4  -  0.00806892367012521
# slope_median_2  -  0.00784517585679722
# slope_mean_2  -  0.007701971599590584
# hpmf_std_2  -  0.007621913198150071
# impundment_std_2  -  0.007477353878200732
#
#
# Amount of features used:   58
# Cohen's kappa score         0.6015317192752208
# Accuracy score              0.9841096822012853
# Recall score                0.5702344367372025
# Precision score             0.6548094373865698
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_median_4', 'hpmf_mean_3', 'impundment_amplified', 'hpmf_min_2', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'slope_std_6', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'skyview_non_ditch', 'impundment_std_4', 'impundment_median_2', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'impundment_max_2', 'impundment_mean_6', 'hpmf_min_4', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'impundment_std_6', 'hpmf_filter_no_streams', 'skyview_min_6', 'hpmf_mean_2', 'slope_mean_6', 'skyview_median_6', 'slope_std_4', 'impundment_max_4', 'slope_min_2', 'skyview_std_6', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'slope_max_4', 'skyview_mean_6', 'skyview_median_4', 'slope_median_4', 'slope_std_2', 'skyview_std_4', 'hpmf_max_6', 'hpmf_min_6', 'skyview_min_4', 'hpmf_gabor', 'skyview_median_2', 'hpmf_std_4', 'slope_median_2', 'slope_mean_2']
# Amount of features X_train: 56, X_test: 56
# Amount of features X_train: 56, X_test: 56
#
#
# Importances for experiment:
# impundment_mean_3  -  0.17908589880184866
# impundment_mean_4  -  0.10894420935050472
# hpmf_mean_4  -  0.042994232522818615
# impundment_mean_2  -  0.03945388116244267
# impundment_median_4  -  0.02636487030485648
# impundment_amplified  -  0.024699534699629634
# hpmf_mean_3  -  0.024269234824795052
# impoundment_amplified_no_streams  -  0.02162971225534819
# hpmf_median_4  -  0.020334613942374943
# skyview_max_6  -  0.017177862494069076
# hpmf_min_2  -  0.014578557150701194
# skyview_gabor_no_streams  -  0.014415942092000209
# skyview_gabor  -  0.014414373938641457
# slope_std_6  -  0.01428661332580039
# slope_min_6  -  0.013882682017468739
# skyview_max_4  -  0.013855884576944092
# hpmf_mean_6  -  0.013673741357441115
# impundment_median_2  -  0.013587886965462377
# impundment_max_2  -  0.013079920014369917
# skyview_non_ditch  -  0.012823698182254902
# slope_min_4  -  0.012282876431870295
# hpmf_min_4  -  0.012244026330238848
# impundment_max_6  -  0.012072185253122203
# slope_median_6  -  0.011958597733616814
# impundment_mean_6  -  0.011692904779309253
# impundment_std_4  -  0.011640756125165842
# impundment_median_6  -  0.011377658065416452
# skyview_max_2  -  0.01108223150186395
# hpmf_filter  -  0.011079787312192637
# slope_non_ditch  -  0.01099812780693879
# hpmf_filter_no_streams  -  0.010779601583677557
# hpmf_mean_2  -  0.010761775885480012
# impundment_std_6  -  0.010633886848435886
# skyview_min_6  -  0.010632292396604747
# skyview_median_6  -  0.010288252003610023
# slope_mean_6  -  0.010285256328488184
# slope_std_4  -  0.010066060733875217
# impundment_max_4  -  0.00975517324469262
# slope_min_2  -  0.009587211079458327
# hpmf_std_6  -  0.009557837923391144
# hpmf_gabor_no_streams  -  0.00943202336319348
# skyview_std_6  -  0.00937590767361405
# slope_max_4  -  0.00903601786532262
# skyview_mean_6  -  0.008791020366059473
# hpmf_std_4  -  0.00865790227128307
# hpmf_max_6  -  0.008595819045935604
# slope_std_2  -  0.008590159792204989
# skyview_median_4  -  0.008566112281088263
# slope_median_4  -  0.008545865966682883
# hpmf_min_6  -  0.008483222148649704
# skyview_std_4  -  0.008474230869823959
# skyview_median_2  -  0.008383962597582666
# skyview_min_4  -  0.008370641124084716
# hpmf_gabor  -  0.00830817398691464
# slope_median_2  -  0.008036179498330484
# slope_mean_2  -  0.008022911802008162
#
#
# Amount of features used:   56
# Cohen's kappa score         0.6042084143056339
# Accuracy score              0.9842311777426281
# Recall score                0.5721310035999648
# Precision score             0.6583414161008729
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_median_4', 'impundment_amplified', 'hpmf_mean_3', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'hpmf_min_2', 'skyview_gabor_no_streams', 'skyview_gabor', 'slope_std_6', 'slope_min_6', 'skyview_max_4', 'hpmf_mean_6', 'impundment_median_2', 'impundment_max_2', 'skyview_non_ditch', 'slope_min_4', 'hpmf_min_4', 'impundment_max_6', 'slope_median_6', 'impundment_mean_6', 'impundment_std_4', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'impundment_std_6', 'skyview_min_6', 'skyview_median_6', 'slope_mean_6', 'slope_std_4', 'impundment_max_4', 'slope_min_2', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'slope_max_4', 'skyview_mean_6', 'hpmf_std_4', 'hpmf_max_6', 'slope_std_2', 'skyview_median_4', 'slope_median_4', 'hpmf_min_6', 'skyview_std_4', 'skyview_median_2', 'skyview_min_4', 'hpmf_gabor']
#
#
# Amount of features X_train: 54, X_test: 54
# Amount of features X_train: 54, X_test: 54
#
#
# Importances for experiment:
# impundment_mean_3  -  0.15202343084853404
# impundment_mean_4  -  0.1237438147396874
# impundment_mean_2  -  0.050900068928327394
# hpmf_mean_4  -  0.039545049329023946
# hpmf_mean_3  -  0.028332835049818535
# impundment_median_4  -  0.02519584008489418
# impundment_amplified  -  0.02470769362469904
# impoundment_amplified_no_streams  -  0.022159556076260002
# hpmf_median_4  -  0.021934079225075946
# hpmf_min_2  -  0.02134728286982211
# skyview_max_6  -  0.0174570063755163
# skyview_gabor  -  0.014950600249247693
# slope_std_6  -  0.014892412165646133
# skyview_gabor_no_streams  -  0.01462952927834938
# skyview_max_4  -  0.014321448407953621
# slope_min_6  -  0.014038331067479638
# hpmf_mean_6  -  0.013587713772904323
# skyview_non_ditch  -  0.013155936083024303
# impundment_median_2  -  0.012876800449660202
# slope_min_4  -  0.012451855981392292
# impundment_std_4  -  0.012442688496605184
# slope_median_6  -  0.012341374154485604
# impundment_max_6  -  0.012314116519067293
# hpmf_min_4  -  0.012098697768195952
# impundment_mean_6  -  0.011722362904751399
# impundment_median_6  -  0.011658904404482577
# skyview_max_2  -  0.011396783447093418
# hpmf_filter  -  0.011353054147663022
# slope_non_ditch  -  0.011325394570501746
# hpmf_filter_no_streams  -  0.010921671645541373
# impundment_std_6  -  0.010899780987017356
# skyview_min_6  -  0.010835028201702755
# slope_mean_6  -  0.010767920171874874
# slope_min_2  -  0.010537587486203284
# skyview_median_6  -  0.010504732634643047
# hpmf_mean_2  -  0.010431830273325421
# slope_std_4  -  0.010276200560130257
# hpmf_std_6  -  0.009796063070668798
# impundment_max_4  -  0.009745973739714751
# slope_median_4  -  0.009725602122861747
# skyview_std_6  -  0.0097228422506241
# hpmf_gabor_no_streams  -  0.009578231765484608
# skyview_median_2  -  0.009472372475772161
# impundment_max_2  -  0.009423899702742478
# slope_max_4  -  0.009407921328777168
# skyview_median_4  -  0.00915118399919822
# slope_std_2  -  0.009139955010975647
# skyview_mean_6  -  0.008997699946859731
# hpmf_std_4  -  0.00897683547663804
# hpmf_max_6  -  0.008816350368145324
# skyview_std_4  -  0.008665224291235119
# skyview_min_4  -  0.008554754835975977
# hpmf_min_6  -  0.008508451751478595
# hpmf_gabor  -  0.008237224882246649
#
#
# Amount of features used:   54
# Cohen's kappa score         0.6053735627663444
# Accuracy score              0.9842334701113327
# Recall score                0.5748704890683993
# Precision score             0.6574286058561273
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'hpmf_mean_3', 'impundment_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'hpmf_min_2', 'skyview_max_6', 'skyview_gabor', 'slope_std_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'slope_min_6', 'hpmf_mean_6', 'skyview_non_ditch', 'impundment_median_2', 'slope_min_4', 'impundment_std_4', 'slope_median_6', 'impundment_max_6', 'hpmf_min_4', 'impundment_mean_6', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'hpmf_filter_no_streams', 'impundment_std_6', 'skyview_min_6', 'slope_mean_6', 'slope_min_2', 'skyview_median_6', 'hpmf_mean_2', 'slope_std_4', 'hpmf_std_6', 'impundment_max_4', 'slope_median_4', 'skyview_std_6', 'hpmf_gabor_no_streams', 'skyview_median_2', 'impundment_max_2', 'slope_max_4', 'skyview_median_4', 'slope_std_2', 'skyview_mean_6', 'hpmf_std_4', 'hpmf_max_6', 'skyview_std_4', 'skyview_min_4']
#
#
# Amount of features X_train: 52, X_test: 52
# Amount of features X_train: 52, X_test: 52
#
#
# Importances for experiment:
# impundment_mean_3  -  0.18146810719634276
# impundment_mean_4  -  0.11761676136319511
# hpmf_mean_4  -  0.04874445551994874
# impundment_mean_2  -  0.03371386855434673
# impundment_amplified  -  0.02518022601559728
# hpmf_mean_3  -  0.02280353123062255
# impoundment_amplified_no_streams  -  0.02233333259829745
# impundment_median_4  -  0.022209552374498256
# hpmf_median_4  -  0.021118102638230024
# skyview_max_6  -  0.017968373169950758
# hpmf_min_2  -  0.016183455794296732
# skyview_gabor  -  0.015147960029833258
# slope_std_6  -  0.014943956494590101
# hpmf_mean_6  -  0.01483531796644387
# skyview_gabor_no_streams  -  0.014802332482210682
# slope_min_6  -  0.014344878308049341
# skyview_max_4  -  0.01428564191006772
# hpmf_min_4  -  0.01388817634717742
# impundment_median_2  -  0.013454509138403063
# skyview_non_ditch  -  0.013410993687350572
# slope_min_4  -  0.012958568518289974
# impundment_max_6  -  0.01263212785751004
# slope_median_6  -  0.012453765057790514
# impundment_std_4  -  0.012359497360192281
# hpmf_gabor_no_streams  -  0.012084226532898111
# impundment_mean_6  -  0.01189658648535042
# impundment_median_6  -  0.01186657817916126
# skyview_max_2  -  0.011847767881130617
# hpmf_filter  -  0.011610307475288226
# slope_non_ditch  -  0.011309716218959638
# skyview_min_6  -  0.011276529670776676
# hpmf_filter_no_streams  -  0.011147753478089491
# hpmf_mean_2  -  0.01107066831592992
# impundment_std_6  -  0.010966985737791039
# slope_mean_6  -  0.010881392043761052
# skyview_median_6  -  0.010839609212615568
# slope_min_2  -  0.010757455869853574
# slope_std_4  -  0.010601525947708915
# hpmf_std_6  -  0.01046737395592143
# skyview_std_6  -  0.010043230859420577
# slope_median_4  -  0.009963523245582069
# impundment_max_4  -  0.0097727747598184
# skyview_median_2  -  0.009678821578774317
# impundment_max_2  -  0.009618081468452347
# slope_max_4  -  0.00959613942008862
# slope_std_2  -  0.00933421841123197
# hpmf_std_4  -  0.00928789561202734
# skyview_median_4  -  0.009273033601964424
# skyview_mean_6  -  0.009228136907540273
# hpmf_max_6  -  0.009060086945502234
# skyview_std_4  -  0.00885076605514071
# skyview_min_4  -  0.008811322515985539
#
#
# Amount of features used:   52
# Cohen's kappa score         0.6045200560203954
# Accuracy score              0.9843320419656297
# Recall score                0.5690754236544033
# Precision score             0.6630247974465996
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_mean_3', 'impoundment_amplified_no_streams', 'impundment_median_4', 'hpmf_median_4', 'skyview_max_6', 'hpmf_min_2', 'skyview_gabor', 'slope_std_6', 'hpmf_mean_6', 'skyview_gabor_no_streams', 'slope_min_6', 'skyview_max_4', 'hpmf_min_4', 'impundment_median_2', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'impundment_std_4', 'hpmf_gabor_no_streams', 'impundment_mean_6', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'skyview_min_6', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'impundment_std_6', 'slope_mean_6', 'skyview_median_6', 'slope_min_2', 'slope_std_4', 'hpmf_std_6', 'skyview_std_6', 'slope_median_4', 'impundment_max_4', 'skyview_median_2', 'impundment_max_2', 'slope_max_4', 'slope_std_2', 'hpmf_std_4', 'skyview_median_4', 'skyview_mean_6', 'hpmf_max_6']
#
#
# Amount of features X_train: 50, X_test: 50
# Amount of features X_train: 50, X_test: 50
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1682910979337549
# impundment_mean_4  -  0.12041773473172812
# hpmf_mean_4  -  0.043875781382785015
# impundment_mean_2  -  0.03661181390567743
# impundment_median_4  -  0.02741695014086681
# hpmf_mean_3  -  0.026468497835352902
# impundment_amplified  -  0.025937491385992825
# impoundment_amplified_no_streams  -  0.022505488559975993
# hpmf_median_4  -  0.022174719746839745
# skyview_max_6  -  0.018414554422258405
# hpmf_min_2  -  0.0178728084478859
# slope_std_6  -  0.015563031548596902
# skyview_gabor  -  0.01526305441124759
# skyview_gabor_no_streams  -  0.015128536145487332
# hpmf_mean_6  -  0.014937981912395268
# skyview_max_4  -  0.014859483018176727
# slope_min_6  -  0.014795800551592748
# impundment_median_2  -  0.014068980290258383
# skyview_non_ditch  -  0.013805414200177403
# slope_min_4  -  0.01326813594897779
# hpmf_min_4  -  0.013256910547320547
# impundment_max_6  -  0.013021190807662852
# slope_median_6  -  0.012808980945585309
# hpmf_mean_2  -  0.01277153443089862
# impundment_std_4  -  0.012758997916995186
# impundment_mean_6  -  0.012661351677299568
# skyview_min_6  -  0.012561765185368797
# hpmf_gabor_no_streams  -  0.012344805553103154
# impundment_median_6  -  0.012241319494233172
# skyview_max_2  -  0.012031236620535932
# hpmf_filter  -  0.011869557296139817
# slope_non_ditch  -  0.011694536148904613
# skyview_std_6  -  0.011573521236263564
# hpmf_filter_no_streams  -  0.011448188477332928
# slope_mean_6  -  0.011235542242025151
# impundment_std_6  -  0.0112021835450744
# slope_min_2  -  0.011154699515686196
# skyview_median_6  -  0.011025630874940299
# slope_std_4  -  0.010886505399465075
# hpmf_std_6  -  0.010856921513008506
# impundment_max_2  -  0.01058313643135066
# slope_max_4  -  0.010301769015645695
# slope_median_4  -  0.010193512964311941
# skyview_median_2  -  0.01003801232224293
# impundment_max_4  -  0.00995179121702972
# slope_std_2  -  0.009763750873362266
# skyview_mean_6  -  0.009711914774309943
# skyview_median_4  -  0.009547309675420428
# hpmf_std_4  -  0.009452359815649708
# hpmf_max_6  -  0.009373706962804772
#
#
# Amount of features used:   50
# Cohen's kappa score         0.6030286812691232
# Accuracy score              0.9842311777426281
# Recall score                0.5692861533058214
# Precision score             0.659384915792043
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_median_4', 'hpmf_mean_3', 'impundment_amplified', 'impoundment_amplified_no_streams', 'hpmf_median_4', 'skyview_max_6', 'hpmf_min_2', 'slope_std_6', 'skyview_gabor', 'skyview_gabor_no_streams', 'hpmf_mean_6', 'skyview_max_4', 'slope_min_6', 'impundment_median_2', 'skyview_non_ditch', 'slope_min_4', 'hpmf_min_4', 'impundment_max_6', 'slope_median_6', 'hpmf_mean_2', 'impundment_std_4', 'impundment_mean_6', 'skyview_min_6', 'hpmf_gabor_no_streams', 'impundment_median_6', 'skyview_max_2', 'hpmf_filter', 'slope_non_ditch', 'skyview_std_6', 'hpmf_filter_no_streams', 'slope_mean_6', 'impundment_std_6', 'slope_min_2', 'skyview_median_6', 'slope_std_4', 'hpmf_std_6', 'impundment_max_2', 'slope_max_4', 'slope_median_4', 'skyview_median_2', 'impundment_max_4', 'slope_std_2', 'skyview_mean_6', 'skyview_median_4']
#
#
# Amount of features X_train: 48, X_test: 48
# Amount of features X_train: 48, X_test: 48
#
#
# Importances for experiment:
# impundment_mean_3  -  0.1979047638644414
# impundment_mean_4  -  0.11583897259364032
# hpmf_mean_4  -  0.03614546584324993
# impundment_mean_2  -  0.03393183389388569
# impundment_amplified  -  0.026164782665792984
# hpmf_median_4  -  0.024629355690685466
# impoundment_amplified_no_streams  -  0.023007767903381257
# hpmf_mean_3  -  0.022120776412755654
# impundment_median_4  -  0.021739476604761228
# skyview_max_6  -  0.01900329849708927
# hpmf_min_2  -  0.01799089477483122
# hpmf_mean_6  -  0.016176857866699642
# slope_std_6  -  0.015849567157036563
# skyview_gabor  -  0.01547648032123348
# skyview_max_4  -  0.015442729941746967
# skyview_gabor_no_streams  -  0.015264630662135556
# slope_min_6  -  0.015225106286338216
# hpmf_min_4  -  0.0147148651601674
# skyview_non_ditch  -  0.01434852197270067
# slope_min_4  -  0.013685203373798822
# impundment_max_6  -  0.013396145286509856
# slope_median_6  -  0.01309432964684756
# skyview_min_6  -  0.01302941250516951
# hpmf_gabor_no_streams  -  0.012789942892719014
# impundment_median_6  -  0.01270185053227016
# impundment_std_4  -  0.012558866684214333
# impundment_median_2  -  0.012545986750929
# hpmf_std_6  -  0.01242847611731747
# skyview_max_2  -  0.012377408670374904
# hpmf_filter  -  0.0123119630974756
# impundment_mean_6  -  0.012189798100132985
# slope_non_ditch  -  0.012045052359359317
# skyview_std_6  -  0.01195377886932173
# hpmf_filter_no_streams  -  0.011806243910194308
# hpmf_mean_2  -  0.01160262533607856
# slope_mean_6  -  0.01158037005724432
# slope_min_2  -  0.011499305542185072
# impundment_std_6  -  0.0114889879533807
# skyview_median_6  -  0.01123901296972716
# slope_std_4  -  0.01115688404966025
# slope_max_4  -  0.010734100981395343
# slope_median_4  -  0.010566190383344314
# skyview_median_2  -  0.010246211294252183
# slope_std_2  -  0.010123326048785658
# impundment_max_4  -  0.010087096760413639
# impundment_max_2  -  0.010014670196708894
# skyview_mean_6  -  0.00997735699970578
# skyview_median_4  -  0.009793254517910735
#
#
# Amount of features used:   48
# Cohen's kappa score         0.602992052342515
# Accuracy score              0.984116559307399
# Recall score                0.5735007463341821
# Precision score             0.6538923594425757
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'hpmf_mean_3', 'impundment_median_4', 'skyview_max_6', 'hpmf_min_2', 'hpmf_mean_6', 'slope_std_6', 'skyview_gabor', 'skyview_max_4', 'skyview_gabor_no_streams', 'slope_min_6', 'hpmf_min_4', 'skyview_non_ditch', 'slope_min_4', 'impundment_max_6', 'slope_median_6', 'skyview_min_6', 'hpmf_gabor_no_streams', 'impundment_median_6', 'impundment_std_4', 'impundment_median_2', 'hpmf_std_6', 'skyview_max_2', 'hpmf_filter', 'impundment_mean_6', 'slope_non_ditch', 'skyview_std_6', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'slope_mean_6', 'slope_min_2', 'impundment_std_6', 'skyview_median_6', 'slope_std_4', 'slope_max_4', 'slope_median_4', 'skyview_median_2', 'slope_std_2', 'impundment_max_4', 'impundment_max_2']
#
#
# Amount of features X_train: 46, X_test: 46
# Amount of features X_train: 46, X_test: 46
#
#
# Importances for experiment:
# impundment_mean_3  -  0.19842094150004547
# impundment_mean_4  -  0.11291359108294285
# impundment_mean_2  -  0.03743755471596702
# hpmf_mean_4  -  0.035656230499047634
# impundment_amplified  -  0.02656109707602361
# hpmf_median_4  -  0.025814817821448142
# hpmf_mean_3  -  0.024363241569782444
# impoundment_amplified_no_streams  -  0.02325202379590846
# impundment_median_4  -  0.0205529559928428
# skyview_max_6  -  0.01984810165390247
# slope_std_6  -  0.016327010110045198
# skyview_max_4  -  0.01611827359917222
# hpmf_mean_6  -  0.016085237058501813
# hpmf_min_2  -  0.015717859194827564
# skyview_gabor  -  0.015704109427198153
# skyview_gabor_no_streams  -  0.01566758612885173
# slope_min_6  -  0.015604198026636162
# hpmf_min_4  -  0.015316175036039575
# skyview_non_ditch  -  0.014779953738131301
# skyview_median_6  -  0.014122801598028228
# slope_min_4  -  0.014033348250842254
# impundment_median_2  -  0.01392323594027749
# impundment_max_6  -  0.013703308881615466
# skyview_min_6  -  0.01369720655489676
# slope_median_6  -  0.013635446941111143
# impundment_std_4  -  0.013352510264572844
# skyview_max_2  -  0.013286600256968267
# hpmf_gabor_no_streams  -  0.013128813478894084
# impundment_median_6  -  0.01307751962106471
# hpmf_std_6  -  0.012862982423428551
# hpmf_filter  -  0.012626905253141887
# skyview_std_6  -  0.012567787659843094
# impundment_mean_6  -  0.012430886784885296
# slope_non_ditch  -  0.012168600793400035
# slope_mean_6  -  0.012104896029221414
# hpmf_filter_no_streams  -  0.012026582188960574
# slope_min_2  -  0.011788501336927562
# skyview_median_2  -  0.011751766841277784
# impundment_std_6  -  0.01161019971330767
# slope_std_4  -  0.011487140729598416
# slope_median_4  -  0.011067847477550456
# slope_max_4  -  0.011022683524501524
# impundment_max_2  -  0.010865472916173242
# hpmf_mean_2  -  0.010740518044858163
# slope_std_2  -  0.010492154576004362
# impundment_max_4  -  0.010283323891334174
#
#
# Amount of features used:   46
# Cohen's kappa score         0.5999635967817281
# Accuracy score              0.9840936356203531
# Recall score                0.567073491965932
# Precision score             0.6553823672674135
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'impundment_mean_2', 'hpmf_mean_4', 'impundment_amplified', 'hpmf_median_4', 'hpmf_mean_3', 'impoundment_amplified_no_streams', 'impundment_median_4', 'skyview_max_6', 'slope_std_6', 'skyview_max_4', 'hpmf_mean_6', 'hpmf_min_2', 'skyview_gabor', 'skyview_gabor_no_streams', 'slope_min_6', 'hpmf_min_4', 'skyview_non_ditch', 'skyview_median_6', 'slope_min_4', 'impundment_median_2', 'impundment_max_6', 'skyview_min_6', 'slope_median_6', 'impundment_std_4', 'skyview_max_2', 'hpmf_gabor_no_streams', 'impundment_median_6', 'hpmf_std_6', 'hpmf_filter', 'skyview_std_6', 'impundment_mean_6', 'slope_non_ditch', 'slope_mean_6', 'hpmf_filter_no_streams', 'slope_min_2', 'skyview_median_2', 'impundment_std_6', 'slope_std_4', 'slope_median_4', 'slope_max_4', 'impundment_max_2', 'hpmf_mean_2']
#
#
# Amount of features X_train: 44, X_test: 44
# Amount of features X_train: 44, X_test: 44
#
#
# Importances for experiment:
# impundment_mean_3  -  0.20203600862412074
# impundment_mean_4  -  0.12975203856895207
# hpmf_mean_4  -  0.03277906161957029
# impundment_mean_2  -  0.029951033312754526
# impundment_amplified  -  0.027279548386591343
# hpmf_median_4  -  0.027238933243226973
# impoundment_amplified_no_streams  -  0.023411110050214037
# skyview_max_6  -  0.020478420865400603
# hpmf_mean_3  -  0.02037289820473004
# slope_std_6  -  0.017066038332630276
# hpmf_mean_6  -  0.016553116505182368
# skyview_max_4  -  0.016373849125244727
# slope_min_6  -  0.016064916286165184
# skyview_gabor  -  0.016015496080734423
# impundment_median_4  -  0.01587569137643472
# hpmf_min_4  -  0.015860044490933093
# skyview_gabor_no_streams  -  0.015811738596344622
# skyview_non_ditch  -  0.015273388783363893
# impundment_max_6  -  0.015215407840730624
# hpmf_min_2  -  0.015030650426831042
# skyview_median_6  -  0.014598925810402912
# slope_min_4  -  0.014358840623078151
# impundment_median_2  -  0.014340714856284631
# skyview_min_6  -  0.014177028400117048
# slope_median_6  -  0.014088755834593734
# impundment_std_4  -  0.013781984985805455
# skyview_max_2  -  0.013598413880631818
# hpmf_gabor_no_streams  -  0.01350172770976003
# impundment_median_6  -  0.013410932247269485
# hpmf_std_6  -  0.013386738686934404
# impundment_mean_6  -  0.013151480164299933
# skyview_std_6  -  0.013068672066509416
# hpmf_filter  -  0.01299278688933999
# slope_std_4  -  0.012642478795657372
# slope_mean_6  -  0.012531018131974714
# slope_min_2  -  0.012431760905994384
# slope_non_ditch  -  0.012395371610491212
# skyview_median_2  -  0.012353281109805596
# impundment_std_6  -  0.012312118482746754
# hpmf_filter_no_streams  -  0.012294157933956355
# hpmf_mean_2  -  0.011620450290053281
# slope_median_4  -  0.011522763186611737
# slope_max_4  -  0.01151582884688514
# impundment_max_2  -  0.011484377830640907
#
#
# Amount of features used:   44
# Cohen's kappa score         0.5965187543690789
# Accuracy score              0.9839973561347607
# Recall score                0.5624374396347352
# Precision score             0.6536860151849131
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'skyview_max_6', 'hpmf_mean_3', 'slope_std_6', 'hpmf_mean_6', 'skyview_max_4', 'slope_min_6', 'skyview_gabor', 'impundment_median_4', 'hpmf_min_4', 'skyview_gabor_no_streams', 'skyview_non_ditch', 'impundment_max_6', 'hpmf_min_2', 'skyview_median_6', 'slope_min_4', 'impundment_median_2', 'skyview_min_6', 'slope_median_6', 'impundment_std_4', 'skyview_max_2', 'hpmf_gabor_no_streams', 'impundment_median_6', 'hpmf_std_6', 'impundment_mean_6', 'skyview_std_6', 'hpmf_filter', 'slope_std_4', 'slope_mean_6', 'slope_min_2', 'slope_non_ditch', 'skyview_median_2', 'impundment_std_6', 'hpmf_filter_no_streams', 'hpmf_mean_2', 'slope_median_4']
#
#
# Amount of features X_train: 42, X_test: 42
# Amount of features X_train: 42, X_test: 42
#
#
# Importances for experiment:
# impundment_mean_3  -  0.2207517879504194
# impundment_mean_4  -  0.11252076728693167
# hpmf_mean_4  -  0.032807548083308366
# impundment_mean_2  -  0.029852011612870058
# impundment_amplified  -  0.0278435210622925
# hpmf_median_4  -  0.026184477776843774
# impoundment_amplified_no_streams  -  0.023808292383272495
# hpmf_mean_3  -  0.022581436991321174
# skyview_max_6  -  0.021124287601307162
# slope_std_6  -  0.018184105121019322
# impundment_median_4  -  0.0176681190972311
# hpmf_min_2  -  0.0171525707321614
# hpmf_mean_6  -  0.016986768687357295
# skyview_max_4  -  0.01676652223951279
# slope_min_6  -  0.016745446375897935
# skyview_gabor  -  0.016420746953591518
# hpmf_min_4  -  0.016076157265512123
# skyview_gabor_no_streams  -  0.016070119793520507
# impundment_max_6  -  0.01585965097838121
# skyview_non_ditch  -  0.015792160792883547
# skyview_median_6  -  0.015151561484131661
# impundment_std_4  -  0.01482504501089682
# skyview_min_6  -  0.014811254007126216
# slope_min_4  -  0.014779392856122928
# slope_median_6  -  0.014526292296683927
# slope_std_4  -  0.014443067651578538
# impundment_median_2  -  0.014282079027855828
# skyview_max_2  -  0.014136466637134717
# impundment_median_6  -  0.01405728496504232
# hpmf_std_6  -  0.013941068275414161
# hpmf_gabor_no_streams  -  0.013915462972663955
# skyview_std_6  -  0.013753100003474704
# hpmf_filter  -  0.013339631772595142
# impundment_mean_6  -  0.013208821539835738
# slope_mean_6  -  0.013174466568874731
# slope_min_2  -  0.012890843606471615
# skyview_median_2  -  0.012748125260789915
# hpmf_filter_no_streams  -  0.01265477855652989
# impundment_std_6  -  0.012648702159513015
# slope_non_ditch  -  0.01256071221362266
# slope_median_4  -  0.01203913362353544
# hpmf_mean_2  -  0.010916210724470663
#
#
# Amount of features used:   42
# Cohen's kappa score         0.6026461263140878
# Accuracy score              0.9840661271958981
# Recall score                0.5745543945912723
# Precision score             0.6518049246951948
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'hpmf_mean_3', 'skyview_max_6', 'slope_std_6', 'impundment_median_4', 'hpmf_min_2', 'hpmf_mean_6', 'skyview_max_4', 'slope_min_6', 'skyview_gabor', 'hpmf_min_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'skyview_non_ditch', 'skyview_median_6', 'impundment_std_4', 'skyview_min_6', 'slope_min_4', 'slope_median_6', 'slope_std_4', 'impundment_median_2', 'skyview_max_2', 'impundment_median_6', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'hpmf_filter', 'impundment_mean_6', 'slope_mean_6', 'slope_min_2', 'skyview_median_2', 'hpmf_filter_no_streams', 'impundment_std_6', 'slope_non_ditch']
#
#
# Amount of features X_train: 40, X_test: 40
# Amount of features X_train: 40, X_test: 40
#
#
# Importances for experiment:
# impundment_mean_3  -  0.22896388660800415
# impundment_mean_4  -  0.12067830449958677
# hpmf_mean_4  -  0.03087209133495473
# hpmf_median_4  -  0.02904295802395057
# impundment_amplified  -  0.028554710591419927
# impundment_mean_2  -  0.027793361500356766
# impoundment_amplified_no_streams  -  0.024053401421274843
# skyview_max_6  -  0.021688644646691013
# hpmf_mean_3  -  0.019749141951942748
# slope_std_6  -  0.018641314543063083
# hpmf_mean_6  -  0.01731753397321217
# slope_min_6  -  0.01727442919149355
# skyview_max_4  -  0.017222097506786768
# hpmf_min_4  -  0.017217056054144694
# hpmf_min_2  -  0.017122200668545896
# skyview_gabor  -  0.01662550185718649
# skyview_gabor_no_streams  -  0.01654648110482672
# slope_median_6  -  0.016450134136257573
# impundment_max_6  -  0.01644520411053072
# skyview_non_ditch  -  0.016329681473494406
# skyview_median_6  -  0.015602910735118857
# skyview_min_6  -  0.015262991725552956
# slope_min_4  -  0.015254894194743428
# slope_std_4  -  0.014935884051844083
# impundment_median_2  -  0.014851332743316917
# impundment_median_6  -  0.014574309858811318
# skyview_max_2  -  0.01441942687637305
# hpmf_std_6  -  0.014416462569195293
# hpmf_gabor_no_streams  -  0.014257962000611076
# slope_mean_6  -  0.014222641545310236
# impundment_std_4  -  0.014178131643953798
# skyview_std_6  -  0.014103304873540487
# hpmf_filter  -  0.013715413329789334
# slope_min_2  -  0.01361017008112458
# impundment_mean_6  -  0.013479782243372342
# skyview_median_2  -  0.01336109425008079
# hpmf_filter_no_streams  -  0.01294507072567071
# impundment_std_6  -  0.012943318218855113
# slope_non_ditch  -  0.01277186040715456
# impundment_median_4  -  0.012504902727857462
#
#
# Amount of features used:   40
# Cohen's kappa score         0.6029024672319632
# Accuracy score              0.9841922074746502
# Recall score                0.5704451663886206
# Precision score             0.6575974735819264
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'hpmf_median_4', 'impundment_amplified', 'impundment_mean_2', 'impoundment_amplified_no_streams', 'skyview_max_6', 'hpmf_mean_3', 'slope_std_6', 'hpmf_mean_6', 'slope_min_6', 'skyview_max_4', 'hpmf_min_4', 'hpmf_min_2', 'skyview_gabor', 'skyview_gabor_no_streams', 'slope_median_6', 'impundment_max_6', 'skyview_non_ditch', 'skyview_median_6', 'skyview_min_6', 'slope_min_4', 'slope_std_4', 'impundment_median_2', 'impundment_median_6', 'skyview_max_2', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'slope_mean_6', 'impundment_std_4', 'skyview_std_6', 'hpmf_filter', 'slope_min_2', 'impundment_mean_6', 'skyview_median_2', 'hpmf_filter_no_streams', 'impundment_std_6']
#
#
# Amount of features X_train: 38, X_test: 38
# Amount of features X_train: 38, X_test: 38
#
#
# Importances for experiment:
# impundment_mean_3  -  0.23286195828753287
# impundment_mean_4  -  0.10925999599297023
# hpmf_mean_4  -  0.03502829722429293
# impundment_mean_2  -  0.03357965114605562
# hpmf_median_4  -  0.02938447327240746
# impundment_amplified  -  0.028570747040474367
# impoundment_amplified_no_streams  -  0.024453064132609913
# skyview_max_6  -  0.022749356725010127
# hpmf_mean_3  -  0.02263644900065593
# skyview_non_ditch  -  0.019649664051513825
# slope_std_6  -  0.01932343305265624
# slope_min_6  -  0.018333728039450818
# hpmf_mean_6  -  0.018255603342542143
# slope_median_6  -  0.01782961943681584
# skyview_max_4  -  0.017520463364069858
# skyview_gabor  -  0.017218137007009762
# skyview_gabor_no_streams  -  0.017157704434377946
# hpmf_min_2  -  0.017060868710743856
# impundment_max_6  -  0.016872355350136634
# hpmf_min_4  -  0.01669027005599907
# slope_min_4  -  0.01619357564491605
# impundment_median_2  -  0.01601417417628731
# skyview_median_6  -  0.016004896621141386
# skyview_min_6  -  0.015906726306208752
# impundment_median_6  -  0.015823241256828373
# slope_mean_6  -  0.015120121045416195
# slope_std_4  -  0.0151172562585833
# hpmf_std_6  -  0.014935082359210103
# skyview_max_2  -  0.014828325795570606
# hpmf_gabor_no_streams  -  0.014649339333061721
# impundment_std_4  -  0.014615572890631708
# skyview_std_6  -  0.014511843753161729
# slope_min_2  -  0.014090450667366994
# hpmf_filter  -  0.014008916438292338
# impundment_mean_6  -  0.013700853855595111
# skyview_median_2  -  0.013574896550753408
# impundment_std_6  -  0.013289329945236072
# hpmf_filter_no_streams  -  0.013179557434413475
#
#
# Amount of features used:   38
# Cohen's kappa score         0.6028684701359162
# Accuracy score              0.9843641351274939
# Recall score                0.5639125471946616
# Precision score             0.666168782673637
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2', 'hpmf_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'skyview_max_6', 'hpmf_mean_3', 'skyview_non_ditch', 'slope_std_6', 'slope_min_6', 'hpmf_mean_6', 'slope_median_6', 'skyview_max_4', 'skyview_gabor', 'skyview_gabor_no_streams', 'hpmf_min_2', 'impundment_max_6', 'hpmf_min_4', 'slope_min_4', 'impundment_median_2', 'skyview_median_6', 'skyview_min_6', 'impundment_median_6', 'slope_mean_6', 'slope_std_4', 'hpmf_std_6', 'skyview_max_2', 'hpmf_gabor_no_streams', 'impundment_std_4', 'skyview_std_6', 'slope_min_2', 'hpmf_filter', 'impundment_mean_6', 'skyview_median_2']
#
#
# Amount of features X_train: 36, X_test: 36
# Amount of features X_train: 36, X_test: 36
#
#
# Importances for experiment:
# impundment_mean_3  -  0.26014951960062693
# impundment_mean_4  -  0.10999987237192903
# hpmf_median_4  -  0.03115263441009271
# impundment_amplified  -  0.0293372296503392
# impoundment_amplified_no_streams  -  0.025220307775611274
# skyview_max_6  -  0.02329149774446162
# hpmf_mean_4  -  0.02272263412817622
# impundment_mean_2  -  0.022343077153411033
# skyview_non_ditch  -  0.02020451513367644
# hpmf_filter  -  0.02015704635942111
# slope_std_6  -  0.019852840755919695
# impundment_max_6  -  0.01961889948087056
# slope_min_6  -  0.018805704301704196
# hpmf_mean_6  -  0.018680438799299724
# slope_median_6  -  0.018265310298518637
# skyview_max_4  -  0.017961551045769138
# hpmf_min_2  -  0.017766198947579
# skyview_gabor_no_streams  -  0.017760529978341905
# hpmf_mean_3  -  0.01756766153454977
# hpmf_min_4  -  0.017545289425646843
# skyview_gabor  -  0.017398808422785808
# impundment_median_2  -  0.016877198253439342
# slope_min_4  -  0.016555177863619413
# skyview_median_6  -  0.016454900161869738
# impundment_median_6  -  0.016453858406436074
# skyview_min_6  -  0.016422360204402277
# impundment_mean_6  -  0.015837718057236924
# slope_mean_6  -  0.015450203219881881
# hpmf_std_6  -  0.015447198643050195
# slope_std_4  -  0.015420155963494593
# hpmf_gabor_no_streams  -  0.01536480620993861
# impundment_std_4  -  0.015236720001917005
# skyview_max_2  -  0.01517622409035826
# skyview_std_6  -  0.015000600257072269
# slope_min_2  -  0.014579885035534226
# skyview_median_2  -  0.01392142631301825
#
#
# Amount of features used:   36
# Cohen's kappa score         0.599055400345867
# Accuracy score              0.9842518090609693
# Recall score                0.5590657652120468
# Precision score             0.6639969966211988
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'skyview_max_6', 'hpmf_mean_4', 'impundment_mean_2', 'skyview_non_ditch', 'hpmf_filter', 'slope_std_6', 'impundment_max_6', 'slope_min_6', 'hpmf_mean_6', 'slope_median_6', 'skyview_max_4', 'hpmf_min_2', 'skyview_gabor_no_streams', 'hpmf_mean_3', 'hpmf_min_4', 'skyview_gabor', 'impundment_median_2', 'slope_min_4', 'skyview_median_6', 'impundment_median_6', 'skyview_min_6', 'impundment_mean_6', 'slope_mean_6', 'hpmf_std_6', 'slope_std_4', 'hpmf_gabor_no_streams', 'impundment_std_4', 'skyview_max_2', 'skyview_std_6']
#
#
# Amount of features X_train: 34, X_test: 34
# Amount of features X_train: 34, X_test: 34
#
#
# Importances for experiment:
# impundment_mean_3  -  0.24567236441926135
# impundment_mean_4  -  0.11740618410522768
# hpmf_median_4  -  0.03138315776972693
# impundment_amplified  -  0.030285476842903433
# hpmf_mean_4  -  0.02816655148912997
# impundment_mean_2  -  0.02631987370023102
# impoundment_amplified_no_streams  -  0.02563130987318763
# skyview_max_6  -  0.024351688013529486
# hpmf_filter  -  0.021237594956471026
# skyview_non_ditch  -  0.0211870289571448
# slope_std_6  -  0.020646474926969555
# impundment_max_6  -  0.02053656071551991
# hpmf_mean_3  -  0.02011622582835096
# slope_min_6  -  0.019847171457677774
# slope_median_6  -  0.0193905965114751
# hpmf_mean_6  -  0.019225161710226465
# skyview_max_4  -  0.018722145121280592
# skyview_median_6  -  0.018615922425471082
# skyview_gabor_no_streams  -  0.018539796663310383
# skyview_gabor  -  0.018168171987550878
# hpmf_min_4  -  0.01813004730934133
# slope_min_4  -  0.018039012454402717
# skyview_min_6  -  0.01737869646596745
# impundment_median_6  -  0.017238259243693647
# skyview_max_2  -  0.01709599569784474
# hpmf_min_2  -  0.016686287318492712
# impundment_mean_6  -  0.016623916765691603
# slope_std_4  -  0.016547925538064216
# impundment_median_2  -  0.016495735097808824
# slope_mean_6  -  0.016297874604523536
# hpmf_std_6  -  0.016283841946790813
# impundment_std_4  -  0.016012087551696266
# skyview_std_6  -  0.015861575848147964
# hpmf_gabor_no_streams  -  0.015859286682888225
#
#
# Amount of features used:   34
# Cohen's kappa score         0.5999284998032481
# Accuracy score              0.9842334701113327
# Recall score                0.5618052506804811
# Precision score             0.6622779778909452
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'hpmf_mean_4', 'impundment_mean_2', 'impoundment_amplified_no_streams', 'skyview_max_6', 'hpmf_filter', 'skyview_non_ditch', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_3', 'slope_min_6', 'slope_median_6', 'hpmf_mean_6', 'skyview_max_4', 'skyview_median_6', 'skyview_gabor_no_streams', 'skyview_gabor', 'hpmf_min_4', 'slope_min_4', 'skyview_min_6', 'impundment_median_6', 'skyview_max_2', 'hpmf_min_2', 'impundment_mean_6', 'slope_std_4', 'impundment_median_2', 'slope_mean_6', 'hpmf_std_6', 'impundment_std_4']
# Amount of features X_train: 32, X_test: 32
# Amount of features X_train: 32, X_test: 32
#
#
# Importances for experiment:
# impundment_mean_3  -  0.30333097095313954
# impundment_mean_4  -  0.07987929172708863
# hpmf_median_4  -  0.033858728438593555
# impundment_amplified  -  0.03160370002356851
# impoundment_amplified_no_streams  -  0.026258510997367666
# skyview_max_6  -  0.0256187038885613
# skyview_non_ditch  -  0.022404665198738877
# hpmf_filter  -  0.02239251367416987
# impundment_mean_2  -  0.02224815514425965
# slope_std_6  -  0.022018910654939144
# impundment_max_6  -  0.02166811112403384
# hpmf_mean_6  -  0.021006091313490665
# skyview_min_6  -  0.020969152854043775
# slope_min_6  -  0.02066555744164135
# slope_median_6  -  0.020235334308618496
# skyview_gabor_no_streams  -  0.01978148185691334
# skyview_max_4  -  0.01960035124733274
# hpmf_mean_4  -  0.019475427422090623
# skyview_median_6  -  0.01934198856069541
# hpmf_min_4  -  0.01894694948232018
# slope_min_4  -  0.018784750000795363
# skyview_gabor  -  0.018296020732389978
# skyview_max_2  -  0.01829283982676546
# impundment_median_6  -  0.018171548527883413
# hpmf_std_6  -  0.017504012059192144
# slope_std_4  -  0.017411247473981643
# impundment_mean_6  -  0.01727557504042915
# hpmf_min_2  -  0.017255160244131686
# slope_mean_6  -  0.017031458860224866
# impundment_std_4  -  0.016646997083945066
# impundment_median_2  -  0.01612053818124973
# hpmf_mean_3  -  0.015905255657404402
#
#
# Amount of features used:   32
# Cohen's kappa score         0.6025302308225611
# Accuracy score              0.9842976564350611
# Recall score                0.5655983844060058
# Precision score             0.6631253860407659
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_non_ditch', 'hpmf_filter', 'impundment_mean_2', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_6', 'skyview_min_6', 'slope_min_6', 'slope_median_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'hpmf_mean_4', 'skyview_median_6', 'hpmf_min_4', 'slope_min_4', 'skyview_gabor', 'skyview_max_2', 'impundment_median_6', 'hpmf_std_6', 'slope_std_4', 'impundment_mean_6', 'hpmf_min_2', 'slope_mean_6', 'impundment_std_4']
#
#
# Amount of features X_train: 30, X_test: 30
# Amount of features X_train: 30, X_test: 30
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3044545087715057
# impundment_mean_4  -  0.08096936707104063
# hpmf_median_4  -  0.03780765766355358
# impundment_amplified  -  0.03200924004739092
# hpmf_mean_4  -  0.027199578972953605
# impoundment_amplified_no_streams  -  0.026710614934202077
# impundment_mean_2  -  0.026447675230518525
# skyview_max_6  -  0.026417167181927804
# hpmf_filter  -  0.023317750449841017
# skyview_non_ditch  -  0.02325387754685035
# slope_std_6  -  0.02289745796032407
# impundment_max_6  -  0.022577993459506396
# hpmf_mean_6  -  0.021891030712211268
# skyview_min_6  -  0.021664993796787255
# slope_min_6  -  0.02136990828576139
# slope_median_6  -  0.0207804510638742
# skyview_gabor_no_streams  -  0.020224959307111046
# skyview_max_4  -  0.020111073507883295
# skyview_median_6  -  0.019954988021972042
# slope_min_4  -  0.019442119403835105
# impundment_median_6  -  0.018969266561103267
# hpmf_min_4  -  0.018705457751840786
# skyview_max_2  -  0.018654165600178615
# skyview_gabor  -  0.018540979080588767
# hpmf_std_6  -  0.018144677778897354
# slope_std_4  -  0.017923224048670854
# impundment_mean_6  -  0.017774828265317393
# hpmf_min_2  -  0.017734571430590568
# slope_mean_6  -  0.017311439335223985
# impundment_std_4  -  0.01673897675853818
#
#
# Amount of features used:   30
# Cohen's kappa score         0.5967574032346911
# Accuracy score              0.9840271569279203
# Recall score                0.5619106155061901
# Precision score             0.6549183347660568
#
# ------------------------------------------------------

# %%
most_important_features = ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified',
                           'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_non_ditch', 'hpmf_filter',
                           'impundment_mean_2', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_6', 'skyview_min_6',
                           'slope_min_6', 'slope_median_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'hpmf_mean_4',
                           'skyview_median_6', 'hpmf_min_4', 'slope_min_4', 'skyview_gabor', 'skyview_max_2',
                           'impundment_median_6', 'hpmf_std_6', 'slope_std_4', 'impundment_mean_6', 'hpmf_min_2',
                           'slope_mean_6', 'impundment_std_4']
for num_features in [30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]:
    
    most_important_features = most_important_features[:num_features]
    print(f"Features used in experiment:\n{most_important_features}")
    print("\n")
    feature_importances = {i:0 for i in most_important_features}
    y_test_all = []
    pred_all = []
    
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        _max_features = 25 if num_features > 25 else num_features
        clf = RandomForestClassifier(n_estimators=200, class_weight="balanced", max_features=_max_features,
                                     random_state=42, n_jobs=-1)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")

        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(np.array(y_test).reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

        importances = clf.feature_importances_

        
        for i, importance in enumerate(importances):
            feature_importances[most_important_features[i]] += importance
        
    for importance_name in most_important_features:
        feature_importances[importance_name] /= 2
    
    
    
    most_important_features = list(dict(sorted(feature_importances.items(),
                                               key=operator.itemgetter(1),reverse=True)).keys())

    print("\n")
    print(f"Importances for experiment:")
    for key in most_important_features:
        print(key, " - ", feature_importances[key])
    print("\n")
    print(f"Amount of features used:   {num_features}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
# Out:
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'impoundment_amplified_no_streams', 'skyview_max_6', 'skyview_non_ditch', 'hpmf_filter', 'impundment_mean_2', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_6', 'skyview_min_6', 'slope_min_6', 'slope_median_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'hpmf_mean_4', 'skyview_median_6', 'hpmf_min_4', 'slope_min_4', 'skyview_gabor', 'skyview_max_2', 'impundment_median_6', 'hpmf_std_6', 'slope_std_4', 'impundment_mean_6', 'hpmf_min_2', 'slope_mean_6', 'impundment_std_4']
#
#
# Amount of features X_train: 30, X_test: 30
# Amount of features X_train: 30, X_test: 30
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3044545087715057
# impundment_mean_4  -  0.08096936707104063
# hpmf_median_4  -  0.03780765766355358
# impundment_amplified  -  0.03200924004739092
# hpmf_mean_4  -  0.027199578972953605
# impoundment_amplified_no_streams  -  0.026710614934202077
# impundment_mean_2  -  0.026447675230518525
# skyview_max_6  -  0.026417167181927804
# hpmf_filter  -  0.023317750449841017
# skyview_non_ditch  -  0.02325387754685035
# slope_std_6  -  0.02289745796032407
# impundment_max_6  -  0.022577993459506396
# hpmf_mean_6  -  0.021891030712211268
# skyview_min_6  -  0.021664993796787255
# slope_min_6  -  0.02136990828576139
# slope_median_6  -  0.0207804510638742
# skyview_gabor_no_streams  -  0.020224959307111046
# skyview_max_4  -  0.020111073507883295
# skyview_median_6  -  0.019954988021972042
# slope_min_4  -  0.019442119403835105
# impundment_median_6  -  0.018969266561103267
# hpmf_min_4  -  0.018705457751840786
# skyview_max_2  -  0.018654165600178615
# skyview_gabor  -  0.018540979080588767
# hpmf_std_6  -  0.018144677778897354
# slope_std_4  -  0.017923224048670854
# impundment_mean_6  -  0.017774828265317393
# hpmf_min_2  -  0.017734571430590568
# slope_mean_6  -  0.017311439335223985
# impundment_std_4  -  0.01673897675853818
#
#
# Amount of features used:   30
# Cohen's kappa score         0.5967574032346911
# Accuracy score              0.9840271569279203
# Recall score                0.5619106155061901
# Precision score             0.6549183347660568
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'hpmf_mean_4', 'impoundment_amplified_no_streams', 'impundment_mean_2', 'skyview_max_6', 'hpmf_filter', 'skyview_non_ditch', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_6', 'skyview_min_6', 'slope_min_6', 'slope_median_6', 'skyview_gabor_no_streams', 'skyview_max_4', 'skyview_median_6', 'slope_min_4', 'impundment_median_6', 'hpmf_min_4', 'skyview_max_2', 'skyview_gabor', 'hpmf_std_6', 'slope_std_4', 'impundment_mean_6', 'hpmf_min_2']
#
#
# Amount of features X_train: 28, X_test: 28
# Amount of features X_train: 28, X_test: 28
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3320031420078279
# impundment_mean_4  -  0.06910038021407337
# hpmf_median_4  -  0.04006890126059297
# impundment_amplified  -  0.032736181205603704
# skyview_max_6  -  0.027575648717455062
# impoundment_amplified_no_streams  -  0.02710108153662205
# slope_median_6  -  0.0256163624761711
# hpmf_filter  -  0.024568874504289656
# slope_std_6  -  0.02450488476407119
# impundment_max_6  -  0.024416093464829293
# skyview_non_ditch  -  0.024306149423702284
# impundment_mean_2  -  0.023319101949024562
# skyview_min_6  -  0.022926507159074794
# hpmf_mean_6  -  0.022740492536303024
# slope_min_6  -  0.02247694993387952
# skyview_median_6  -  0.021053938958224157
# skyview_max_4  -  0.020892575278232614
# skyview_gabor_no_streams  -  0.020567327051470533
# slope_min_4  -  0.0204928644640116
# impundment_median_6  -  0.020229551247879472
# hpmf_mean_4  -  0.01972793505384533
# hpmf_min_4  -  0.019546245634788607
# skyview_max_2  -  0.019537454626759383
# hpmf_std_6  -  0.019422846352998555
# slope_std_4  -  0.019245402161805956
# skyview_gabor  -  0.018988260300264997
# impundment_mean_6  -  0.018737835738557203
# hpmf_min_2  -  0.018097011977641225
#
#
# Amount of features used:   28
# Cohen's kappa score         0.5993512870610691
# Accuracy score              0.9841624066814907
# Recall score                0.5630696285889893
# Precision score             0.6592647421662966
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'skyview_max_6', 'impoundment_amplified_no_streams', 'slope_median_6', 'hpmf_filter', 'slope_std_6', 'impundment_max_6', 'skyview_non_ditch', 'impundment_mean_2', 'skyview_min_6', 'hpmf_mean_6', 'slope_min_6', 'skyview_median_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'slope_min_4', 'impundment_median_6', 'hpmf_mean_4', 'hpmf_min_4', 'skyview_max_2', 'hpmf_std_6', 'slope_std_4', 'skyview_gabor']
#
#
# Amount of features X_train: 26, X_test: 26
# Amount of features X_train: 26, X_test: 26
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3503309948595964
# impundment_mean_4  -  0.05707084989749488
# hpmf_median_4  -  0.041665469568213175
# impundment_amplified  -  0.03417433382473108
# skyview_max_6  -  0.0291208098880643
# impundment_max_6  -  0.02844931271942904
# impoundment_amplified_no_streams  -  0.027727454463886726
# slope_median_6  -  0.026816553551696928
# hpmf_filter  -  0.026015445898505643
# slope_std_6  -  0.025740573806437853
# skyview_non_ditch  -  0.025404966971584925
# hpmf_min_4  -  0.023934956111219367
# skyview_min_6  -  0.023917871393561423
# hpmf_mean_6  -  0.02376111361760605
# slope_min_6  -  0.023699950307133635
# skyview_median_6  -  0.022624030848147243
# impundment_mean_2  -  0.02243798149553374
# impundment_median_6  -  0.02217162502693191
# skyview_max_4  -  0.02134409339883854
# skyview_gabor_no_streams  -  0.02119791869066413
# hpmf_mean_4  -  0.02105565047048622
# slope_min_4  -  0.0209461134645257
# hpmf_std_6  -  0.020325264165977214
# slope_std_4  -  0.020240966647222296
# skyview_gabor  -  0.02003496152931548
# skyview_max_2  -  0.01979073738319611
#
#
# Amount of features used:   26
# Cohen's kappa score         0.5984927844064791
# Accuracy score              0.9838414750628491
# Recall score                0.572868557379928
# Precision score             0.6448055028462998
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'skyview_max_6', 'impundment_max_6', 'impoundment_amplified_no_streams', 'slope_median_6', 'hpmf_filter', 'slope_std_6', 'skyview_non_ditch', 'hpmf_min_4', 'skyview_min_6', 'hpmf_mean_6', 'slope_min_6', 'skyview_median_6', 'impundment_mean_2', 'impundment_median_6', 'skyview_max_4', 'skyview_gabor_no_streams', 'hpmf_mean_4', 'slope_min_4', 'hpmf_std_6', 'slope_std_4']
#
#
# Amount of features X_train: 24, X_test: 24
# Amount of features X_train: 24, X_test: 24
#
#
# Importances for experiment:
# impundment_mean_3  -  0.36456101488184084
# impundment_mean_4  -  0.04630928309687864
# hpmf_median_4  -  0.042892765225354554
# impundment_amplified  -  0.03466813607924302
# skyview_gabor_no_streams  -  0.034407019853816424
# skyview_max_6  -  0.030634606554217854
# impundment_max_6  -  0.029902201984988247
# slope_median_6  -  0.028128538282472856
# impoundment_amplified_no_streams  -  0.02791342065897757
# hpmf_filter  -  0.027330304761695436
# slope_std_6  -  0.026971243745131962
# skyview_non_ditch  -  0.026925925472739587
# skyview_median_6  -  0.025078015293538272
# skyview_min_6  -  0.024868405391298018
# skyview_max_4  -  0.024778542292051044
# hpmf_min_4  -  0.02477277498352249
# slope_min_6  -  0.02460414233437601
# hpmf_mean_6  -  0.024562666271353523
# impundment_median_6  -  0.02325710907473938
# impundment_mean_2  -  0.022628572060655404
# slope_min_4  -  0.02160198712823081
# slope_std_4  -  0.0214864834176725
# hpmf_std_6  -  0.02122069878906234
# hpmf_mean_4  -  0.020496142366143347
#
#
# Amount of features used:   24
# Cohen's kappa score         0.5961334386251411
# Accuracy score              0.9836030687175725
# Recall score                0.5759241373254895
# Precision score             0.636025133814289
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'skyview_gabor_no_streams', 'skyview_max_6', 'impundment_max_6', 'slope_median_6', 'impoundment_amplified_no_streams', 'hpmf_filter', 'slope_std_6', 'skyview_non_ditch', 'skyview_median_6', 'skyview_min_6', 'skyview_max_4', 'hpmf_min_4', 'slope_min_6', 'hpmf_mean_6', 'impundment_median_6', 'impundment_mean_2', 'slope_min_4', 'slope_std_4']
# Amount of features X_train: 22, X_test: 22
# Amount of features X_train: 22, X_test: 22
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3661024998568824
# impundment_mean_4  -  0.04808080710710179
# hpmf_median_4  -  0.046243122126269624
# impundment_amplified  -  0.036131605079245906
# skyview_gabor_no_streams  -  0.03550554496503846
# skyview_max_6  -  0.03300648633188505
# impundment_max_6  -  0.03216149952154544
# hpmf_mean_6  -  0.030251528927090765
# slope_median_6  -  0.0301935203470806
# hpmf_filter  -  0.029397876238147255
# impoundment_amplified_no_streams  -  0.029080839097043135
# slope_std_6  -  0.028748274048098453
# skyview_non_ditch  -  0.02829470819490504
# hpmf_min_4  -  0.027382680340581396
# skyview_min_6  -  0.026817355286710767
# skyview_median_6  -  0.02636100059224395
# slope_min_6  -  0.025975206878105395
# skyview_max_4  -  0.025800441670476452
# impundment_median_6  -  0.025297615582538145
# impundment_mean_2  -  0.023759382908327034
# slope_min_4  -  0.02279837746946569
# slope_std_4  -  0.022609627431217298
#
#
# Amount of features used:   22
# Cohen's kappa score         0.5974510573419618
# Accuracy score              0.9837589497894842
# Recall score                0.5733953815084731
# Precision score             0.6418966737438075
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'impundment_amplified', 'skyview_gabor_no_streams', 'skyview_max_6', 'impundment_max_6', 'hpmf_mean_6', 'slope_median_6', 'hpmf_filter', 'impoundment_amplified_no_streams', 'slope_std_6', 'skyview_non_ditch', 'hpmf_min_4', 'skyview_min_6', 'skyview_median_6', 'slope_min_6', 'skyview_max_4', 'impundment_median_6', 'impundment_mean_2']
#
#
# Amount of features X_train: 20, X_test: 20
# Amount of features X_train: 20, X_test: 20
#
#
# Importances for experiment:
# impundment_mean_3  -  0.367486264684814
# impundment_mean_4  -  0.04969806128514505
# hpmf_median_4  -  0.04728341931488971
# skyview_gabor_no_streams  -  0.038029889856230424
# impundment_amplified  -  0.03769641329870689
# skyview_max_6  -  0.0351619516523807
# slope_std_6  -  0.03440577226033856
# impundment_max_6  -  0.034280450000752416
# slope_median_6  -  0.03350719750573808
# hpmf_mean_6  -  0.032111990649094924
# hpmf_filter  -  0.03169852233733661
# slope_min_6  -  0.0314653211156493
# skyview_non_ditch  -  0.030609927997182967
# impoundment_amplified_no_streams  -  0.030399721315403836
# skyview_min_6  -  0.028973759958776286
# hpmf_min_4  -  0.02864986135313155
# skyview_median_6  -  0.028368844850662295
# skyview_max_4  -  0.027524094298991508
# impundment_median_6  -  0.02738567101444557
# impundment_mean_2  -  0.025262865250329346
#
#
# Amount of features used:   20
# Cohen's kappa score         0.588256786903474
# Accuracy score              0.9833852936906372
# Recall score                0.5649661954517516
# Precision score             0.6322367645324843
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'skyview_gabor_no_streams', 'impundment_amplified', 'skyview_max_6', 'slope_std_6', 'impundment_max_6', 'slope_median_6', 'hpmf_mean_6', 'hpmf_filter', 'slope_min_6', 'skyview_non_ditch', 'impoundment_amplified_no_streams', 'skyview_min_6', 'hpmf_min_4', 'skyview_median_6', 'skyview_max_4']
#
#
# Amount of features X_train: 18, X_test: 18
# Amount of features X_train: 18, X_test: 18
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3763014589688574
# impundment_mean_4  -  0.05298734837997526
# hpmf_median_4  -  0.04967904883765605
# skyview_gabor_no_streams  -  0.04032705781581902
# impundment_amplified  -  0.03951156765583648
# impundment_max_6  -  0.03807782989933935
# skyview_max_6  -  0.03789207479664167
# slope_std_6  -  0.037747237232852004
# slope_median_6  -  0.03635774521544763
# hpmf_filter  -  0.034769791374303
# hpmf_mean_6  -  0.03438544022109148
# slope_min_6  -  0.03395494955222575
# skyview_non_ditch  -  0.033007384190100415
# impoundment_amplified_no_streams  -  0.03239436947772096
# skyview_min_6  -  0.03151803747992991
# skyview_median_6  -  0.031044470700035458
# hpmf_min_4  -  0.03031259434045163
# skyview_max_4  -  0.029731593861716542
#
#
# Amount of features used:   18
# Cohen's kappa score         0.5980500954951795
# Accuracy score              0.9842449319548556
# Recall score                0.5569584686978664
# Precision score             0.6645712848881066
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'skyview_gabor_no_streams', 'impundment_amplified', 'impundment_max_6', 'skyview_max_6', 'slope_std_6', 'slope_median_6', 'hpmf_filter', 'hpmf_mean_6', 'slope_min_6', 'skyview_non_ditch', 'impoundment_amplified_no_streams', 'skyview_min_6', 'skyview_median_6']
#
#
# Amount of features X_train: 16, X_test: 16
# Amount of features X_train: 16, X_test: 16
#
#
# Importances for experiment:
# impundment_mean_3  -  0.37778360999915
# impundment_mean_4  -  0.05629467687172981
# hpmf_median_4  -  0.05127962439658103
# skyview_max_6  -  0.04884877862050198
# skyview_gabor_no_streams  -  0.04524578634716646
# impundment_amplified  -  0.04205707011570124
# slope_std_6  -  0.04120406987151219
# impundment_max_6  -  0.0406689758659005
# hpmf_mean_6  -  0.04040184826334097
# slope_median_6  -  0.039628908535181286
# skyview_median_6  -  0.0390319700645109
# hpmf_filter  -  0.0378304420063722
# slope_min_6  -  0.03660794288294632
# skyview_non_ditch  -  0.03488938987046132
# skyview_min_6  -  0.034407505333207536
# impoundment_amplified_no_streams  -  0.03381940095573633
#
#
# Amount of features used:   16
# Cohen's kappa score         0.5863740269277316
# Accuracy score              0.9836947634657558
# Recall score                0.5496882957239442
# Precision score             0.6475918570009931
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_mean_4', 'hpmf_median_4', 'skyview_max_6', 'skyview_gabor_no_streams', 'impundment_amplified', 'slope_std_6', 'impundment_max_6', 'hpmf_mean_6', 'slope_median_6', 'skyview_median_6', 'hpmf_filter', 'slope_min_6', 'skyview_non_ditch']
#
#
# Amount of features X_train: 14, X_test: 14
# Amount of features X_train: 14, X_test: 14
#
#
# Importances for experiment:
# impundment_mean_3  -  0.37978368186069683
# impundment_amplified  -  0.06971160315623098
# impundment_mean_4  -  0.058490135544695204
# skyview_max_6  -  0.052946708319341965
# hpmf_median_4  -  0.052664548645081646
# skyview_gabor_no_streams  -  0.04874210329875148
# impundment_max_6  -  0.04549770451620344
# slope_std_6  -  0.045018595102642125
# hpmf_mean_6  -  0.04286631966318486
# slope_median_6  -  0.04267221704420036
# skyview_median_6  -  0.042584881538160896
# hpmf_filter  -  0.040822125540300444
# slope_min_6  -  0.04009755238563451
# skyview_non_ditch  -  0.03810182338487539
#
#
# Amount of features used:   14
# Cohen's kappa score         0.5857616407258348
# Accuracy score              0.9834953273884571
# Recall score                0.5552726314865221
# Precision score             0.6388653170081222
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_amplified', 'impundment_mean_4', 'skyview_max_6', 'hpmf_median_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'slope_std_6', 'hpmf_mean_6', 'slope_median_6', 'skyview_median_6', 'hpmf_filter']
#
#
# Amount of features X_train: 12, X_test: 12
# Amount of features X_train: 12, X_test: 12
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3840169211475611
# impundment_amplified  -  0.07595816610362127
# skyview_max_6  -  0.0643701249449237
# impundment_mean_4  -  0.06283839146803852
# hpmf_median_4  -  0.055419705596030655
# skyview_gabor_no_streams  -  0.05521394135338045
# impundment_max_6  -  0.05333881290129903
# slope_std_6  -  0.05173401180430549
# slope_median_6  -  0.05159301316834703
# skyview_median_6  -  0.05097986140925713
# hpmf_mean_6  -  0.04781488623416463
# hpmf_filter  -  0.04672216386907095
#
#
# Amount of features used:   12
# Cohen's kappa score         0.5719352321269038
# Accuracy score              0.9822001390703681
# Recall score                0.56728422161735
# Precision score             0.5954434859544349
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_amplified', 'skyview_max_6', 'impundment_mean_4', 'hpmf_median_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'slope_std_6', 'slope_median_6', 'skyview_median_6']
# Amount of features X_train: 10, X_test: 10
# Amount of features X_train: 10, X_test: 10
#
#
# Importances for experiment:
# impundment_mean_3  -  0.3908593663868433
# impundment_amplified  -  0.08534543733425909
# skyview_max_6  -  0.0753470020552641
# impundment_mean_4  -  0.07259573216225848
# hpmf_median_4  -  0.06535152604180632
# skyview_gabor_no_streams  -  0.06419530852297099
# impundment_max_6  -  0.06275577746898112
# slope_median_6  -  0.0619892707736107
# slope_std_6  -  0.060864265239933615
# skyview_median_6  -  0.06069631401407219
#
#
# Amount of features used:   10
# Cohen's kappa score         0.5594106453964741
# Accuracy score              0.9807857475796407
# Recall score                0.5835104047765388
# Precision score             0.5556335908498043
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_amplified', 'skyview_max_6', 'impundment_mean_4', 'hpmf_median_4', 'skyview_gabor_no_streams', 'impundment_max_6', 'slope_median_6']
#
#
# Amount of features X_train: 8, X_test: 8
# Amount of features X_train: 8, X_test: 8
#
#
# Importances for experiment:
# impundment_mean_3  -  0.4027047005237149
# impundment_amplified  -  0.09786993583978491
# skyview_max_6  -  0.09752860555481019
# slope_median_6  -  0.0849598679393389
# impundment_mean_4  -  0.08399231034768959
# skyview_gabor_no_streams  -  0.08329141673012905
# impundment_max_6  -  0.07849008396133336
# hpmf_median_4  -  0.07116307910319902
#
#
# Amount of features used:   8
# Cohen's kappa score         0.5344071935811645
# Accuracy score              0.9784223154452162
# Recall score                0.5948898059531127
# Precision score             0.5034777956126271
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_amplified', 'skyview_max_6', 'slope_median_6', 'impundment_mean_4', 'skyview_gabor_no_streams']
#
#
# Amount of features X_train: 6, X_test: 6
# Amount of features X_train: 6, X_test: 6
#
#
# Importances for experiment:
# impundment_mean_3  -  0.43625107652500017
# impundment_amplified  -  0.12419891534709447
# skyview_max_6  -  0.12220464047876081
# slope_median_6  -  0.1104455343315813
# impundment_mean_4  -  0.10570727016342382
# skyview_gabor_no_streams  -  0.10119256315413935
#
#
# Amount of features used:   6
# Cohen's kappa score         0.48583475423920053
# Accuracy score              0.974525288647426
# Recall score                0.5822460268680305
# Precision score             0.43601073062963547
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'impundment_amplified', 'skyview_max_6', 'slope_median_6']
#
#
# Amount of features X_train: 4, X_test: 4
# Amount of features X_train: 4, X_test: 4
#
#
# Importances for experiment:
# impundment_mean_3  -  0.5030177473940215
# skyview_max_6  -  0.1775983430593177
# impundment_amplified  -  0.1651079279356123
# slope_median_6  -  0.15427598161104847
#
#
# Amount of features used:   4
# Cohen's kappa score         0.3383060752692465
# Accuracy score              0.9530251625671473
# Recall score                0.6034243568355431
# Precision score             0.2550434201736807
#
# ------------------------------------------------------
#
# Features used in experiment:
# ['impundment_mean_3', 'skyview_max_6']
#
#
# Amount of features X_train: 2, X_test: 2
# Amount of features X_train: 2, X_test: 2
#
#
# Importances for experiment:
# impundment_mean_3  -  0.6785085717458932
# skyview_max_6  -  0.32149142825410676
#
#
# Amount of features used:   2
# Cohen's kappa score         0.23806864268390515
# Accuracy score              0.9353624616983396
# Recall score                0.5300904381420669
# Precision score             0.17488181312569523
#
# ------------------------------------------------------

# %%
from itertools import product

# %%
params = [["gini", "entropy"],
          [35, None],
          [2, 10],
          ["balanced", None],
          [200, 300]]

# %%
most_important_features = ['impundment_mean_3', 'impundment_mean_4', 'hpmf_mean_4', 'impundment_mean_2',
                           'impundment_amplified', 'hpmf_median_4', 'impoundment_amplified_no_streams', 'hpmf_mean_3',
                           'skyview_max_6', 'slope_std_6', 'impundment_median_4', 'hpmf_min_2', 'hpmf_mean_6',
                           'skyview_max_4', 'slope_min_6', 'skyview_gabor', 'hpmf_min_4', 'skyview_gabor_no_streams',
                           'impundment_max_6', 'skyview_non_ditch', 'skyview_median_6', 'impundment_std_4', 'skyview_min_6',
                           'slope_min_4', 'slope_median_6', 'slope_std_4', 'impundment_median_2', 'skyview_max_2',
                           'impundment_median_6', 'hpmf_std_6', 'hpmf_gabor_no_streams', 'skyview_std_6', 'hpmf_filter',
                           'impundment_mean_6', 'slope_mean_6', 'slope_min_2', 'skyview_median_2', 'hpmf_filter_no_streams',
                           'impundment_std_6', 'slope_non_ditch']

# %%
param_combos = list(product(*params))

# %%
len(param_combos)
# Out:
# 32

# %%
params_and_score = []
j = 0
for combo in param_combos:
    j += 1
    y_test_all = []
    pred_all = []
    
    params = {'criterion': combo[0],
    'max_depth': combo[1],
    'min_samples_split': combo[2],
    'class_weight': combo[3],
    'n_estimators': combo[4]}
    print(f"params: {params}")
    
    for (training_dataset, test_dataset) in experiment_arr:

        X_train = training_dataset.filter(items=most_important_features).loc[:, training_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_train = training_dataset["label_3m"]
        training_dataset = None

        clf = RandomForestClassifier(**params, n_jobs=-1, random_state=42)
        print(clf)

        clf.fit(X_train, y_train)

        X_test = test_dataset.filter(items=most_important_features).loc[:, test_dataset.filter(items=most_important_features).columns != "label_3m"]
        y_test = test_dataset["label_3m"]
        
        print(f"Amount of features X_train: {len(X_train.columns)}, X_test: {len(X_test.columns)}")
  
        
        proba = clf.predict_proba(X_test)[:,1:].reshape(2997,2620)
        
        proba_post_process = post_processing.proba_post_process(proba, 6, 0.4)
    
        labels_grid = post_processing.raster_to_zones(np.array(y_test).reshape(2997, 2620), 6, 4)

        for i, pred_var in enumerate(proba_post_process.reshape(-1)):
            y_test_all.append(labels_grid.reshape(-1)[i])
            pred_all.append(pred_var)

    print("\n")
    print(f"Iteration {j} of {len(param_combos)}")
    print("Cohen's kappa score        ", cohen_kappa_score(y_test_all, pred_all))
    print("Accuracy score             ", accuracy_score(y_test_all, pred_all))
    print("Recall score               ", recall_score(y_test_all, pred_all))
    print("Precision score            ", precision_score(y_test_all, pred_all))
    print("\n------------------------------------------------------\n")
    params_and_score.append((params, cohen_kappa_score(y_test_all, pred_all)))

print(params_and_score)
# Out:
# params: {'criterion': 'gini', 'max_depth': 35, 'min_samples_split': 2, 'class_weight': 'balanced', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=35, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=89, verbose=0,
#                        warm_start=False)

# %%
sorted(params_and_score,key=lambda x:(-x[1],x[0]))
